# %% [markdown]
# **Load packages**

# %%
import os
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from scipy.stats import kurtosis
from scipy.stats import skew
from sklearn.metrics import accuracy_score, confusion_matrix

sns.set()
PATH="../input/"

# %% [markdown]
# **Load data**

# %%
X_train_df = pd.read_csv(PATH+"/career-con-2019/X_train.csv")
X_test_df = pd.read_csv(PATH+"/career-con-2019/X_test.csv")
Y_train_df = pd.read_csv(PATH+"/career-con-2019/y_train.csv")
target = pd.read_csv(PATH+'/career-con-2019/y_train.csv')
sub = pd.read_csv(PATH+"/career-con-2019/sample_submission.csv")

# %% [markdown]
# # Feature Engineering

# %%
def fe(data):
    df = pd.DataFrame()
    data['totl_anglr_vel'] = (data['angular_velocity_X']**2 + data['angular_velocity_Y']**2 + data['angular_velocity_Z']**2)** 0.5
    data['totl_linr_acc'] = (data['linear_acceleration_X']**2 + data['linear_acceleration_Y']**2 + data['linear_acceleration_Z']**2)**0.5
    data['totl_xyz'] = (data['orientation_X']**2 + data['orientation_Y']**2 + data['orientation_Z']**2)**0.5
    data['acc_vs_vel'] = data['totl_linr_acc'] / data['totl_anglr_vel']
    
    def mean_change_of_abs_change(x):
        return np.mean(np.diff(np.abs(np.diff(x))))
    
    for col in data.columns:
        if col in ['row_id','series_id','measurement_number']:
            continue
        df[col + '_mean'] = data.groupby(['series_id'])[col].mean()
        df[col + '_median'] = data.groupby(['series_id'])[col].median()
        df[col + '_max'] = data.groupby(['series_id'])[col].max()
        df[col + '_min'] = data.groupby(['series_id'])[col].min()
        df[col + '_std'] = data.groupby(['series_id'])[col].std()
        df[col + '_range'] = df[col + '_max'] - df[col + '_min']
        df[col + '_maxtoMin'] = df[col + '_max'] / df[col + '_min']
        df[col + '_mean_abs_chg'] = data.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        df[col + '_mean_change_of_abs_change'] = data.groupby('series_id')[col].apply(mean_change_of_abs_change)
        df[col + '_abs_max'] = data.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        df[col + '_abs_min'] = data.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        df[col + '_abs_avg'] = (df[col + '_abs_min'] + df[col + '_abs_max'])/2
    return df

train_df = fe(X_train_df)
test_df = fe(X_test_df)
print ("New features: ",train_df.shape[1])
display(train_df.head())
# Out:
# New features:  168
#            orientation_X_mean         ...          acc_vs_vel_abs_avg
# series_id                             ...
# 0                   -0.758666         ...                  525.847045
# 1                   -0.958606         ...                  322.382516
# 2                   -0.512057         ...                  478.552183
# 3                   -0.939169         ...                  408.614740
# 4                   -0.891301         ...                   75.741783
#
# [5 rows x 168 columns]

# %% [markdown]
# **Filling missing NAs and infinite data ∞  by zeroes 0**

# %%
train_df.fillna(0, inplace = True)
train_df.replace(-np.inf, 0, inplace = True)
train_df.replace(np.inf, 0, inplace = True)
test_df.fillna(0, inplace = True)
test_df.replace(-np.inf, 0, inplace = True)
test_df.replace(np.inf, 0, inplace = True)

# %% [markdown]
# **Standarization**

# %%
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(train_df))
X_test_scaled = pd.DataFrame(scaler.transform(test_df))
X_train_scaled.head()
# Out:
#         0         1         2      ...          165       166       167
# 0 -1.080161 -1.079898 -1.089366    ...     0.143058  0.063600  0.139838
# 1 -1.371767 -1.371667 -1.381118    ...    -0.075991 -0.166719 -0.081564
# 2 -0.720492 -0.720416 -0.726728    ...     0.090946  0.030849  0.088373
# 3 -1.343418 -1.343338 -1.352650    ...     0.034807 -0.381534  0.012270
# 4 -1.273604 -1.273001 -1.276691    ...    -0.361545 -0.097638 -0.349948
#
# [5 rows x 168 columns]

# %% [markdown]
# **Label Encoding**

# %%
le = LabelEncoder()
target['surface'] = le.fit_transform(target['surface'])
target.head()
# Out:
#    series_id  group_id  surface
# 0          0        13        2
# 1          1        31        1
# 2          2        20        1
# 3          3        31        1
# 4          4        22        6

# %% [markdown]
# # XGBoost

# %%
folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=59)

# %%
data = X_train_scaled
test = X_test_scaled

# %%
predicted = np.zeros((test.shape[0],9))
measured = np.zeros((data.shape[0]))
score = 0

# %% [markdown]
# ### SUFFLE + BOOTSTRAP

# %%
# https://www.kaggle.com/jiweiliu/lgb-2-leaves-augment#500381
def shuffle_col_vals(x1):
    rand_x = np.array([np.random.choice(x1.shape[0], size=x1.shape[0], replace=False) for i in range(x1.shape[1])]).T
    grid = np.indices(x1.shape)
    rand_y = grid[1]
    return x1[(rand_x, rand_y)]

def augment(x,y,t=2):
    xs,xn = [],[]
    for i in range(t):
        mask = y>0
        x1 = x[mask].copy()
        x1 = shuffle_col_vals(x1)
        xs.append(x1)

    for i in range(t//2):
        mask = y==0
        x1 = x[mask].copy()
        x1 = shuffle_col_vals(x1)
        xn.append(x1)

    xs = np.vstack(xs); xn = np.vstack(xn)
    ys = np.ones(xs.shape[0]);yn = np.zeros(xn.shape[0])
    x = np.vstack([x,xs,xn]); y = np.concatenate([y,ys,yn])
    
    return x,y

# %%
# Grid search
max_depth = [7, 8, 10, 12, 15, 20, 25]
subsample = [0.3, 0.5, 0.7, 0.8, 1.0]
colsample_bytree = [0.3, 0.5, 0.7, 0.8, 1.0]
param_grid = dict(max_depth=max_depth, subsample=subsample, colsample_bytree=colsample_bytree)

# K-Fold cross validation
n_folds = 5
kfold = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=0)

# Model
model = XGBClassifier(n_estimators=300, random_state=2019)

grid_search = GridSearchCV(model, param_grid, scoring="accuracy", n_jobs=-1, cv=kfold, verbose=1)
result = grid_search.fit(data.values, target['surface'].values)

print("Best: %f using %s" % (result.best_score_, result.best_params_))
means = result.cv_results_['mean_test_score']
stds = result.cv_results_['std_test_score']
params = result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 5 folds for each of 175 candidates, totalling 875 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed: 55.1min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 166.9min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 380.9min
# [Parallel(n_jobs=-1)]: Done 875 out of 875 | elapsed: 442.1min finished
# Best: 0.897375 using {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 1.0}
# 0.869291 (0.008207) with: {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 0.3}
# 0.888189 (0.009426) with: {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 0.5}
# 0.890814 (0.008965) with: {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 0.7}
# 0.894488 (0.009084) with: {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 0.8}
# 0.892126 (0.008939) with: {'colsample_bytree': 0.3, 'max_depth': 7, 'subsample': 1.0}
# 0.866404 (0.012597) with: {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 0.3}
# 0.883990 (0.006217) with: {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 0.5}
# 0.890814 (0.007329) with: {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 0.7}
# 0.895538 (0.007317) with: {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 0.8}
# 0.895801 (0.011452) with: {'colsample_bytree': 0.3, 'max_depth': 8, 'subsample': 1.0}
# 0.867717 (0.008481) with: {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 0.3}
# 0.886089 (0.006162) with: {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 0.5}
# 0.892651 (0.012384) with: {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 0.7}
# 0.892913 (0.010751) with: {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 0.8}
# 0.895276 (0.010293) with: {'colsample_bytree': 0.3, 'max_depth': 10, 'subsample': 1.0}
# 0.869029 (0.007215) with: {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 0.3}
# 0.887139 (0.007929) with: {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 0.5}
# 0.892126 (0.008450) with: {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 0.7}
# 0.894751 (0.007967) with: {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 0.8}
# 0.897375 (0.007190) with: {'colsample_bytree': 0.3, 'max_depth': 12, 'subsample': 1.0}
# 0.868766 (0.005912) with: {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 0.3}
# 0.884777 (0.006052) with: {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 0.5}
# 0.891601 (0.007074) with: {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 0.7}
# 0.897113 (0.007494) with: {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 0.8}
# 0.896850 (0.008112) with: {'colsample_bytree': 0.3, 'max_depth': 15, 'subsample': 1.0}
# 0.866404 (0.009955) with: {'colsample_bytree': 0.3, 'max_depth': 20, 'subsample': 0.3}
# 0.884252 (0.004953) with: {'colsample_bytree': 0.3, 'max_depth': 20, 'subsample': 0.5}
# 0.891076 (0.007677) with: {'colsample_bytree': 0.3, 'max_depth': 20, 'subsample': 0.7}
# 0.896063 (0.009941) with: {'colsample_bytree': 0.3, 'max_depth': 20, 'subsample': 0.8}
# 0.895276 (0.010888) with: {'colsample_bytree': 0.3, 'max_depth': 20, 'subsample': 1.0}
# 0.866667 (0.009682) with: {'colsample_bytree': 0.3, 'max_depth': 25, 'subsample': 0.3}
# 0.882940 (0.006159) with: {'colsample_bytree': 0.3, 'max_depth': 25, 'subsample': 0.5}
# 0.891864 (0.010026) with: {'colsample_bytree': 0.3, 'max_depth': 25, 'subsample': 0.7}
# 0.894488 (0.009062) with: {'colsample_bytree': 0.3, 'max_depth': 25, 'subsample': 0.8}
# 0.893176 (0.008821) with: {'colsample_bytree': 0.3, 'max_depth': 25, 'subsample': 1.0}
# 0.863780 (0.011808) with: {'colsample_bytree': 0.5, 'max_depth': 7, 'subsample': 0.3}
# 0.880052 (0.003963) with: {'colsample_bytree': 0.5, 'max_depth': 7, 'subsample': 0.5}
# 0.888451 (0.006297) with: {'colsample_bytree': 0.5, 'max_depth': 7, 'subsample': 0.7}
# 0.890814 (0.010253) with: {'colsample_bytree': 0.5, 'max_depth': 7, 'subsample': 0.8}
# 0.891864 (0.009906) with: {'colsample_bytree': 0.5, 'max_depth': 7, 'subsample': 1.0}
# 0.869816 (0.005400) with: {'colsample_bytree': 0.5, 'max_depth': 8, 'subsample': 0.3}
# 0.881890 (0.008309) with: {'colsample_bytree': 0.5, 'max_depth': 8, 'subsample': 0.5}
# 0.886089 (0.007464) with: {'colsample_bytree': 0.5, 'max_depth': 8, 'subsample': 0.7}
# 0.891601 (0.012182) with: {'colsample_bytree': 0.5, 'max_depth': 8, 'subsample': 0.8}
# 0.892651 (0.008775) with: {'colsample_bytree': 0.5, 'max_depth': 8, 'subsample': 1.0}
# 0.870341 (0.010579) with: {'colsample_bytree': 0.5, 'max_depth': 10, 'subsample': 0.3}
# 0.879528 (0.007617) with: {'colsample_bytree': 0.5, 'max_depth': 10, 'subsample': 0.5}
# 0.886089 (0.006822) with: {'colsample_bytree': 0.5, 'max_depth': 10, 'subsample': 0.7}
# 0.892388 (0.009126) with: {'colsample_bytree': 0.5, 'max_depth': 10, 'subsample': 0.8}
# 0.889239 (0.014951) with: {'colsample_bytree': 0.5, 'max_depth': 10, 'subsample': 1.0}
# 0.865879 (0.006026) with: {'colsample_bytree': 0.5, 'max_depth': 12, 'subsample': 0.3}
# 0.885039 (0.007720) with: {'colsample_bytree': 0.5, 'max_depth': 12, 'subsample': 0.5}
# 0.885827 (0.005016) with: {'colsample_bytree': 0.5, 'max_depth': 12, 'subsample': 0.7}
# 0.891601 (0.007324) with: {'colsample_bytree': 0.5, 'max_depth': 12, 'subsample': 0.8}
# 0.888451 (0.013375) with: {'colsample_bytree': 0.5, 'max_depth': 12, 'subsample': 1.0}
# 0.868504 (0.007597) with: {'colsample_bytree': 0.5, 'max_depth': 15, 'subsample': 0.3}
# 0.880052 (0.008425) with: {'colsample_bytree': 0.5, 'max_depth': 15, 'subsample': 0.5}
# 0.885302 (0.007280) with: {'colsample_bytree': 0.5, 'max_depth': 15, 'subsample': 0.7}
# 0.890551 (0.008747) with: {'colsample_bytree': 0.5, 'max_depth': 15, 'subsample': 0.8}
# 0.891864 (0.011699) with: {'colsample_bytree': 0.5, 'max_depth': 15, 'subsample': 1.0}
# 0.869291 (0.005310) with: {'colsample_bytree': 0.5, 'max_depth': 20, 'subsample': 0.3}
# 0.880840 (0.007562) with: {'colsample_bytree': 0.5, 'max_depth': 20, 'subsample': 0.5}
# 0.886089 (0.008193) with: {'colsample_bytree': 0.5, 'max_depth': 20, 'subsample': 0.7}
# 0.894488 (0.010064) with: {'colsample_bytree': 0.5, 'max_depth': 20, 'subsample': 0.8}
# 0.890551 (0.011611) with: {'colsample_bytree': 0.5, 'max_depth': 20, 'subsample': 1.0}
# 0.869291 (0.005310) with: {'colsample_bytree': 0.5, 'max_depth': 25, 'subsample': 0.3}
# 0.882152 (0.005780) with: {'colsample_bytree': 0.5, 'max_depth': 25, 'subsample': 0.5}
# 0.885302 (0.007222) with: {'colsample_bytree': 0.5, 'max_depth': 25, 'subsample': 0.7}
# 0.892126 (0.011736) with: {'colsample_bytree': 0.5, 'max_depth': 25, 'subsample': 0.8}
# 0.890551 (0.010046) with: {'colsample_bytree': 0.5, 'max_depth': 25, 'subsample': 1.0}
# 0.862730 (0.006296) with: {'colsample_bytree': 0.7, 'max_depth': 7, 'subsample': 0.3}
# 0.878740 (0.007972) with: {'colsample_bytree': 0.7, 'max_depth': 7, 'subsample': 0.5}
# 0.883727 (0.009886) with: {'colsample_bytree': 0.7, 'max_depth': 7, 'subsample': 0.7}
# 0.888976 (0.009321) with: {'colsample_bytree': 0.7, 'max_depth': 7, 'subsample': 0.8}
# 0.891076 (0.014449) with: {'colsample_bytree': 0.7, 'max_depth': 7, 'subsample': 1.0}
# 0.863255 (0.007821) with: {'colsample_bytree': 0.7, 'max_depth': 8, 'subsample': 0.3}
# 0.878740 (0.008008) with: {'colsample_bytree': 0.7, 'max_depth': 8, 'subsample': 0.5}
# 0.883990 (0.001184) with: {'colsample_bytree': 0.7, 'max_depth': 8, 'subsample': 0.7}
# 0.889501 (0.007748) with: {'colsample_bytree': 0.7, 'max_depth': 8, 'subsample': 0.8}
# 0.886089 (0.011496) with: {'colsample_bytree': 0.7, 'max_depth': 8, 'subsample': 1.0}
# 0.862467 (0.002392) with: {'colsample_bytree': 0.7, 'max_depth': 10, 'subsample': 0.3}
# 0.880052 (0.009905) with: {'colsample_bytree': 0.7, 'max_depth': 10, 'subsample': 0.5}
# 0.884777 (0.007158) with: {'colsample_bytree': 0.7, 'max_depth': 10, 'subsample': 0.7}
# 0.890551 (0.008775) with: {'colsample_bytree': 0.7, 'max_depth': 10, 'subsample': 0.8}
# 0.887927 (0.013071) with: {'colsample_bytree': 0.7, 'max_depth': 10, 'subsample': 1.0}
# 0.862992 (0.008190) with: {'colsample_bytree': 0.7, 'max_depth': 12, 'subsample': 0.3}
# 0.881102 (0.009505) with: {'colsample_bytree': 0.7, 'max_depth': 12, 'subsample': 0.5}
# 0.884252 (0.009243) with: {'colsample_bytree': 0.7, 'max_depth': 12, 'subsample': 0.7}
# 0.887664 (0.009128) with: {'colsample_bytree': 0.7, 'max_depth': 12, 'subsample': 0.8}
# 0.886089 (0.012026) with: {'colsample_bytree': 0.7, 'max_depth': 12, 'subsample': 1.0}
# 0.862205 (0.011309) with: {'colsample_bytree': 0.7, 'max_depth': 15, 'subsample': 0.3}
# 0.881365 (0.008808) with: {'colsample_bytree': 0.7, 'max_depth': 15, 'subsample': 0.5}
# 0.883727 (0.009442) with: {'colsample_bytree': 0.7, 'max_depth': 15, 'subsample': 0.7}
# 0.887402 (0.006085) with: {'colsample_bytree': 0.7, 'max_depth': 15, 'subsample': 0.8}
# 0.888189 (0.013770) with: {'colsample_bytree': 0.7, 'max_depth': 15, 'subsample': 1.0}
# 0.857480 (0.007976) with: {'colsample_bytree': 0.7, 'max_depth': 20, 'subsample': 0.3}
# 0.880052 (0.005779) with: {'colsample_bytree': 0.7, 'max_depth': 20, 'subsample': 0.5}
# 0.883727 (0.009120) with: {'colsample_bytree': 0.7, 'max_depth': 20, 'subsample': 0.7}
# 0.887139 (0.007155) with: {'colsample_bytree': 0.7, 'max_depth': 20, 'subsample': 0.8}
# 0.888451 (0.011713) with: {'colsample_bytree': 0.7, 'max_depth': 20, 'subsample': 1.0}
# 0.860105 (0.003555) with: {'colsample_bytree': 0.7, 'max_depth': 25, 'subsample': 0.3}
# 0.878478 (0.009403) with: {'colsample_bytree': 0.7, 'max_depth': 25, 'subsample': 0.5}
# 0.883465 (0.012625) with: {'colsample_bytree': 0.7, 'max_depth': 25, 'subsample': 0.7}
# 0.890289 (0.008892) with: {'colsample_bytree': 0.7, 'max_depth': 25, 'subsample': 0.8}
# 0.885827 (0.012322) with: {'colsample_bytree': 0.7, 'max_depth': 25, 'subsample': 1.0}
# 0.865092 (0.007443) with: {'colsample_bytree': 0.8, 'max_depth': 7, 'subsample': 0.3}
# 0.876903 (0.008572) with: {'colsample_bytree': 0.8, 'max_depth': 7, 'subsample': 0.5}
# 0.884252 (0.007442) with: {'colsample_bytree': 0.8, 'max_depth': 7, 'subsample': 0.7}
# 0.886089 (0.010095) with: {'colsample_bytree': 0.8, 'max_depth': 7, 'subsample': 0.8}
# 0.888976 (0.013459) with: {'colsample_bytree': 0.8, 'max_depth': 7, 'subsample': 1.0}
# 0.868766 (0.008514) with: {'colsample_bytree': 0.8, 'max_depth': 8, 'subsample': 0.3}
# 0.878215 (0.006145) with: {'colsample_bytree': 0.8, 'max_depth': 8, 'subsample': 0.5}
# 0.882152 (0.008224) with: {'colsample_bytree': 0.8, 'max_depth': 8, 'subsample': 0.7}
# 0.886877 (0.010345) with: {'colsample_bytree': 0.8, 'max_depth': 8, 'subsample': 0.8}
# 0.887139 (0.011755) with: {'colsample_bytree': 0.8, 'max_depth': 8, 'subsample': 1.0}
# 0.859580 (0.013312) with: {'colsample_bytree': 0.8, 'max_depth': 10, 'subsample': 0.3}
# 0.874803 (0.009487) with: {'colsample_bytree': 0.8, 'max_depth': 10, 'subsample': 0.5}
# 0.881365 (0.009003) with: {'colsample_bytree': 0.8, 'max_depth': 10, 'subsample': 0.7}
# 0.887402 (0.013903) with: {'colsample_bytree': 0.8, 'max_depth': 10, 'subsample': 0.8}
# 0.888189 (0.013437) with: {'colsample_bytree': 0.8, 'max_depth': 10, 'subsample': 1.0}
# 0.861417 (0.009809) with: {'colsample_bytree': 0.8, 'max_depth': 12, 'subsample': 0.3}
# 0.878215 (0.006506) with: {'colsample_bytree': 0.8, 'max_depth': 12, 'subsample': 0.5}
# 0.881102 (0.010815) with: {'colsample_bytree': 0.8, 'max_depth': 12, 'subsample': 0.7}
# 0.887139 (0.010085) with: {'colsample_bytree': 0.8, 'max_depth': 12, 'subsample': 0.8}
# 0.888189 (0.012553) with: {'colsample_bytree': 0.8, 'max_depth': 12, 'subsample': 1.0}
# 0.861155 (0.006848) with: {'colsample_bytree': 0.8, 'max_depth': 15, 'subsample': 0.3}
# 0.874541 (0.009512) with: {'colsample_bytree': 0.8, 'max_depth': 15, 'subsample': 0.5}
# 0.882152 (0.010530) with: {'colsample_bytree': 0.8, 'max_depth': 15, 'subsample': 0.7}
# 0.886089 (0.010157) with: {'colsample_bytree': 0.8, 'max_depth': 15, 'subsample': 0.8}
# 0.885827 (0.010710) with: {'colsample_bytree': 0.8, 'max_depth': 15, 'subsample': 1.0}
# 0.860892 (0.009408) with: {'colsample_bytree': 0.8, 'max_depth': 20, 'subsample': 0.3}
# 0.877165 (0.009898) with: {'colsample_bytree': 0.8, 'max_depth': 20, 'subsample': 0.5}
# 0.881102 (0.006954) with: {'colsample_bytree': 0.8, 'max_depth': 20, 'subsample': 0.7}
# 0.887927 (0.009761) with: {'colsample_bytree': 0.8, 'max_depth': 20, 'subsample': 0.8}
# 0.886877 (0.010847) with: {'colsample_bytree': 0.8, 'max_depth': 20, 'subsample': 1.0}
# 0.862467 (0.010558) with: {'colsample_bytree': 0.8, 'max_depth': 25, 'subsample': 0.3}
# 0.879528 (0.008234) with: {'colsample_bytree': 0.8, 'max_depth': 25, 'subsample': 0.5}
# 0.882940 (0.008541) with: {'colsample_bytree': 0.8, 'max_depth': 25, 'subsample': 0.7}
# 0.886877 (0.007756) with: {'colsample_bytree': 0.8, 'max_depth': 25, 'subsample': 0.8}
# 0.886089 (0.012958) with: {'colsample_bytree': 0.8, 'max_depth': 25, 'subsample': 1.0}
# 0.858005 (0.009079) with: {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 0.3}
# 0.875066 (0.010840) with: {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 0.5}
# 0.882152 (0.007442) with: {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 0.7}
# 0.887139 (0.009645) with: {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 0.8}
# 0.889764 (0.013404) with: {'colsample_bytree': 1.0, 'max_depth': 7, 'subsample': 1.0}
# 0.856693 (0.007034) with: {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 0.3}
# 0.875066 (0.009535) with: {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 0.5}
# 0.881627 (0.011103) with: {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 0.7}
# 0.885564 (0.007154) with: {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 0.8}
# 0.886877 (0.014948) with: {'colsample_bytree': 1.0, 'max_depth': 8, 'subsample': 1.0}
# 0.860367 (0.005768) with: {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 0.3}
# 0.875853 (0.005557) with: {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 0.5}
# 0.883202 (0.007885) with: {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 0.7}
# 0.886877 (0.009956) with: {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 0.8}
# 0.887139 (0.009950) with: {'colsample_bytree': 1.0, 'max_depth': 10, 'subsample': 1.0}
# 0.861155 (0.009418) with: {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 0.3}
# 0.874541 (0.006271) with: {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 0.5}
# 0.883990 (0.007924) with: {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 0.7}
# 0.887664 (0.010110) with: {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 0.8}
# 0.884514 (0.012974) with: {'colsample_bytree': 1.0, 'max_depth': 12, 'subsample': 1.0}
# 0.857218 (0.007061) with: {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 0.3}
# 0.877953 (0.007267) with: {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 0.5}
# 0.883202 (0.006779) with: {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 0.7}
# 0.884514 (0.009742) with: {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 0.8}
# 0.886089 (0.008275) with: {'colsample_bytree': 1.0, 'max_depth': 15, 'subsample': 1.0}
# 0.859843 (0.006942) with: {'colsample_bytree': 1.0, 'max_depth': 20, 'subsample': 0.3}
# 0.877165 (0.007278) with: {'colsample_bytree': 1.0, 'max_depth': 20, 'subsample': 0.5}
# 0.886352 (0.007508) with: {'colsample_bytree': 1.0, 'max_depth': 20, 'subsample': 0.7}
# 0.889239 (0.011623) with: {'colsample_bytree': 1.0, 'max_depth': 20, 'subsample': 0.8}
# 0.881102 (0.011605) with: {'colsample_bytree': 1.0, 'max_depth': 20, 'subsample': 1.0}
# 0.858793 (0.008310) with: {'colsample_bytree': 1.0, 'max_depth': 25, 'subsample': 0.3}
# 0.877690 (0.003495) with: {'colsample_bytree': 1.0, 'max_depth': 25, 'subsample': 0.5}
# 0.886089 (0.009332) with: {'colsample_bytree': 1.0, 'max_depth': 25, 'subsample': 0.7}
# 0.888451 (0.012146) with: {'colsample_bytree': 1.0, 'max_depth': 25, 'subsample': 0.8}
# 0.880840 (0.010671) with: {'colsample_bytree': 1.0, 'max_depth': 25, 'subsample': 1.0}

# %%
for times, (trn_idx, val_idx) in enumerate(folds.split(data.values,target['surface'].values)):
    model = XGBClassifier(n_estimators=300, bootstrap=True, class_weight="balanced", random_state=2019)
    model.fit(data.iloc[trn_idx],target['surface'][trn_idx])
    measured[val_idx] = model.predict(data.iloc[val_idx])
    predicted += model.predict_proba(test)/folds.n_splits
    score += model.score(data.iloc[val_idx],target['surface'][val_idx])
    print("Fold: {} score: {}".format(times,model.score(data.iloc[val_idx],target['surface'][val_idx])))

    importances = model.feature_importances_
    indices = np.argsort(importances)
    features = data.columns
    
    if model.score(data.iloc[val_idx],target['surface'][val_idx]) > 0.9500:
        hm = 30
        plt.figure(figsize=(7, 10))
        plt.title('Feature Importances')
        plt.barh(range(len(indices[:hm])), importances[indices][:hm], color='b', align='center')
        plt.yticks(range(len(indices[:hm])), [features[i] for i in indices])
        plt.xlabel('Relative Importance')
        plt.show()
# Out:
# Fold: 0 score: 0.9194805194805195
# Fold: 1 score: 0.8671875
# Fold: 2 score: 0.8798955613577023
# Fold: 3 score: 0.8900523560209425
# Fold: 4 score: 0.8818897637795275
# Fold: 5 score: 0.868766404199475
# Fold: 6 score: 0.8530183727034121
# Fold: 7 score: 0.8786279683377308
# Fold: 8 score: 0.8624338624338624
# Fold: 9 score: 0.9202127659574468

# %%
print('Avg Accuracy', score / folds.n_splits)
Y_val_max = measured
val_pred = target['surface']
labels_names = target['surface'].unique()
cnf_matrix = confusion_matrix(Y_val_max, val_pred)
cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(cnf_matrix_norm, index=labels_names, columns=labels_names)

plt.figure(figsize=(20, 7))
ax = plt.axes()
ax.set_title('Validation')
sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax)
plt.show()
# Out:
# Avg Accuracy 0.8821565074270618

# %% [markdown]
# **Submission**

# %%
test_sub = model.predict(test)
sub['surface'] = le.inverse_transform(test_sub)
sub.to_csv('submission.csv', index=False)
sub.head()
# Out:
#    series_id                 surface
# 0          0  hard_tiles_large_space
# 1          1                  carpet
# 2          2                   tiled
# 3          3              soft_tiles
# 4          4              soft_tiles
