# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from keras import optimizers
from keras.layers import Dense, Dropout
from keras.utils import to_categorical
from keras.models import Sequential, Model
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load data

# %%
train = pd.read_csv('../input/X_train.csv')
labels = pd.read_csv('../input/y_train.csv')
test = pd.read_csv('../input/X_test.csv')

# %% [markdown]
# ### Join train features with labels

# %%
train = pd.merge(train, labels, how='inner')
print(train.shape)
display(train.head())
display(train.describe().T)
# Out:
# (487680, 15)
#   row_id  series_id      ...        group_id        surface
# 0    0_0          0      ...              13  fine_concrete
# 1    0_1          0      ...              13  fine_concrete
# 2    0_2          0      ...              13  fine_concrete
# 3    0_3          0      ...              13  fine_concrete
# 4    0_4          0      ...              13  fine_concrete
#
# [5 rows x 15 columns]
#                           count     ...             max
# series_id              487680.0     ...      3809.00000
# measurement_number     487680.0     ...       127.00000
# orientation_X          487680.0     ...         0.98910
# orientation_Y          487680.0     ...         0.98898
# orientation_Z          487680.0     ...         0.15571
# orientation_W          487680.0     ...         0.15477
# angular_velocity_X     487680.0     ...         2.28220
# angular_velocity_Y     487680.0     ...         1.07910
# angular_velocity_Z     487680.0     ...         1.38730
# linear_acceleration_X  487680.0     ...        36.79700
# linear_acceleration_Y  487680.0     ...        73.00800
# linear_acceleration_Z  487680.0     ...        65.83900
# group_id               487680.0     ...        72.00000
#
# [13 rows x 8 columns]

# %% [markdown]
# ### Pre process the labels

# %%
target = train['surface']
n_labels = target.nunique()
labels_names = target.unique()
le = LabelEncoder()
target = le.fit_transform(target.values)
target = to_categorical(target)
train.drop('surface', axis=1, inplace=True)

# %% [markdown]
# ### Train/validation split

# %%
features = ['angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z', 
            'linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z', 
            'series_id', 'measurement_number']

X_train, X_val, Y_train, Y_val = train_test_split(train[features], target, test_size=0.2, random_state=0)

# %% [markdown]
# ### Feature engineering

# %%
def agg_features(df):
#     df['orientation'] = df['orientation_X'] + df['orientation_Y'] + df['orientation_Z'] + df['orientation_W']
    df['angular_velocity'] = df['angular_velocity_X'] + df['angular_velocity_Y'] + df['angular_velocity_Z']
    df['linear_acceleration'] = df['linear_acceleration_X'] + df['linear_acceleration_Y'] + df['linear_acceleration_Z']
    
agg_features(X_train)
agg_features(X_val)
agg_features(test)

# %% [markdown]
# ### Mean encoding on categorical features

# %%
features.append('angular_velocity')
features.append('linear_acceleration')
mean_enc_features = list(features)

# By series
for feature in (features):
    if feature not in ['series_id', 'measurement_number']:
        median = '%s_series_mean' % feature
        std = '%s_series_std' % feature
        diff = '%s_series_mean_diff' % feature
        mean_enc_features.append(median)
        mean_enc_features.append(std)
        mean_enc_features.append(diff)
        X_train[median] = X_train['series_id'].map(X_train.groupby('series_id')[feature].mean())
        X_val[median] = X_val['series_id'].map(X_val.groupby('series_id')[feature].mean())
        test[median] = test['series_id'].map(test.groupby('series_id')[feature].mean())
        
        X_train[std] = X_train['series_id'].map(X_train.groupby('series_id')[feature].std())
        X_val[std] = X_val['series_id'].map(X_val.groupby('series_id')[feature].std())
        test[std] = test['series_id'].map(test.groupby('series_id')[feature].std())
        
        X_train[diff] = X_train[feature] - X_train[median]
        X_val[diff] = X_val[feature] - X_val[median]
        test[diff] = test[feature] - test[median]
    

# By measurement
for feature in (features):
    if feature not in ['series_id', 'measurement_number']:
        median = '%s_measurement_mean' % feature
        std = '%s_measurement_std' % feature
        diff = '%s_measurement_mean_diff' % feature
        mean_enc_features.append(median)
        mean_enc_features.append(std)
        mean_enc_features.append(diff)
        X_train[median] = X_train['measurement_number'].map(X_train.groupby('measurement_number')[feature].mean())
        X_val[median] = X_val['measurement_number'].map(X_val.groupby('measurement_number')[feature].mean())
        test[median] = test['measurement_number'].map(test.groupby('measurement_number')[feature].mean())
        
        X_train[std] = X_train['measurement_number'].map(X_train.groupby('measurement_number')[feature].std())
        X_val[std] = X_val['measurement_number'].map(X_val.groupby('measurement_number')[feature].std())
        test[std] = test['measurement_number'].map(test.groupby('measurement_number')[feature].std())
        
        X_train[diff] = X_train[feature] - X_train[median]
        X_val[diff] = X_val[feature] - X_val[median]
        test[diff] = test[feature] - test[median]
    
features = list(mean_enc_features)

# %%
X_train.drop(['series_id', 'measurement_number'], axis=1, inplace=True)
X_val.drop(['series_id', 'measurement_number'], axis=1, inplace=True)

features = list(X_train.columns)
print('Train shape', X_train.shape)
print('Validation shape', X_val.shape)
display(X_train.describe().T)
# Out:
# Train shape (390144, 56)
# Validation shape (97536, 56)
#                                                 count     ...             max
# angular_velocity_X                           390144.0     ...        2.282200
# angular_velocity_Y                           390144.0     ...        1.079100
# angular_velocity_Z                           390144.0     ...        1.272500
# linear_acceleration_X                        390144.0     ...       36.797000
# linear_acceleration_Y                        390144.0     ...       73.008000
# linear_acceleration_Z                        390144.0     ...       55.766000
# angular_velocity                             390144.0     ...        3.073330
# linear_acceleration                          390144.0     ...      122.698700
# angular_velocity_X_series_mean               390144.0     ...        0.192636
# angular_velocity_X_series_std                390144.0     ...        0.808108
# angular_velocity_X_series_mean_diff          390144.0     ...        2.233904
# angular_velocity_Y_series_mean               390144.0     ...        0.341735
# angular_velocity_Y_series_std                390144.0     ...        0.294912
# angular_velocity_Y_series_mean_diff          390144.0     ...        1.041195
# angular_velocity_Z_series_mean               390144.0     ...        0.900606
# angular_velocity_Z_series_std                390144.0     ...        0.567906
# angular_velocity_Z_series_mean_diff          390144.0     ...        1.266870
# linear_acceleration_X_series_mean            390144.0     ...        1.285731
# linear_acceleration_X_series_std             390144.0     ...       11.461467
# linear_acceleration_X_series_mean_diff       390144.0     ...       36.230897
# linear_acceleration_Y_series_mean            390144.0     ...        4.150350
# linear_acceleration_Y_series_std             390144.0     ...       25.214114
# linear_acceleration_Y_series_mean_diff       390144.0     ...       72.538670
# linear_acceleration_Z_series_mean            390144.0     ...       -7.734875
# linear_acceleration_Z_series_std             390144.0     ...       18.977340
# linear_acceleration_Z_series_mean_diff       390144.0     ...       66.667456
# angular_velocity_series_mean                 390144.0     ...        0.611305
# angular_velocity_series_std                  390144.0     ...        0.903421
# angular_velocity_series_mean_diff            390144.0     ...        2.879417
# linear_acceleration_series_mean              390144.0     ...       -4.210701
# linear_acceleration_series_std               390144.0     ...       40.546379
# linear_acceleration_series_mean_diff         390144.0     ...      132.141919
# angular_velocity_X_measurement_mean          390144.0     ...        0.007469
# angular_velocity_X_measurement_std           390144.0     ...        0.128434
# angular_velocity_X_measurement_mean_diff     390144.0     ...        2.282746
# angular_velocity_Y_measurement_mean          390144.0     ...        0.010663
# angular_velocity_Y_measurement_std           390144.0     ...        0.092615
# angular_velocity_Y_measurement_mean_diff     390144.0     ...        1.072940
# angular_velocity_Z_measurement_mean          390144.0     ...       -0.015033
# angular_velocity_Z_measurement_std           390144.0     ...        0.235696
# angular_velocity_Z_measurement_mean_diff     390144.0     ...        1.291741
# linear_acceleration_X_measurement_mean       390144.0     ...        0.238596
# linear_acceleration_X_measurement_std        390144.0     ...        2.072934
# linear_acceleration_X_measurement_mean_diff  390144.0     ...       36.688108
# linear_acceleration_Y_measurement_mean       390144.0     ...        2.981398
# linear_acceleration_Y_measurement_std        390144.0     ...        3.158332
# linear_acceleration_Y_measurement_mean_diff  390144.0     ...       70.141631
# linear_acceleration_Z_measurement_mean       390144.0     ...       -9.197749
# linear_acceleration_Z_measurement_std        390144.0     ...        3.091649
# linear_acceleration_Z_measurement_mean_diff  390144.0     ...       65.047095
# angular_velocity_measurement_mean            390144.0     ...       -0.003905
# angular_velocity_measurement_std             390144.0     ...        0.211654
# angular_velocity_measurement_mean_diff       390144.0     ...        3.078595
# linear_acceleration_measurement_mean         390144.0     ...       -6.100791
# linear_acceleration_measurement_std          390144.0     ...        5.457053
# linear_acceleration_measurement_mean_diff    390144.0     ...      128.976842
#
# [56 rows x 8 columns]

# %% [markdown]
# ### Scale the data

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(test[features])

# %% [markdown]
# ### Model

# %%
epochs = 100
batch = 128
lr = 0.001
adam = optimizers.Adam(lr)

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(n_labels, activation="softmax"))
model.compile(loss='categorical_crossentropy', optimizer=adam)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               7296
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 9)                 585
# =================================================================
# Total params: 16,137
# Trainable params: 16,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=epochs, verbose=2)
# Out:
# Train on 390144 samples, validate on 97536 samples
# Epoch 1/100
#  - 40s - loss: 1.5933 - val_loss: 1.4301
# Epoch 2/100
#  - 38s - loss: 1.4732 - val_loss: 1.3871
# Epoch 3/100
#  - 40s - loss: 1.4460 - val_loss: 1.3892
# Epoch 4/100
#  - 39s - loss: 1.4325 - val_loss: 1.3554
# Epoch 5/100
#  - 39s - loss: 1.4234 - val_loss: 1.3644
# Epoch 6/100
#  - 38s - loss: 1.4151 - val_loss: 1.3793
# Epoch 7/100
#  - 39s - loss: 1.4093 - val_loss: 1.3529
# Epoch 8/100
#  - 38s - loss: 1.4035 - val_loss: 1.3327
# Epoch 9/100
#  - 39s - loss: 1.3999 - val_loss: 1.3301
# Epoch 10/100
#  - 38s - loss: 1.3950 - val_loss: 1.3294
# Epoch 11/100
#  - 40s - loss: 1.3935 - val_loss: 1.3295
# Epoch 12/100
#  - 38s - loss: 1.3912 - val_loss: 1.3337
# Epoch 13/100
#  - 39s - loss: 1.3888 - val_loss: 1.3301
# Epoch 14/100
#  - 38s - loss: 1.3893 - val_loss: 1.3212
# Epoch 15/100
#  - 39s - loss: 1.3855 - val_loss: 1.3269
# Epoch 16/100
#  - 38s - loss: 1.3848 - val_loss: 1.3306
# Epoch 17/100
#  - 39s - loss: 1.3826 - val_loss: 1.3177
# Epoch 18/100
#  - 38s - loss: 1.3801 - val_loss: 1.3275
# Epoch 19/100
#  - 39s - loss: 1.3791 - val_loss: 1.3175
# Epoch 20/100
#  - 38s - loss: 1.3790 - val_loss: 1.3406
# Epoch 21/100
#  - 38s - loss: 1.3787 - val_loss: 1.3161
# Epoch 22/100
#  - 38s - loss: 1.3749 - val_loss: 1.3252
# Epoch 23/100
#  - 38s - loss: 1.3750 - val_loss: 1.3296
# Epoch 24/100
#  - 38s - loss: 1.3742 - val_loss: 1.3281
# Epoch 25/100
#  - 38s - loss: 1.3741 - val_loss: 1.3418
# Epoch 26/100
#  - 39s - loss: 1.3735 - val_loss: 1.3232
# Epoch 27/100
#  - 38s - loss: 1.3707 - val_loss: 1.3377
# Epoch 28/100
#  - 39s - loss: 1.3707 - val_loss: 1.3290
# Epoch 29/100
#  - 38s - loss: 1.3703 - val_loss: 1.3203
# Epoch 30/100
#  - 38s - loss: 1.3698 - val_loss: 1.3336
# Epoch 31/100
#  - 38s - loss: 1.3708 - val_loss: 1.3318
# Epoch 32/100
#  - 38s - loss: 1.3685 - val_loss: 1.3241
# Epoch 33/100
#  - 37s - loss: 1.3687 - val_loss: 1.3150
# Epoch 34/100
#  - 38s - loss: 1.3686 - val_loss: 1.3240
# Epoch 35/100
#  - 37s - loss: 1.3659 - val_loss: 1.3361
# Epoch 36/100
#  - 40s - loss: 1.3677 - val_loss: 1.3348
# Epoch 37/100
#  - 37s - loss: 1.3665 - val_loss: 1.3252
# Epoch 38/100
#  - 38s - loss: 1.3669 - val_loss: 1.3160
# Epoch 39/100
#  - 37s - loss: 1.3656 - val_loss: 1.3140
# Epoch 40/100
#  - 38s - loss: 1.3626 - val_loss: 1.3360
# Epoch 41/100
#  - 38s - loss: 1.3646 - val_loss: 1.3276
# Epoch 42/100
#  - 37s - loss: 1.3629 - val_loss: 1.3292
# Epoch 43/100
#  - 38s - loss: 1.3627 - val_loss: 1.3220
# Epoch 44/100
#  - 39s - loss: 1.3635 - val_loss: 1.3201
# Epoch 45/100
#  - 38s - loss: 1.3616 - val_loss: 1.3163
# Epoch 46/100
#  - 37s - loss: 1.3608 - val_loss: 1.3204
# Epoch 47/100
#  - 38s - loss: 1.3616 - val_loss: 1.3173
# Epoch 48/100
#  - 37s - loss: 1.3614 - val_loss: 1.3180
# Epoch 49/100
#  - 38s - loss: 1.3603 - val_loss: 1.3161
# Epoch 50/100
#  - 37s - loss: 1.3587 - val_loss: 1.3126
# Epoch 51/100
#  - 38s - loss: 1.3584 - val_loss: 1.3325
# Epoch 52/100
#  - 38s - loss: 1.3600 - val_loss: 1.3138
# Epoch 53/100
#  - 38s - loss: 1.3597 - val_loss: 1.3216
# Epoch 54/100
#  - 37s - loss: 1.3591 - val_loss: 1.3210
# Epoch 55/100
#  - 38s - loss: 1.3571 - val_loss: 1.3479
# Epoch 56/100
#  - 37s - loss: 1.3587 - val_loss: 1.3203
# Epoch 57/100
#  - 37s - loss: 1.3571 - val_loss: 1.3228
# Epoch 58/100
#  - 38s - loss: 1.3572 - val_loss: 1.3167
# Epoch 59/100
#  - 37s - loss: 1.3568 - val_loss: 1.3169
# Epoch 60/100
#  - 40s - loss: 1.3561 - val_loss: 1.3290
# Epoch 61/100
#  - 37s - loss: 1.3566 - val_loss: 1.3201
# Epoch 62/100
#  - 38s - loss: 1.3555 - val_loss: 1.3243
# Epoch 63/100
#  - 37s - loss: 1.3565 - val_loss: 1.3201
# Epoch 64/100
#  - 38s - loss: 1.3566 - val_loss: 1.3225
# Epoch 65/100
#  - 37s - loss: 1.3538 - val_loss: 1.3185
# Epoch 66/100
#  - 38s - loss: 1.3555 - val_loss: 1.3236
# Epoch 67/100
#  - 37s - loss: 1.3555 - val_loss: 1.3225
# Epoch 68/100
#  - 39s - loss: 1.3545 - val_loss: 1.3223
# Epoch 69/100
#  - 38s - loss: 1.3551 - val_loss: 1.3189
# Epoch 70/100
#  - 38s - loss: 1.3540 - val_loss: 1.3245
# Epoch 71/100
#  - 37s - loss: 1.3538 - val_loss: 1.3240
# Epoch 72/100
#  - 38s - loss: 1.3552 - val_loss: 1.3320
# Epoch 73/100
#  - 37s - loss: 1.3535 - val_loss: 1.3349
# Epoch 74/100
#  - 37s - loss: 1.3535 - val_loss: 1.3114
# Epoch 75/100
#  - 38s - loss: 1.3536 - val_loss: 1.3309
# Epoch 76/100
#  - 38s - loss: 1.3526 - val_loss: 1.3141
# Epoch 77/100
#  - 38s - loss: 1.3526 - val_loss: 1.3182
# Epoch 78/100
#  - 37s - loss: 1.3530 - val_loss: 1.3268
# Epoch 79/100
#  - 38s - loss: 1.3515 - val_loss: 1.3239
# Epoch 80/100
#  - 37s - loss: 1.3521 - val_loss: 1.3160
# Epoch 81/100
#  - 38s - loss: 1.3521 - val_loss: 1.3212
# Epoch 82/100
#  - 37s - loss: 1.3523 - val_loss: 1.3159
# Epoch 83/100
#  - 38s - loss: 1.3512 - val_loss: 1.3226
# Epoch 84/100
#  - 38s - loss: 1.3499 - val_loss: 1.3191
# Epoch 85/100
#  - 39s - loss: 1.3508 - val_loss: 1.3194
# Epoch 86/100
#  - 37s - loss: 1.3515 - val_loss: 1.3137
# Epoch 87/100
#  - 38s - loss: 1.3534 - val_loss: 1.3211
# Epoch 88/100
#  - 37s - loss: 1.3499 - val_loss: 1.3207
# Epoch 89/100
#  - 37s - loss: 1.3489 - val_loss: 1.3190
# Epoch 90/100
#  - 38s - loss: 1.3509 - val_loss: 1.3324
# Epoch 91/100
#  - 37s - loss: 1.3504 - val_loss: 1.3200
# Epoch 92/100
#  - 38s - loss: 1.3493 - val_loss: 1.3156
# Epoch 93/100
#  - 38s - loss: 1.3495 - val_loss: 1.3296
# Epoch 94/100
#  - 38s - loss: 1.3490 - val_loss: 1.3222
# Epoch 95/100
#  - 37s - loss: 1.3481 - val_loss: 1.3163
# Epoch 96/100
#  - 38s - loss: 1.3488 - val_loss: 1.3203
# Epoch 97/100
#  - 37s - loss: 1.3496 - val_loss: 1.3150
# Epoch 98/100
#  - 38s - loss: 1.3487 - val_loss: 1.3151
# Epoch 99/100
#  - 37s - loss: 1.3486 - val_loss: 1.3200
# Epoch 100/100
#  - 38s - loss: 1.3478 - val_loss: 1.3337

# %% [markdown]
# #### Model loss plot

# %%
history_pd = pd.DataFrame.from_dict(history.history)
plt.figure(figsize=(20, 8))
ax = plt.axes()
ax.set_title('Model Loss')
sns.lineplot(data=history_pd)
plt.show()

# %% [markdown]
# #### Model evaluation

# %%
train_pred = model.predict_classes(X_train)
val_pred = model.predict_classes(X_val)
Y_train_max = np.argmax(Y_train, axis=1)
Y_val_max = np.argmax(Y_val, axis=1)

print('Train accuracy', accuracy_score(Y_train_max, train_pred))
print('Validation accuracy', accuracy_score(Y_val_max, val_pred))
# Out:
# Train accuracy 0.541133530183727
# Validation accuracy 0.5170706200787402

# %% [markdown]
# #### Model confusion matrix

# %%
cnf_matrix = confusion_matrix(Y_train_max, train_pred)
cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(cnf_matrix_norm, index=labels_names, columns=labels_names)

plt.figure(figsize=(20, 7))
ax = plt.axes()
ax.set_title('Train')
sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax)
plt.show()

cnf_matrix = confusion_matrix(Y_val_max, val_pred)
cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(cnf_matrix_norm, index=labels_names, columns=labels_names)

plt.figure(figsize=(20, 7))
ax = plt.axes()
ax.set_title('Validation')
sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax)
plt.show()

# %% [markdown]
# ### Test predictions

# %%
predictions = model.predict_classes(X_test)
test['surface'] = le.inverse_transform(predictions)
df = test[['series_id', 'surface']]
df = df.groupby('series_id', as_index=False).agg(lambda x:x.value_counts().index[0])
df.to_csv('submission.csv', index=False)
df.head(10)
