# %% [markdown]
# **Load packages**

# %%
import os
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from scipy.stats import kurtosis
from scipy.stats import skew
from sklearn.metrics import accuracy_score, confusion_matrix
from bayes_opt import BayesianOptimization

sns.set()
PATH="../input/"

# %% [markdown]
# **Load data**

# %%
X_train_df = pd.read_csv(PATH+"/X_train.csv")
X_test_df = pd.read_csv(PATH+"/X_test.csv")
Y_train_df = pd.read_csv(PATH+"/y_train.csv")
target = pd.read_csv(PATH+'/y_train.csv')
sub = pd.read_csv(PATH+"/sample_submission.csv")

# %% [markdown]
# # Feature Engineering

# %%
def fe(data):
    df = pd.DataFrame()
    data['totl_anglr_vel'] = (data['angular_velocity_X']**2 + data['angular_velocity_Y']**2 + data['angular_velocity_Z']**2)** 0.5
    data['totl_linr_acc'] = (data['linear_acceleration_X']**2 + data['linear_acceleration_Y']**2 + data['linear_acceleration_Z']**2)**0.5
    data['totl_xyz'] = (data['orientation_X']**2 + data['orientation_Y']**2 + data['orientation_Z']**2)**0.5
    data['acc_vs_vel'] = data['totl_linr_acc'] / data['totl_anglr_vel']
    
    def mean_change_of_abs_change(x):
        return np.mean(np.diff(np.abs(np.diff(x))))
    
    for col in data.columns:
        if col in ['row_id','series_id','measurement_number']:
            continue
        df[col + '_mean'] = data.groupby(['series_id'])[col].mean()
        df[col + '_median'] = data.groupby(['series_id'])[col].median()
        df[col + '_max'] = data.groupby(['series_id'])[col].max()
        df[col + '_min'] = data.groupby(['series_id'])[col].min()
        df[col + '_std'] = data.groupby(['series_id'])[col].std()
        df[col + '_range'] = df[col + '_max'] - df[col + '_min']
        df[col + '_maxtoMin'] = df[col + '_max'] / df[col + '_min']
        df[col + '_mean_abs_chg'] = data.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        df[col + '_mean_change_of_abs_change'] = data.groupby('series_id')[col].apply(mean_change_of_abs_change)
        df[col + '_abs_max'] = data.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        df[col + '_abs_min'] = data.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        df[col + '_abs_avg'] = (df[col + '_abs_min'] + df[col + '_abs_max'])/2
    return df

train_df = fe(X_train_df)
test_df = fe(X_test_df)
print ("New features: ",train_df.shape[1])
display(train_df.head())
# Out:
# New features:  168
#            orientation_X_mean         ...          acc_vs_vel_abs_avg
# series_id                             ...
# 0                   -0.758666         ...                  525.847045
# 1                   -0.958606         ...                  322.382516
# 2                   -0.512057         ...                  478.552183
# 3                   -0.939169         ...                  408.614740
# 4                   -0.891301         ...                   75.741783
#
# [5 rows x 168 columns]

# %% [markdown]
# **Filling missing NAs and infinite data ∞  by zeroes 0**

# %%
train_df.fillna(0, inplace = True)
train_df.replace(-np.inf, 0, inplace = True)
train_df.replace(np.inf, 0, inplace = True)
test_df.fillna(0, inplace = True)
test_df.replace(-np.inf, 0, inplace = True)
test_df.replace(np.inf, 0, inplace = True)

# %% [markdown]
# **Standarization**

# %%
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(train_df))
X_test_scaled = pd.DataFrame(scaler.transform(test_df))
X_train_scaled.head()
# Out:
#         0         1         2      ...          165       166       167
# 0 -1.080161 -1.079898 -1.089366    ...     0.143058  0.063600  0.139838
# 1 -1.371767 -1.371667 -1.381118    ...    -0.075991 -0.166719 -0.081564
# 2 -0.720492 -0.720416 -0.726728    ...     0.090946  0.030849  0.088373
# 3 -1.343418 -1.343338 -1.352650    ...     0.034807 -0.381534  0.012270
# 4 -1.273604 -1.273001 -1.276691    ...    -0.361545 -0.097638 -0.349948
#
# [5 rows x 168 columns]

# %% [markdown]
# **Label Encoding**

# %%
le = LabelEncoder()
target['surface'] = le.fit_transform(target['surface'])
target.head()
# Out:
#    series_id  group_id  surface
# 0          0        13        2
# 1          1        31        1
# 2          2        20        1
# 3          3        31        1
# 4          4        22        6

# %% [markdown]
# # LightGBM

# %%
folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=59)

# %%
data = X_train_scaled
test = X_test_scaled

# %%
predicted = np.zeros((test.shape[0],9))
measured = np.zeros((data.shape[0]))
score = 0

# %% [markdown]
# ### SUFFLE + BOOTSTRAP

# %%
# https://www.kaggle.com/jiweiliu/lgb-2-leaves-augment#500381
def shuffle_col_vals(x1):
    rand_x = np.array([np.random.choice(x1.shape[0], size=x1.shape[0], replace=False) for i in range(x1.shape[1])]).T
    grid = np.indices(x1.shape)
    rand_y = grid[1]
    return x1[(rand_x, rand_y)]

def augment(x,y,t=2):
    xs,xn = [],[]
    for i in range(t):
        mask = y>0
        x1 = x[mask].copy()
        x1 = shuffle_col_vals(x1)
        xs.append(x1)

    for i in range(t//2):
        mask = y==0
        x1 = x[mask].copy()
        x1 = shuffle_col_vals(x1)
        xn.append(x1)

    xs = np.vstack(xs); xn = np.vstack(xn)
    ys = np.ones(xs.shape[0]);yn = np.zeros(xn.shape[0])
    x = np.vstack([x,xs,xn]); y = np.concatenate([y,ys,yn])
    
    return x,y

# %%
def lgbm_evaluate(**params):
    params['max_depth'] = int(params['max_depth'])
    params['min_data_in_leaf'] = int(params['min_data_in_leaf'])
    test_pred_proba = np.zeros((train_df.shape[0], 9))
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(data.values, target['surface'].values)):
        X_train, X_valid = data.iloc[train_idx], data.iloc[valid_idx]
        y_train, y_valid = target['surface'][train_idx], target['surface'][valid_idx]
        
        model = lgb.LGBMClassifier(**params, n_estimators=300, n_jobs=-1)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], 
                  eval_metric='multi_logloss', verbose=False, early_stopping_rounds=100)

        y_pred_valid = model.predict_proba(X_valid)

        test_pred_proba[valid_idx] = y_pred_valid

    return accuracy_score(y_valid, y_pred_valid.argmax(1))

# %%
# Random search
max_depth = np.random.choice(range(6, 25), 10, replace=False)
bagging_fraction = np.random.uniform(0.25, 1, 10)
feature_fraction = np.random.uniform(0.25, 1, 10)
min_data_in_leaf = np.random.choice(range(10, 500), 100, replace=False)
lambda_l1 = np.random.uniform(0, 1, 100)
learning_rate = np.random.uniform(0.0001, 0.1, 100)

param_grid = {
             'max_depth' : (6, 25),
             'bagging_fraction' : (0.25, 1),
             'feature_fraction': (0.25, 1),
             'min_data_in_leaf': (0.25, 1),
             'lambda_l1': (0.25, 1),
             'learning_rate': (0.25, 1)
             }

result = BayesianOptimization(lgbm_evaluate, param_grid)
result.maximize(init_points=15, n_iter=300)
print(result.max["params"])
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l1 | learni... | max_depth | min_da... |
# -------------------------------------------------------------------------------------------------
# |  1        |  0
# |  34       |  0.9282   |  1.0      |  0.25     |  0.25     |  0.25     |  24.04    |  1.0      |
# |  35       |  0.9309   |  0.25     |  0.25     |  0.25     |  0.25     |  22.65    |  0.25     |
# |  36       |  0.9176   |  1.0      |  0.25     |  1.0      |  0.25     |  6.0      |  1.0      |
# |  37       |  0.9149   |  0.2711   |  0.986    |  0.9879   |  0.2897   |  9.17     |  0.2615   |
# |  38       |  0.9149   |  0.25     |  0.25     |  1.0      |  0.25     |  19.58    |  0.25     |
# |  39       |  0.9229   |  0.9295   |  0.7147   |  0.2628   |  0.2568   |  22.28    |  0.3615   |
# |  40       |  0.9229   |  0.25     |  0.25     |  0.25     |  0.25     |  6.0      |  0.7313   |
# |  41       |  0.9282   |  0.25     |  0.25     |  0.25     |  0.25     |  24.06    |  0.25     |
# |  42       |  0.9043   |  0.9828   |  1.0      |  1.0      |  0.25     |  9.81     |  1.0      |
# |  43       |  0.9096   |  0.9515   |  0.2603   |  0.9642   |  0.25     |  13.31    |  1.0      |
# |  44       |  0.9255   |  0.25     |  0.25     |  0.25     |  0.25     |  8.698    |  0.25     |
# |  45       |  0.9069   |  0.25     |  0.25     |  1.0      |  0.25     |  10.25    |  0.25     |
# |  46       |  0.9202   |  1.0      |  1.0      |  0.25     |  0.25     |  6.0      |  1.0      |
# |  47       |  0.9309   |  1.0      |  0.25     |  0.25     |  0.25     |  22.57    |  0.25     |
# |  48       |  0.9176   |  1.0      |  1.0      |  0.996    |  0.25     |  14.04    |  0.9973   |
# |  49       |  0.9202   |  0.3032   |  0.25     |  0.25     |  0.2602   |  22.85    |  0.9007   |
# |  50       |  0.9255   |  0.5429   |  0.25     |  0.25     |  0.25     |  21.21    |  0.25     |
# |  51       |  0.9122   |  0.9545   |  0.9862   |  0.479    |  0.2613   |  24.83    |  0.8633   |
# |  52       |  0.9016   |  0.9624   |  0.2811   |  0.9986   |  0.2821   |  18.82    |  0.8562   |
# |  53       |  0.9202   |  0.25     |  0.25     |  0.25     |  0.25     |  18.6     |  0.25     |
# |  54       |  0.9255   |  0.25     |  0.25     |  0.25     |  0.2557   |  8.306    |  0.9999   |
# |  55       |  0.9255   |  0.9365   |  0.25     |  0.25     |  0.25     |  9.662    |  0.25     |
# |  56       |  0.9229   |  0.2634   |  0.25     |  1.0      |  0.25     |  23.12    |  0.25     |
# |  57       |  0.9202   |  0.25     |  0.25     |  0.25     |  0.25     |  19.45    |  1.0      |
# |  58       |  0.9069   |  0.25     |  1.0      |  0.25     |  0.25     |  6.0      |  1.0      |
# |  59       |  0.9096   |  0.25     |  1.0      |  1.0      |  0.25     |  16.37    |  1.0      |
# |  60       |  0.9096   |  1.0      |  0.7785   |  0.25     |  0.25     |  20.11    |  0.25     |
# |  61       |  0.9096   |  0.25     |  1.0      |  0.25     |  0.25     |  23.53    |  0.25     |
# |  62       |  0.9202   |  0.25     |  0.25     |  0.25     |  0.25     |  24.76    |  0.25     |
# |  63       |  0.9229   |  1.0      |  0.25     |  0.25     |  0.25     |  6.0      |  0.25     |
# |  64       |  0.9069   |  0.9482   |  0.9537   |  0.8171   |  0.2517   |  12.24    |  0.9902   |
# |  65       |  0.9149   |  0.3023   |  0.7756   |  0.9615   |  0.2901   |  13.7     |  0.3025   |
# |  66       |  0.9096   |  0.25     |  0.8663   |  0.25     |  0.25     |  14.04    |  1.0      |
# |  130      |  0.9229   |  0.25     |  0.25     |  0.25     |  0.25     |  6.0      |  0.25     |
# |  131      |  0.9043   |  1.0      |  1.0      |  1.0      |  0.25     |  25.0     |  1.0      |
# |  132      |  0.9122   |  0.25     |  0.25     |  1.0      |  0.25     |  14.02    |  0.2717   |
# |  133      |  0.9122   |  0.25     |  0.8901   |  0.25     |  0.25     |  7.984    |  0.25     |
# |  134      |  0.9122   |  0.9925   |  0.2625   |  0.8769   |  0.2618   |  7.149    |  0.3397   |
# |  135      |  0.9229   |  0.2537   |  0.2652   |  0.7185   |  0.25     |  8.886    |  0.9021   |
# |  136      |  0.9202   |  1.0      |  0.25     |  1.0      |  0.25     |  22.45    |  0.9218   |
# |  137      |  0.9229   |  0.4568   |  0.25     |  0.25     |  0.25     |  6.516    |  0.25     |
# |  138      |  0.9043   |  1.0      |  1.0      |  1.0      |  0.25     |  6.0      |  0.25     |
# |  139      |  0.9202   |  1.0      |  0.25     |  0.25     |  0.25     |  19.06    |  1.0      |
# |  140      |  0.9202   |  0.25     |  0.25     |  0.25     |  0.25     |  17.32    |  0.25     |
# |  141      |  0.9176   |  1.0      |  1.0      |  0.25     |  0.25     |  23.68    |  1.0      |
# |  142      |  0.9122   |  0.25     |  1.0      |  1.0      |  0.25     |  14.89    |  0.25     |
# |  143      |  0.9149   |  1.0      |  0.25     |  0.813    |  0.25     |  10.33    |  0.2834   |
# |  144      |  0.9122   |  1.0      |  1.0      |  0.25     |  0.25     |  13.23    |  1.0      |
# |  145      |  0.9255   |  0.25     |  0.486    |  0.4761   |  0.2713   |  9.459    |  0.4203   |
# |  146      |  0.9229   |  0.25     |  0.25     |  1.0      |  0.25     |  25.0     |  0.25     |
# |  147      |  0.9069   |  1.0      |  1.0      |  0.305    |  0.25     |  25.0     |  0.25     |
# |  148      |  0.875    |  0.3177   |  0.25     |  1.0      |  0.756    |  17.49    |  0.25     |
# |  149      |  0.8644   |  1.0      |  0.25     |  0.25     |  1.0      |  17.65    |  1.0      |
# |  150      |  0.859    |  1.0      |  1.0      |  1.0      |  1.0      |  22.19    |  1.0      |
# |  151      |  0.9069   |  0.9035   |  0.9614   |  0.25     |  0.25     |  16.04    |  1.0      |
# |  152      |  0.9255   |  0.25     |  0.7676   |  0.25     |  0.25     |  11.48    |  0.8342   |
# |  153      |  0.8777   |  0.9922   |  0.8235   |  0.9619   |  0.9629   |  9.02     |  0.2666   |
# |  154      |  0.9176   |  0.25     |  0.25     |  0.25     |  0.25     |  11.96    |  0.916    |
# |  155      |  0.9069   |  0.6116   |  0.507    |  0.7318   |  0.2753   |  14.79    |  0.7934   |
# |  156      |  0.9229   |  1.0      |  0.25     |  0.25     |  0.25     |  15.27    |  0.25     |
# |  157      |  0.8537   |  1.0      |  1.0      |  1.0      |  1.0      |  14.86    |  1.0      |
# |  158      |  0.8644   |  0.25     |  0.25     |  1.0      |  1.0      |  6.0      |  1.0      |
# |  159      |  0.9149   |  0.25     |  1.0      |  0.25     |  0.25     |  16.06    |  0.25     |
# |  160      |  0.9149   |  1.0      |  1.0      |  1.0      |  0.25     |  17.15    |  1.0      |
# |  161      |  0.9229   |  0.25     |  0.25     |  0.25     |  0.25     |  15.42    |  0.25     |
# |  162      |  0.9122   |  0.25     |  0.4049   |  0.25     |  0.25     |  10.95    |  0.2561   |
# |  163      |  0.8963   |  0.9107   |  0.923    |  0.991    |  0.2535   |  12.94    |  0.25     |
# |  164      |  0.8564   |  0.25     |  1.0      |  1.0      |  1.0      |  11.86    |  1.0      |
# |  165      |  0.9016   |  0.25     |  1.0      |  1.0      |  0.25     |  10.4     |  0.25     |
# |  166      |  0.875    |  0.25     |  0.25     |  0.25     |  0.7778   |  7.351    |  0.25     |
# |  167      |  0.9202   |  0.6683   |  0.5671   |  0.2525   |  0.2501   |  7.204    |  0.7964   |
# |  168      |  0.9255   |  0.9968   |  0.271    |  0.9991   |  0.2519   |  23.93    |  0.366    |
# |  169      |  0.9096   |  0.9792   |  0.955    |  0.2706   |  0.269    |  11.49    |  0.3762   |
# |  170      |  0.9202   |  0.25     |  0.25     |  0.25     |  0.25     |  20.58    |  0.8666   |
# |  171      |  0.9255   |  0.25     |  0.25     |  1.0      |  0.25     |  8.744    |  0.25     |
# |  172      |  0.9122   |  0.2521   |  0.4363   |  0.9881   |  0.2569   |  11.8     |  0.9769   |
# |  173      |  0.9069   |  1.0      |  1.0      |  0.25     |  0.25     |  6.0      |  0.25     |
# |  174      |  0.9255   |  1.0      |  0.25     |  0.25     |  0.25     |  14.36    |  0.25     |
# |  175      |  0.9255   |  1.0      |  0.25     |  0.25     |  0.25     |  13.92    |  0.8954   |
# |  176      |  0.9149   |  0.6357   |  0.5203   |  0.287    |  0.2553   |  9.981    |  0.6587   |
# |  177      |  0.9096   |  1.0      |  1.0      |  0.4173   |  0.25     |  7.22     |  1.0      |
# |  178      |  0.9176   |  0.25     |  0.25     |  0.25     |  0.25     |  10.92    |  1.0      |
# |  179      |  0.9069   |  1.0      |  1.0      |  0.25     |  0.25     |  21.42    |  0.25     |
# |  180      |  0.9122   |  0.359    |  0.9166   |  0.2516   |  0.2536   |  17.09    |  0.8034   |
# |  181      |  0.9069   |  0.5815   |  0.4622   |  0.9896   |  0.2627   |  17.87    |  0.8685   |
# |  182      |  0.9202   |  1.0      |  1.0      |  0.25     |  0.25     |  17.12    |  0.25     |
# |  183      |  0.9255   |  0.25     |  0.25     |  0.25     |  0.25     |  21.61    |  0.25     |
# |  184      |  0.9229   |  0.3184   |  0.25     |  0.5624   |  0.2502   |  9.15     |  0.25     |
# |  185      |  0.9282   |  1.0      |  0.25     |  0.3602   |  0.25     |  7.861    |  1.0      |
# |  186      |  0.9229   |  1.0      |  0.25     |  0.25     |  0.25     |  9.139    |  0.25     |
# |  187      |  0.9043   |  1.0      |  1.0      |  1.0      |  0.25     |  23.95    |  1.0      |
# |  188      |  0.9016   |  0.9829   |  0.4048   |  0.5044   |  0.2506   |  22.82    |  0.3505   |
# |  189      |  0.9229   |  0.25     |  0.25     |  1.0      |  0.25     |  24.19    |  0.25     |
# |  190      |  0.9122   |  0.25     |  1.0      |  1.0      |  0.25     |  21.09    |  1.0      |
# |  191      |  0.9176   |  1.0      |  0.25     |  0.25     |  0.25     |  11.51    |  1.0      |
# |  192      |  0.859    |  0.25     |  0.25     |  0.25     |  1.0      |  23.85    |  0.25     |
# |  193      |  0.8777   |  0.9834   |  0.25     |  0.25     |  0.7807   |  14.25    |  0.25     |
# |  194      |  0.9202   |  1.0      |  0.25     |  0.25     |  0.25     |  19.54    |  0.25     |
# |  195      |  0.9176   |  0.3501   |  0.25     |  1.0      |  0.25     |  20.69    |  0.9993   |
# |  196      |  0.9229   |  1.0      |  0.25     |  1.0      |  0.25     |  23.78    |  1.0      |
# |  197      |  0.9202   |  0.25     |  0.25     |  1.0      |  0.25     |  22.04    |  0.9355   |
# |  198      |  0.8617   |  1.0      |  1.0      |  1.0      |  1.0      |  6.0      |  1.0      |
# |  199      |  0.9255   |  0.9039   |  0.25     |  1.0      |  0.25     |  8.067    |  1.0      |
# |  200      |  0.9096   |  0.25     |  1.0      |  0.25     |  0.25     |  22.45    |  0.25     |
# |  201      |  0.9122   |  0.9988   |  0.2833   |  0.9995   |  0.2507   |  14.51    |  0.9094   |
# |  202      |  0.9229   |  0.25     |  0.25     |  1.0      |  0.25     |  9.854    |  1.0      |
# |  203      |  0.9016   |  0.25     |  1.0      |  1.0      |  0.25     |  17.15    |  0.25     |
# |  204      |  0.9069   |  1.0      |  1.0      |  0.25     |  0.25     |  25.0     |  1.0      |
# |  205      |  0.9202   |  0.294    |  0.7699   |  0.9894   |  0.2599   |  8.881    |  0.9885   |
# |  206      |  0.9202   |  0.25     |  0.25     |  1.0      |  0.25     |  18.2     |  0.25     |
# |  207      |  0.8511   |  1.0      |  1.0      |  1.0      |  1.0      |  20.2     |  0.25     |
# |  208      |  0.9069   |  0.25     |  0.25     |  1.0      |  0.25     |  15.13    |  1.0      |
# |  209      |  0.9016   |  0.25     |  1.0      |  1.0      |  0.25     |  19.9     |  1.0      |
# |  210      |  0.9255   |  0.25     |  0.25     |  0.25     |  0.25     |  8.091    |  0.4932   |
# |  211      |  0.9202   |  1.0      |  0.25     |  0.25     |  0.25     |  16.38    |  1.0      |
# |  212      |  0.9096   |  0.9281   |  0.3018   |  0.9978   |  0.2535   |  11.22    |  0.8058   |
# |  213      |  0.9202   |  0.6912   |  0.25     |  0.25     |  0.25     |  19.1     |  0.5567   |
# |  214      |  0.9255   |  0.25     |  0.25     |  0.25     |  0.25     |  23.93    |  0.5915   |
# |  215      |  0.9096   |  0.256    |  0.6991   |  0.2508   |  0.2601   |  6.736    |  0.8611   |
# |  216      |  0.8856   |  1.0      |  0.25     |  1.0      |  0.6127   |  7.486    |  1.0      |
# |  217      |  0.9282   |  0.25     |  0.25     |  0.25     |  0.25     |  23.82    |  1.0      |
# |  218      |  0.8883   |  0.2547   |  0.9973   |  0.2909   |  0.6298   |  9.387    |  0.5924   |
# |  219      |  0.9202   |  0.9798   |  0.9885   |  0.9289   |  0.2893   |  8.305    |  0.921    |
# |  220      |  0.9069   |  1.0      |  1.0      |  0.251    |  0.25     |  22.35    |  0.25     |
# |  221      |  0.9122   |  0.9997   |  0.7647   |  0.985    |  0.2633   |  21.73    |  0.396    |
# |  222      |  0.9202   |  1.0      |  1.0      |  1.0      |  0.25     |  7.357    |  0.25     |
# |  223      |  0.9043   |  0.338    |  0.9625   |  0.9697   |  0.2576   |  7.92     |  0.2647   |
# |  224      |  0.9202   |  0.6303   |  0.2507   |  0.25     |  0.25     |  7.692    |  1.0      |
# |  225      |  0.9309   |  0.9812   |  0.6615   |  0.3054   |  0.3057   |  8.688    |  0.9409   |
# |  226      |  0.9149   |  0.9897   |  0.2551   |  0.3144   |  0.4      |  12.97    |  0.9912   |
# |  227      |  0.9335   |  0.9645   |  0.7233   |  0.5989   |  0.2834   |  8.192    |  0.9525   |
# |  228      |  0.9176   |  0.9863   |  0.3519   |  0.3382   |  0.2621   |  8.405    |  0.9849   |
# |  229      |  0.9122   |  0.9715   |  0.5533   |  0.9191   |  0.2745   |  8.973    |  0.3821   |
# |  230      |  0.9229   |  0.9708   |  0.9141   |  0.298    |  0.2658   |  9.021    |  0.4901   |
# |  231      |  0.9016   |  0.2602   |  0.8468   |  0.25     |  0.25     |  22.36    |  1.0      |
# |  232      |  0.8564   |  0.25     |  0.9911   |  1.0      |  0.9994   |  25.0     |  1.0      |
# |  233      |  0.9122   |  0.957    |  0.51     |  0.8136   |  0.2534   |  7.734    |  0.6875   |
# |  234      |  0.9122   |  0.25     |  1.0      |  1.0      |  0.25     |  21.78    |  0.25     |
# |  235      |  0.9122   |  0.9911   |  0.979    |  0.3446   |  0.424    |  8.267    |  0.8239   |
# |  236      |  0.9255   |  0.8658   |  0.7966   |  0.6497   |  0.275    |  8.749    |  0.9638   |
# |  237      |  0.9016   |  0.6779   |  0.9714   |  0.2559   |  0.25     |  20.41    |  0.9992   |
# |  238      |  0.8404   |  0.3361   |  1.0      |  0.2508   |  1.0      |  6.0      |  0.999    |
# |  239      |  0.8777   |  0.25     |  0.25     |  0.5126   |  0.8759   |  13.93    |  0.9936   |
# |  240      |  0.9069   |  0.25     |  0.25     |  1.0      |  0.25     |  6.0      |  1.0      |
# |  241      |  0.9176   |  0.966    |  0.4116   |  0.4867   |  0.259    |  6.45     |  0.2763   |
# |  242      |  0.9255   |  0.6721   |  0.6971   |  0.6452   |  0.2528   |  8.243    |  0.994    |
# |  243      |  0.9043   |  0.9929   |  0.9425   |  0.2692   |  0.2538   |  10.53    |  0.3646   |
# |  244      |  0.9255   |  0.3011   |  0.6781   |  0.6072   |  0.2549   |  11.36    |  0.6236   |
# |  245      |  0.9122   |  0.25     |  0.25     |  0.5043   |  0.25     |  14.47    |  0.8175   |
# |  246      |  0.8617   |  0.3012   |  0.9827   |  0.9497   |  0.9942   |  6.647    |  0.293    |
# |  247      |  0.9202   |  1.0      |  0.25     |  0.25     |  0.25     |  15.08    |  1.0      |
# |  248      |  0.9149   |  0.25     |  0.25     |  0.25     |  0.25     |  12.68    |  0.25     |
# |  249      |  0.9282   |  0.25     |  0.25     |  0.25     |  0.25     |  24.55    |  0.9932   |
# |  250      |  0.9043   |  0.25     |  1.0      |  0.25     |  0.25     |  14.78    |  0.25     |
# |  251      |  0.9176   |  0.9669   |  0.4336   |  0.7375   |  0.3553   |  11.67    |  0.2581   |
# |  252      |  0.9096   |  1.0      |  1.0      |  1.0      |  0.25     |  16.37    |  0.25     |
# |  253      |  0.8457   |  0.25     |  0.25     |  0.25     |  1.0      |  25.0     |  1.0      |
# |  254      |  0.9282   |  0.9848   |  0.25     |  0.25     |  0.25     |  7.325    |  0.25     |
# |  255      |  0.9096   |  1.0      |  1.0      |  0.25     |  0.25     |  15.99    |  0.25     |
# |  256      |  0.9122   |  0.5545   |  0.8535   |  0.5074   |  0.2749   |  11.51    |  0.9896   |
# |  257      |  0.9149   |  1.0      |  0.25     |  0.25     |  0.25     |  12.17    |  0.25     |
# |  258      |  0.9176   |  0.2781   |  0.6891   |  0.6334   |  0.2773   |  10.36    |  0.99     |
# |  259      |  0.8963   |  0.9983   |  0.5135   |  0.5406   |  0.4078   |  13.91    |  0.9947   |
# |  260      |  0.883    |  0.25     |  1.0      |  1.0      |  0.7992   |  13.59    |  0.25     |
# |  261      |  0.9069   |  1.0      |  1.0      |  1.0      |  0.2717   |  15.08    |  0.9695   |
# |  262      |  0.9122   |  0.25     |  1.0      |  0.25     |  0.25     |  11.3     |  0.25     |
# |  263      |  0.8537   |  1.0      |  0.25     |  1.0      |  1.0      |  12.55    |  1.0      |
# |  264      |  0.9255   |  0.9845   |  0.512    |  0.2869   |  0.3012   |  9.471    |  0.9909   |
# |  265      |  0.859    |  0.25     |  1.0      |  1.0      |  1.0      |  22.4     |  0.25     |
# |  266      |  0.9229   |  0.25     |  0.25     |  0.5777   |  0.25     |  17.75    |  0.25     |
# |  267      |  0.9069   |  0.2837   |  0.5832   |  0.9862   |  0.2506   |  20.71    |  0.3728   |
# |  268      |  0.9069   |  1.0      |  0.2708   |  1.0      |  0.25     |  16.29    |  1.0      |
# |  269      |  0.9149   |  0.25     |  0.25     |  0.25     |  0.25     |  13.5     |  0.25     |
# |  270      |  0.9122   |  0.25     |  1.0      |  0.25     |  0.25     |  12.17    |  1.0      |
# |  271      |  0.9202   |  1.0      |  0.25     |  0.25     |  0.25     |  11.13    |  0.25     |
# |  272      |  0.9069   |  1.0      |  1.0      |  1.0      |  0.25     |  21.45    |  1.0      |
# |  273      |  0.9149   |  0.25     |  0.25     |  1.0      |  0.25     |  12.36    |  0.25     |
# |  274      |  0.9229   |  0.25     |  0.25     |  0.25     |  0.25     |  6.0      |  1.0      |
# |  275      |  0.9202   |  0.25     |  0.25     |  0.25     |  0.25     |  19.48    |  0.25     |
# |  276      |  0.9255   |  0.25     |  0.25     |  0.25     |  0.25     |  9.629    |  0.25     |
# |  277      |  0.9096   |  0.9987   |  0.2605   |  0.9823   |  0.2571   |  24.31    |  0.9522   |
# |  278      |  0.9096   |  1.0      |  1.0      |  1.0      |  0.25     |  18.49    |  0.25     |
# |  279      |  0.9096   |  0.4206   |  0.83     |  0.2666   |  0.2507   |  24.2     |  0.9963   |
# |  280      |  0.9149   |  0.25     |  1.0      |  0.25     |  0.25     |  9.369    |  0.25     |
# |  281      |  0.9255   |  0.25     |  0.25     |  1.0      |  0.25     |  8.185    |  1.0      |
# |  282      |  0.9229   |  0.25     |  0.25     |  1.0      |  0.25     |  23.52    |  0.9103   |
# |  283      |  0.9122   |  0.8311   |  0.2514   |  0.267    |  0.2715   |  14.68    |  0.5638   |
# |  284      |  0.9202   |  0.25     |  0.25     |  0.25     |  0.25     |  16.31    |  0.25     |
# |  285      |  0.891    |  0.9926   |  0.999    |  0.9231   |  0.7804   |  17.97    |  0.2699   |
# |  286      |  0.9122   |  0.9929   |  0.516    |  0.253    |  0.2708   |  21.79    |  0.6379   |
# |  287      |  0.9069   |  1.0      |  1.0      |  0.25     |  0.25     |  24.21    |  0.25     |
# |  288      |  0.9176   |  1.0      |  0.25     |  1.0      |  0.25     |  20.95    |  1.0      |
# |  289      |  0.9255   |  0.9975   |  0.7895   |  0.3729   |  0.2612   |  9.079    |  0.9056   |
# |  290      |  0.9122   |  1.0      |  0.25     |  1.0      |  0.25     |  19.61    |  0.25     |
# |  291      |  0.9255   |  0.25     |  0.25     |  0.25     |  0.25     |  20.99    |  0.25     |
# |  292      |  0.9122   |  0.9872   |  0.3156   |  0.2845   |  0.6178   |  9.707    |  0.6188   |
# |  293      |  0.9122   |  1.0      |  0.7194   |  0.2539   |  0.25     |  7.938    |  1.0      |
# |  294      |  0.9096   |  0.25     |  1.0      |  1.0      |  0.25     |  14.66    |  1.0      |
# |  295      |  0.9069   |  0.5751   |  0.9862   |  0.5095   |  0.2811   |  6.938    |  0.251    |
# |  296      |  0.9096   |  0.2534   |  0.6258   |  0.5273   |  0.2565   |  8.709    |  0.6214   |
# |  297      |  0.9176   |  0.25     |  1.0      |  0.25     |  0.25     |  19.82    |  0.25     |
# |  298      |  0.9202   |  1.0      |  0.2501   |  0.25     |  0.25     |  16.19    |  0.25     |
# |  299      |  0.9122   |  1.0      |  0.2526   |  1.0      |  0.25     |  21.02    |  0.25     |
# |  300      |  0.9282   |  0.2508   |  0.25     |  0.25     |  0.25     |  7.732    |  0.25     |
# |  301      |  0.9255   |  0.25     |  0.25     |  0.25     |  0.25     |  9.422    |  1.0      |
# |  302      |  0.9229   |  0.6294   |  0.25     |  0.25     |  0.25     |  17.82    |  0.25     |
# |  303      |  0.9122   |  0.3387   |  0.46     |  0.9824   |  0.2564   |  9.544    |  0.3957   |
# |  304      |  0.875    |  0.25     |  1.0      |  0.25     |  1.0      |  25.0     |  0.25     |
# |  305      |  0.9202   |  0.25     |  0.25     |  0.25     |  0.25     |  16.98    |  1.0      |
# |  306      |  0.9069   |  1.0      |  1.0      |  0.25     |  0.25     |  16.96    |  1.0      |
# |  307      |  0.9069   |  0.955    |  0.649    |  0.6925   |  0.3393   |  8.397    |  0.9736   |
# |  308      |  0.8777   |  0.2611   |  0.8936   |  0.9746   |  0.9546   |  8.083    |  0.9554   |
# |  309      |  0.8138   |  1.0      |  0.25     |  0.7576   |  1.0      |  6.0      |  0.25     |
# |  310      |  0.9149   |  0.6802   |  0.7831   |  0.674    |  0.2592   |  6.054    |  0.7873   |
# |  311      |  0.9149   |  0.9396   |  0.9513   |  0.7415   |  0.271    |  8.495    |  0.3014   |
# |  312      |  0.9043   |  1.0      |  1.0      |  0.25     |  0.25     |  18.48    |  0.25     |
# |  313      |  0.9122   |  0.7406   |  0.9859   |  0.8074   |  0.2519   |  7.79     |  0.956    |
# |  314      |  0.8644   |  1.0      |  1.0      |  1.0      |  1.0      |  10.69    |  0.25     |
# |  315      |  0.9202   |  1.0      |  0.25     |  0.25     |  0.25     |  18.3     |  1.0      |
# =================================================================================================
# {'bagging_fraction': 0.9645268916004999, 'feature_fraction': 0.7232952528196853, 'lambda_l1': 0.5988724323269623, 'learning_rate': 0.28336969566549086, 'max_depth': 8.191750004840658, 'min_data_in_leaf': 0.9524620980453241}

# %%
for times, (trn_idx, val_idx) in enumerate(folds.split(data.values,target['surface'].values)):
    lgb_train = lgb.Dataset(data.iloc[trn_idx], label=target['surface'][trn_idx])
    lgb_val = lgb.Dataset(data.iloc[val_idx], label=target['surface'][val_idx])
    params = {
    'objective': 'multiclass',
    'metric': 'multi_error', 
    "num_class": 9,
    'nthread': -1,
    'n_estimators': 300,
    'max_depth': int(result.max["params"]['max_depth']),
    'bagging_fraction': result.max["params"]['bagging_fraction'],
    'feature_fraction': result.max["params"]['feature_fraction'],
    'min_data_in_leaf': int(result.max["params"]['min_data_in_leaf']),
    'lambda_l1': result.max["params"]['lambda_l1'],
    'learning_rate': result.max["params"]['learning_rate']
    }
    model = lgb.train(params, lgb_train, valid_sets=[lgb_train, lgb_val], early_stopping_rounds=100, verbose_eval=-1)

    measured[val_idx] = [np.argmax(x) for x in model.predict(data.iloc[val_idx])]
    predicted += model.predict(test)/folds.n_splits
    score += (1 - model.best_score['valid_1']['multi_error'])
    print("Fold: {} score: {}".format(times, (1 - model.best_score['valid_1']['multi_error'])))
# Out:
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [20]	training's multi_error: 0	valid_1's multi_error: 0.103896
# Fold: 0 score: 0.8961038961038961
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [18]	training's multi_error: 0.00175131	valid_1's multi_error: 0.132812
# Fold: 1 score: 0.8671875
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [21]	training's multi_error: 0	valid_1's multi_error: 0.138381
# Fold: 2 score: 0.8616187989556136
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [20]	training's multi_error: 0	valid_1's multi_error: 0.10733
# Fold: 3 score: 0.8926701570680629
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [21]	training's multi_error: 0	valid_1's multi_error: 0.112861
# Fold: 4 score: 0.8871391076115486
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [20]	training's multi_error: 0	valid_1's multi_error: 0.144357
# Fold: 5 score: 0.8556430446194225
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [21]	training's multi_error: 0	valid_1's multi_error: 0.144357
# Fold: 6 score: 0.8556430446194225
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [23]	training's multi_error: 0	valid_1's multi_error: 0.126649
# Fold: 7 score: 0.8733509234828496
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [20]	training's multi_error: 0	valid_1's multi_error: 0.137566
# Fold: 8 score: 0.8624338624338624
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [21]	training's multi_error: 0	valid_1's multi_error: 0.087766
# Fold: 9 score: 0.9122340425531915

# %%
print('Avg Accuracy RF', score / folds.n_splits)
Y_val_max = measured
val_pred = target['surface']
labels_names = target['surface'].unique()
cnf_matrix = confusion_matrix(Y_val_max, val_pred)
cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(cnf_matrix_norm, index=labels_names, columns=labels_names)

plt.figure(figsize=(20, 7))
ax = plt.axes()
ax.set_title('Validation')
sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax)
plt.show()
# Out:
# Avg Accuracy RF 0.876402437744787

# %% [markdown]
# **Submission**

# %%
test_sub = [np.argmax(x) for x in model.predict(test)]
sub['surface'] = le.inverse_transform(test_sub)
sub.to_csv('submission.csv', index=False)
sub.head()
# Out:
#    series_id                 surface
# 0          0  hard_tiles_large_space
# 1          1                concrete
# 2          2                   tiled
# 3          3              soft_tiles
# 4          4                soft_pvc
