# %% [markdown]
# **Load packages**

# %%
import os
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from scipy.stats import kurtosis
from scipy.stats import skew
from sklearn.metrics import accuracy_score, confusion_matrix

sns.set()
PATH="../input/"

# %% [markdown]
# **Load data**

# %%
X_train_df = pd.read_csv(PATH+"/X_train.csv")
X_test_df = pd.read_csv(PATH+"/X_test.csv")
Y_train_df = pd.read_csv(PATH+"/y_train.csv")
target = pd.read_csv(PATH+'/y_train.csv')
sub = pd.read_csv(PATH+"/sample_submission.csv")

# %% [markdown]
# # Feature Engineering

# %%
def fe(data):
    df = pd.DataFrame()
    data['totl_anglr_vel'] = (data['angular_velocity_X']**2 + data['angular_velocity_Y']**2 + data['angular_velocity_Z']**2)** 0.5
    data['totl_linr_acc'] = (data['linear_acceleration_X']**2 + data['linear_acceleration_Y']**2 + data['linear_acceleration_Z']**2)**0.5
    data['totl_xyz'] = (data['orientation_X']**2 + data['orientation_Y']**2 + data['orientation_Z']**2)**0.5
    data['acc_vs_vel'] = data['totl_linr_acc'] / data['totl_anglr_vel']
    
    def mean_change_of_abs_change(x):
        return np.mean(np.diff(np.abs(np.diff(x))))
    
    for col in data.columns:
        if col in ['row_id','series_id','measurement_number']:
            continue
        df[col + '_mean'] = data.groupby(['series_id'])[col].mean()
        df[col + '_median'] = data.groupby(['series_id'])[col].median()
        df[col + '_max'] = data.groupby(['series_id'])[col].max()
        df[col + '_min'] = data.groupby(['series_id'])[col].min()
        df[col + '_std'] = data.groupby(['series_id'])[col].std()
        df[col + '_range'] = df[col + '_max'] - df[col + '_min']
        df[col + '_maxtoMin'] = df[col + '_max'] / df[col + '_min']
        df[col + '_mean_abs_chg'] = data.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        df[col + '_mean_change_of_abs_change'] = data.groupby('series_id')[col].apply(mean_change_of_abs_change)
        df[col + '_abs_max'] = data.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        df[col + '_abs_min'] = data.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        df[col + '_abs_avg'] = (df[col + '_abs_min'] + df[col + '_abs_max'])/2
    return df

train_df = fe(X_train_df)
test_df = fe(X_test_df)
print ("New features: ",train_df.shape[1])
display(train_df.head())
# Out:
# New features:  168
#            orientation_X_mean         ...          acc_vs_vel_abs_avg
# series_id                             ...
# 0                   -0.758666         ...                  525.847045
# 1                   -0.958606         ...                  322.382516
# 2                   -0.512057         ...                  478.552183
# 3                   -0.939169         ...                  408.614740
# 4                   -0.891301         ...                   75.741783
#
# [5 rows x 168 columns]

# %% [markdown]
# **Filling missing NAs and infinite data ∞  by zeroes 0**

# %%
train_df.fillna(0, inplace = True)
train_df.replace(-np.inf, 0, inplace = True)
train_df.replace(np.inf, 0, inplace = True)
test_df.fillna(0, inplace = True)
test_df.replace(-np.inf, 0, inplace = True)
test_df.replace(np.inf, 0, inplace = True)

# %% [markdown]
# **Standarization**

# %%
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(train_df))
X_test_scaled = pd.DataFrame(scaler.transform(test_df))
X_train_scaled.head()
# Out:
#         0         1         2      ...          165       166       167
# 0 -1.080161 -1.079898 -1.089366    ...     0.143058  0.063600  0.139838
# 1 -1.371767 -1.371667 -1.381118    ...    -0.075991 -0.166719 -0.081564
# 2 -0.720492 -0.720416 -0.726728    ...     0.090946  0.030849  0.088373
# 3 -1.343418 -1.343338 -1.352650    ...     0.034807 -0.381534  0.012270
# 4 -1.273604 -1.273001 -1.276691    ...    -0.361545 -0.097638 -0.349948
#
# [5 rows x 168 columns]

# %% [markdown]
# **Label Encoding**

# %%
le = LabelEncoder()
target['surface'] = le.fit_transform(target['surface'])
target.head()
# Out:
#    series_id  group_id  surface
# 0          0        13        2
# 1          1        31        1
# 2          2        20        1
# 3          3        31        1
# 4          4        22        6

# %% [markdown]
# # LightGBM

# %%
folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=59)

# %%
data = X_train_scaled
test = X_test_scaled

# %%
predicted = np.zeros((test.shape[0],9))
measured = np.zeros((data.shape[0]))
score = 0

# %% [markdown]
# ### SUFFLE + BOOTSTRAP

# %%
# https://www.kaggle.com/jiweiliu/lgb-2-leaves-augment#500381
def shuffle_col_vals(x1):
    rand_x = np.array([np.random.choice(x1.shape[0], size=x1.shape[0], replace=False) for i in range(x1.shape[1])]).T
    grid = np.indices(x1.shape)
    rand_y = grid[1]
    return x1[(rand_x, rand_y)]

def augment(x,y,t=2):
    xs,xn = [],[]
    for i in range(t):
        mask = y>0
        x1 = x[mask].copy()
        x1 = shuffle_col_vals(x1)
        xs.append(x1)

    for i in range(t//2):
        mask = y==0
        x1 = x[mask].copy()
        x1 = shuffle_col_vals(x1)
        xn.append(x1)

    xs = np.vstack(xs); xn = np.vstack(xn)
    ys = np.ones(xs.shape[0]);yn = np.zeros(xn.shape[0])
    x = np.vstack([x,xs,xn]); y = np.concatenate([y,ys,yn])
    
    return x,y

# %%
# Grid search
max_depth = [5, 6, 8, 9, 12, 15, 20, 25]
bagging_fraction = [0.2, 0.35, 0.5, 0.7, 1.0]
feature_fraction = [0.2, 0.35, 0.5, 0.7, 1.0]
param_grid = dict(max_depth=max_depth, bagging_fraction=bagging_fraction, feature_fraction=feature_fraction)

# K-Fold cross validation
n_folds = 5
kfold = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=0)

# Model
model = lgb.LGBMClassifier(n_estimators=300, objective='multiclass', eval_metric='multi_error', num_class=9,  nthread= -1, verbose_eval=-1)

grid_search = GridSearchCV(model, param_grid, scoring="accuracy", n_jobs=-1, cv=kfold, verbose=1)
result = grid_search.fit(data.values, target['surface'].values)

print("Best: %f using %s" % (result.best_score_, result.best_params_))
means = result.cv_results_['mean_test_score']
stds = result.cv_results_['std_test_score']
params = result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed: 47.6min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 105.5min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 198.5min
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed: 252.4min finished
# Best: 0.911024 using {'bagging_fraction': 0.2, 'feature_fraction': 0.2, 'max_depth': 15}
# 0.895801 (0.012113) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.2, 'max_depth': 5}
# 0.901312 (0.013345) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.2, 'max_depth': 6}
# 0.903937 (0.010818) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.2, 'max_depth': 8}
# 0.904987 (0.012850) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.2, 'max_depth': 9}
# 0.906824 (0.009427) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.2, 'max_depth': 12}
# 0.911024 (0.011405) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.2, 'max_depth': 15}
# 0.905774 (0.010051) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.2, 'max_depth': 20}
# 0.906824 (0.011024) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.2, 'max_depth': 25}
# 0.891076 (0.010439) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.35, 'max_depth': 5}
# 0.899213 (0.012930) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.35, 'max_depth': 6}
# 0.901575 (0.010015) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.35, 'max_depth': 8}
# 0.904724 (0.010256) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.35, 'max_depth': 9}
# 0.902887 (0.014025) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.35, 'max_depth': 12}
# 0.905774 (0.011570) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.35, 'max_depth': 15}
# 0.905249 (0.011919) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.35, 'max_depth': 20}
# 0.906824 (0.013403) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.35, 'max_depth': 25}
# 0.893438 (0.014067) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.5, 'max_depth': 5}
# 0.896850 (0.013305) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.5, 'max_depth': 6}
# 0.904724 (0.011370) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.5, 'max_depth': 8}
# 0.901575 (0.012777) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.5, 'max_depth': 9}
# 0.904724 (0.011838) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.5, 'max_depth': 12}
# 0.906299 (0.012088) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.5, 'max_depth': 15}
# 0.903937 (0.013005) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.5, 'max_depth': 20}
# 0.902625 (0.010908) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.5, 'max_depth': 25}
# 0.893701 (0.013817) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.7, 'max_depth': 5}
# 0.897113 (0.012000) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.7, 'max_depth': 6}
# 0.901050 (0.010524) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.7, 'max_depth': 8}
# 0.897638 (0.011351) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.7, 'max_depth': 9}
# 0.900262 (0.011896) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.7, 'max_depth': 12}
# 0.901837 (0.009659) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.7, 'max_depth': 15}
# 0.901050 (0.009419) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.7, 'max_depth': 20}
# 0.900787 (0.014674) with: {'bagging_fraction': 0.2, 'feature_fraction': 0.7, 'max_depth': 25}
# 0.892651 (0.013422) with: {'bagging_fraction': 0.2, 'feature_fraction': 1.0, 'max_depth': 5}
# 0.894751 (0.014897) with: {'bagging_fraction': 0.2, 'feature_fraction': 1.0, 'max_depth': 6}
# 0.895538 (0.012402) with: {'bagging_fraction': 0.2, 'feature_fraction': 1.0, 'max_depth': 8}
# 0.900000 (0.015281) with: {'bagging_fraction': 0.2, 'feature_fraction': 1.0, 'max_depth': 9}
# 0.901050 (0.012679) with: {'bagging_fraction': 0.2, 'feature_fraction': 1.0, 'max_depth': 12}
# 0.896588 (0.016600) with: {'bagging_fraction': 0.2, 'feature_fraction': 1.0, 'max_depth': 15}
# 0.902362 (0.013617) with: {'bagging_fraction': 0.2, 'feature_fraction': 1.0, 'max_depth': 20}
# 0.899475 (0.014656) with: {'bagging_fraction': 0.2, 'feature_fraction': 1.0, 'max_depth': 25}
# 0.895801 (0.012113) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.2, 'max_depth': 5}
# 0.901312 (0.013345) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.2, 'max_depth': 6}
# 0.903937 (0.010818) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.2, 'max_depth': 8}
# 0.904987 (0.012850) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.2, 'max_depth': 9}
# 0.906824 (0.009427) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.2, 'max_depth': 12}
# 0.911024 (0.011405) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.2, 'max_depth': 15}
# 0.905774 (0.010051) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.2, 'max_depth': 20}
# 0.906824 (0.011024) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.2, 'max_depth': 25}
# 0.891076 (0.010439) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.35, 'max_depth': 5}
# 0.899213 (0.012930) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.35, 'max_depth': 6}
# 0.901575 (0.010015) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.35, 'max_depth': 8}
# 0.904724 (0.010256) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.35, 'max_depth': 9}
# 0.902887 (0.014025) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.35, 'max_depth': 12}
# 0.905774 (0.011570) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.35, 'max_depth': 15}
# 0.905249 (0.011919) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.35, 'max_depth': 20}
# 0.906824 (0.013403) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.35, 'max_depth': 25}
# 0.893438 (0.014067) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.5, 'max_depth': 5}
# 0.896850 (0.013305) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.5, 'max_depth': 6}
# 0.904724 (0.011370) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.5, 'max_depth': 8}
# 0.901575 (0.012777) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.5, 'max_depth': 9}
# 0.904724 (0.011838) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.5, 'max_depth': 12}
# 0.906299 (0.012088) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.5, 'max_depth': 15}
# 0.903937 (0.013005) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.5, 'max_depth': 20}
# 0.902625 (0.010908) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.5, 'max_depth': 25}
# 0.893701 (0.013817) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.7, 'max_depth': 5}
# 0.897113 (0.012000) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.7, 'max_depth': 6}
# 0.901050 (0.010524) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.7, 'max_depth': 8}
# 0.897638 (0.011351) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.7, 'max_depth': 9}
# 0.900262 (0.011896) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.7, 'max_depth': 12}
# 0.901837 (0.009659) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.7, 'max_depth': 15}
# 0.901050 (0.009419) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.7, 'max_depth': 20}
# 0.900787 (0.014674) with: {'bagging_fraction': 0.35, 'feature_fraction': 0.7, 'max_depth': 25}
# 0.892651 (0.013422) with: {'bagging_fraction': 0.35, 'feature_fraction': 1.0, 'max_depth': 5}
# 0.894751 (0.014897) with: {'bagging_fraction': 0.35, 'feature_fraction': 1.0, 'max_depth': 6}
# 0.895538 (0.012402) with: {'bagging_fraction': 0.35, 'feature_fraction': 1.0, 'max_depth': 8}
# 0.900000 (0.015281) with: {'bagging_fraction': 0.35, 'feature_fraction': 1.0, 'max_depth': 9}
# 0.901050 (0.012679) with: {'bagging_fraction': 0.35, 'feature_fraction': 1.0, 'max_depth': 12}
# 0.896588 (0.016600) with: {'bagging_fraction': 0.35, 'feature_fraction': 1.0, 'max_depth': 15}
# 0.902362 (0.013617) with: {'bagging_fraction': 0.35, 'feature_fraction': 1.0, 'max_depth': 20}
# 0.899475 (0.014656) with: {'bagging_fraction': 0.35, 'feature_fraction': 1.0, 'max_depth': 25}
# 0.895801 (0.012113) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.2, 'max_depth': 5}
# 0.901312 (0.013345) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.2, 'max_depth': 6}
# 0.903937 (0.010818) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.2, 'max_depth': 8}
# 0.904987 (0.012850) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.2, 'max_depth': 9}
# 0.906824 (0.009427) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.2, 'max_depth': 12}
# 0.911024 (0.011405) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.2, 'max_depth': 15}
# 0.905774 (0.010051) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.2, 'max_depth': 20}
# 0.906824 (0.011024) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.2, 'max_depth': 25}
# 0.891076 (0.010439) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.35, 'max_depth': 5}
# 0.899213 (0.012930) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.35, 'max_depth': 6}
# 0.901575 (0.010015) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.35, 'max_depth': 8}
# 0.904724 (0.010256) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.35, 'max_depth': 9}
# 0.902887 (0.014025) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.35, 'max_depth': 12}
# 0.905774 (0.011570) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.35, 'max_depth': 15}
# 0.905249 (0.011919) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.35, 'max_depth': 20}
# 0.906824 (0.013403) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.35, 'max_depth': 25}
# 0.893438 (0.014067) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.5, 'max_depth': 5}
# 0.896850 (0.013305) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.5, 'max_depth': 6}
# 0.904724 (0.011370) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.5, 'max_depth': 8}
# 0.901575 (0.012777) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.5, 'max_depth': 9}
# 0.904724 (0.011838) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.5, 'max_depth': 12}
# 0.906299 (0.012088) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.5, 'max_depth': 15}
# 0.903937 (0.013005) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.5, 'max_depth': 20}
# 0.902625 (0.010908) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.5, 'max_depth': 25}
# 0.893701 (0.013817) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.7, 'max_depth': 5}
# 0.897113 (0.012000) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.7, 'max_depth': 6}
# 0.901050 (0.010524) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.7, 'max_depth': 8}
# 0.897638 (0.011351) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.7, 'max_depth': 9}
# 0.900262 (0.011896) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.7, 'max_depth': 12}
# 0.901837 (0.009659) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.7, 'max_depth': 15}
# 0.901050 (0.009419) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.7, 'max_depth': 20}
# 0.900787 (0.014674) with: {'bagging_fraction': 0.5, 'feature_fraction': 0.7, 'max_depth': 25}
# 0.892651 (0.013422) with: {'bagging_fraction': 0.5, 'feature_fraction': 1.0, 'max_depth': 5}
# 0.894751 (0.014897) with: {'bagging_fraction': 0.5, 'feature_fraction': 1.0, 'max_depth': 6}
# 0.895538 (0.012402) with: {'bagging_fraction': 0.5, 'feature_fraction': 1.0, 'max_depth': 8}
# 0.900000 (0.015281) with: {'bagging_fraction': 0.5, 'feature_fraction': 1.0, 'max_depth': 9}
# 0.901050 (0.012679) with: {'bagging_fraction': 0.5, 'feature_fraction': 1.0, 'max_depth': 12}
# 0.896588 (0.016600) with: {'bagging_fraction': 0.5, 'feature_fraction': 1.0, 'max_depth': 15}
# 0.902362 (0.013617) with: {'bagging_fraction': 0.5, 'feature_fraction': 1.0, 'max_depth': 20}
# 0.899475 (0.014656) with: {'bagging_fraction': 0.5, 'feature_fraction': 1.0, 'max_depth': 25}
# 0.895801 (0.012113) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.2, 'max_depth': 5}
# 0.901312 (0.013345) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.2, 'max_depth': 6}
# 0.903937 (0.010818) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.2, 'max_depth': 8}
# 0.904987 (0.012850) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.2, 'max_depth': 9}
# 0.906824 (0.009427) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.2, 'max_depth': 12}
# 0.911024 (0.011405) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.2, 'max_depth': 15}
# 0.905774 (0.010051) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.2, 'max_depth': 20}
# 0.906824 (0.011024) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.2, 'max_depth': 25}
# 0.891076 (0.010439) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.35, 'max_depth': 5}
# 0.899213 (0.012930) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.35, 'max_depth': 6}
# 0.901575 (0.010015) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.35, 'max_depth': 8}
# 0.904724 (0.010256) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.35, 'max_depth': 9}
# 0.902887 (0.014025) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.35, 'max_depth': 12}
# 0.905774 (0.011570) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.35, 'max_depth': 15}
# 0.905249 (0.011919) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.35, 'max_depth': 20}
# 0.906824 (0.013403) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.35, 'max_depth': 25}
# 0.893438 (0.014067) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.5, 'max_depth': 5}
# 0.896850 (0.013305) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.5, 'max_depth': 6}
# 0.904724 (0.011370) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.5, 'max_depth': 8}
# 0.901575 (0.012777) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.5, 'max_depth': 9}
# 0.904724 (0.011838) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.5, 'max_depth': 12}
# 0.906299 (0.012088) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.5, 'max_depth': 15}
# 0.903937 (0.013005) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.5, 'max_depth': 20}
# 0.902625 (0.010908) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.5, 'max_depth': 25}
# 0.893701 (0.013817) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.7, 'max_depth': 5}
# 0.897113 (0.012000) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.7, 'max_depth': 6}
# 0.901050 (0.010524) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.7, 'max_depth': 8}
# 0.897638 (0.011351) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.7, 'max_depth': 9}
# 0.900262 (0.011896) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.7, 'max_depth': 12}
# 0.901837 (0.009659) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.7, 'max_depth': 15}
# 0.901050 (0.009419) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.7, 'max_depth': 20}
# 0.900787 (0.014674) with: {'bagging_fraction': 0.7, 'feature_fraction': 0.7, 'max_depth': 25}
# 0.892651 (0.013422) with: {'bagging_fraction': 0.7, 'feature_fraction': 1.0, 'max_depth': 5}
# 0.894751 (0.014897) with: {'bagging_fraction': 0.7, 'feature_fraction': 1.0, 'max_depth': 6}
# 0.895538 (0.012402) with: {'bagging_fraction': 0.7, 'feature_fraction': 1.0, 'max_depth': 8}
# 0.900000 (0.015281) with: {'bagging_fraction': 0.7, 'feature_fraction': 1.0, 'max_depth': 9}
# 0.901050 (0.012679) with: {'bagging_fraction': 0.7, 'feature_fraction': 1.0, 'max_depth': 12}
# 0.896588 (0.016600) with: {'bagging_fraction': 0.7, 'feature_fraction': 1.0, 'max_depth': 15}
# 0.902362 (0.013617) with: {'bagging_fraction': 0.7, 'feature_fraction': 1.0, 'max_depth': 20}
# 0.899475 (0.014656) with: {'bagging_fraction': 0.7, 'feature_fraction': 1.0, 'max_depth': 25}
# 0.895801 (0.012113) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.2, 'max_depth': 5}
# 0.901312 (0.013345) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.2, 'max_depth': 6}
# 0.903937 (0.010818) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.2, 'max_depth': 8}
# 0.904987 (0.012850) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.2, 'max_depth': 9}
# 0.906824 (0.009427) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.2, 'max_depth': 12}
# 0.911024 (0.011405) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.2, 'max_depth': 15}
# 0.905774 (0.010051) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.2, 'max_depth': 20}
# 0.906824 (0.011024) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.2, 'max_depth': 25}
# 0.891076 (0.010439) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.35, 'max_depth': 5}
# 0.899213 (0.012930) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.35, 'max_depth': 6}
# 0.901575 (0.010015) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.35, 'max_depth': 8}
# 0.904724 (0.010256) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.35, 'max_depth': 9}
# 0.902887 (0.014025) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.35, 'max_depth': 12}
# 0.905774 (0.011570) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.35, 'max_depth': 15}
# 0.905249 (0.011919) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.35, 'max_depth': 20}
# 0.906824 (0.013403) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.35, 'max_depth': 25}
# 0.893438 (0.014067) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.5, 'max_depth': 5}
# 0.896850 (0.013305) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.5, 'max_depth': 6}
# 0.904724 (0.011370) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.5, 'max_depth': 8}
# 0.901575 (0.012777) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.5, 'max_depth': 9}
# 0.904724 (0.011838) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.5, 'max_depth': 12}
# 0.906299 (0.012088) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.5, 'max_depth': 15}
# 0.903937 (0.013005) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.5, 'max_depth': 20}
# 0.902625 (0.010908) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.5, 'max_depth': 25}
# 0.893701 (0.013817) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.7, 'max_depth': 5}
# 0.897113 (0.012000) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.7, 'max_depth': 6}
# 0.901050 (0.010524) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.7, 'max_depth': 8}
# 0.897638 (0.011351) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.7, 'max_depth': 9}
# 0.900262 (0.011896) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.7, 'max_depth': 12}
# 0.901837 (0.009659) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.7, 'max_depth': 15}
# 0.901050 (0.009419) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.7, 'max_depth': 20}
# 0.900787 (0.014674) with: {'bagging_fraction': 1.0, 'feature_fraction': 0.7, 'max_depth': 25}
# 0.892651 (0.013422) with: {'bagging_fraction': 1.0, 'feature_fraction': 1.0, 'max_depth': 5}
# 0.894751 (0.014897) with: {'bagging_fraction': 1.0, 'feature_fraction': 1.0, 'max_depth': 6}
# 0.895538 (0.012402) with: {'bagging_fraction': 1.0, 'feature_fraction': 1.0, 'max_depth': 8}
# 0.900000 (0.015281) with: {'bagging_fraction': 1.0, 'feature_fraction': 1.0, 'max_depth': 9}
# 0.901050 (0.012679) with: {'bagging_fraction': 1.0, 'feature_fraction': 1.0, 'max_depth': 12}
# 0.896588 (0.016600) with: {'bagging_fraction': 1.0, 'feature_fraction': 1.0, 'max_depth': 15}
# 0.902362 (0.013617) with: {'bagging_fraction': 1.0, 'feature_fraction': 1.0, 'max_depth': 20}
# 0.899475 (0.014656) with: {'bagging_fraction': 1.0, 'feature_fraction': 1.0, 'max_depth': 25}

# %%
for times, (trn_idx, val_idx) in enumerate(folds.split(data.values,target['surface'].values)):
    lgb_train = lgb.Dataset(data.iloc[trn_idx], label=target['surface'][trn_idx])
    lgb_val = lgb.Dataset(data.iloc[val_idx], label=target['surface'][val_idx])
    params = {
    'objective': 'multiclass',
    'metric': 'multi_error', 
    "num_class": 9,
    'nthread': -1,
    'n_estimators': 300,
    'max_depth': result.best_params_['max_depth'],
    'bagging_fraction': result.best_params_['bagging_fraction'],
    'feature_fraction': result.best_params_['feature_fraction']
    }
    model = lgb.train(params, lgb_train, valid_sets=[lgb_train, lgb_val], early_stopping_rounds=50, verbose_eval=-1)

    measured[val_idx] = [np.argmax(x) for x in model.predict(data.iloc[val_idx])]
    predicted += model.predict(test)/folds.n_splits
    score += (1 - model.best_score['valid_1']['multi_error'])
    print("Fold: {} score: {}".format(times, (1 - model.best_score['valid_1']['multi_error'])))
# Out:
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [60]	training's multi_error: 0	valid_1's multi_error: 0.0727273
# Fold: 0 score: 0.9272727272727272
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [59]	training's multi_error: 0	valid_1's multi_error: 0.117188
# Fold: 1 score: 0.8828125
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [57]	training's multi_error: 0	valid_1's multi_error: 0.125326
# Fold: 2 score: 0.8746736292428199
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [57]	training's multi_error: 0	valid_1's multi_error: 0.102094
# Fold: 3 score: 0.8979057591623036
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [29]	training's multi_error: 0.0131234	valid_1's multi_error: 0.0997375
# Fold: 4 score: 0.9002624671916011
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [59]	training's multi_error: 0	valid_1's multi_error: 0.115486
# Fold: 5 score: 0.8845144356955381
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [56]	training's multi_error: 0	valid_1's multi_error: 0.128609
# Fold: 6 score: 0.8713910761154855
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [58]	training's multi_error: 0	valid_1's multi_error: 0.126649
# Fold: 7 score: 0.8733509234828496
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [59]	training's multi_error: 0	valid_1's multi_error: 0.103175
# Fold: 8 score: 0.8968253968253969
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [58]	training's multi_error: 0	valid_1's multi_error: 0.0930851
# Fold: 9 score: 0.9069148936170213

# %%
print('Avg Accuracy RF', score / folds.n_splits)
Y_val_max = measured
val_pred = target['surface']
labels_names = target['surface'].unique()
cnf_matrix = confusion_matrix(Y_val_max, val_pred)
cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(cnf_matrix_norm, index=labels_names, columns=labels_names)

plt.figure(figsize=(20, 7))
ax = plt.axes()
ax.set_title('Validation')
sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax)
plt.show()
# Out:
# Avg Accuracy RF 0.8915923808605741

# %% [markdown]
# **Submission**

# %%
test_sub = [np.argmax(x) for x in model.predict(test)]
sub['surface'] = le.inverse_transform(test_sub)
sub.to_csv('submission.csv', index=False)
sub.head()
# Out:
#    series_id                 surface
# 0          0  hard_tiles_large_space
# 1          1                  carpet
# 2          2                   tiled
# 3          3              soft_tiles
# 4          4              soft_tiles
