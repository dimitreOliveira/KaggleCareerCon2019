# %% [markdown]
# **Load packages**

# %%
import os
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from scipy.stats import kurtosis
from scipy.stats import skew
from sklearn.metrics import accuracy_score, confusion_matrix
from bayes_opt import BayesianOptimization

sns.set()
PATH="../input/"

# %% [markdown]
# **Load data**

# %%
X_train_df = pd.read_csv(PATH+"/X_train.csv")
X_test_df = pd.read_csv(PATH+"/X_test.csv")
Y_train_df = pd.read_csv(PATH+"/y_train.csv")
target = pd.read_csv(PATH+'/y_train.csv')
sub = pd.read_csv(PATH+"/sample_submission.csv")

# %% [markdown]
# # Feature Engineering

# %%
def fe(data):
    df = pd.DataFrame()
    data['totl_anglr_vel'] = (data['angular_velocity_X']**2 + data['angular_velocity_Y']**2 + data['angular_velocity_Z']**2)** 0.5
    data['totl_linr_acc'] = (data['linear_acceleration_X']**2 + data['linear_acceleration_Y']**2 + data['linear_acceleration_Z']**2)**0.5
    data['totl_xyz'] = (data['orientation_X']**2 + data['orientation_Y']**2 + data['orientation_Z']**2)**0.5
    data['acc_vs_vel'] = data['totl_linr_acc'] / data['totl_anglr_vel']
    
    def mean_change_of_abs_change(x):
        return np.mean(np.diff(np.abs(np.diff(x))))
    
    for col in data.columns:
        if col in ['row_id','series_id','measurement_number']:
            continue
        df[col + '_mean'] = data.groupby(['series_id'])[col].mean()
        df[col + '_median'] = data.groupby(['series_id'])[col].median()
        df[col + '_max'] = data.groupby(['series_id'])[col].max()
        df[col + '_min'] = data.groupby(['series_id'])[col].min()
        df[col + '_std'] = data.groupby(['series_id'])[col].std()
        df[col + '_range'] = df[col + '_max'] - df[col + '_min']
        df[col + '_maxtoMin'] = df[col + '_max'] / df[col + '_min']
        df[col + '_mean_abs_chg'] = data.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        df[col + '_mean_change_of_abs_change'] = data.groupby('series_id')[col].apply(mean_change_of_abs_change)
        df[col + '_abs_max'] = data.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        df[col + '_abs_min'] = data.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        df[col + '_abs_avg'] = (df[col + '_abs_min'] + df[col + '_abs_max'])/2
    return df

train_df = fe(X_train_df)
test_df = fe(X_test_df)
print ("New features: ",train_df.shape[1])
display(train_df.head())
# Out:
# New features:  168
#            orientation_X_mean         ...          acc_vs_vel_abs_avg
# series_id                             ...
# 0                   -0.758666         ...                  525.847045
# 1                   -0.958606         ...                  322.382516
# 2                   -0.512057         ...                  478.552183
# 3                   -0.939169         ...                  408.614740
# 4                   -0.891301         ...                   75.741783
#
# [5 rows x 168 columns]

# %% [markdown]
# **Filling missing NAs and infinite data ∞  by zeroes 0**

# %%
train_df.fillna(0, inplace = True)
train_df.replace(-np.inf, 0, inplace = True)
train_df.replace(np.inf, 0, inplace = True)
test_df.fillna(0, inplace = True)
test_df.replace(-np.inf, 0, inplace = True)
test_df.replace(np.inf, 0, inplace = True)

# %% [markdown]
# **Standarization**

# %%
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(train_df))
X_test_scaled = pd.DataFrame(scaler.transform(test_df))
X_train_scaled.head()
# Out:
#         0         1         2      ...          165       166       167
# 0 -1.080161 -1.079898 -1.089366    ...     0.143058  0.063600  0.139838
# 1 -1.371767 -1.371667 -1.381118    ...    -0.075991 -0.166719 -0.081564
# 2 -0.720492 -0.720416 -0.726728    ...     0.090946  0.030849  0.088373
# 3 -1.343418 -1.343338 -1.352650    ...     0.034807 -0.381534  0.012270
# 4 -1.273604 -1.273001 -1.276691    ...    -0.361545 -0.097638 -0.349948
#
# [5 rows x 168 columns]

# %% [markdown]
# **Label Encoding**

# %%
le = LabelEncoder()
target['surface'] = le.fit_transform(target['surface'])
target.head()
# Out:
#    series_id  group_id  surface
# 0          0        13        2
# 1          1        31        1
# 2          2        20        1
# 3          3        31        1
# 4          4        22        6

# %% [markdown]
# # LightGBM

# %%
folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=59)

# %%
data = X_train_scaled
test = X_test_scaled

# %%
predicted = np.zeros((test.shape[0],9))
measured = np.zeros((data.shape[0]))
score = 0

# %% [markdown]
# ### SUFFLE + BOOTSTRAP

# %%
# https://www.kaggle.com/jiweiliu/lgb-2-leaves-augment#500381
def shuffle_col_vals(x1):
    rand_x = np.array([np.random.choice(x1.shape[0], size=x1.shape[0], replace=False) for i in range(x1.shape[1])]).T
    grid = np.indices(x1.shape)
    rand_y = grid[1]
    return x1[(rand_x, rand_y)]

def augment(x,y,t=2):
    xs,xn = [],[]
    for i in range(t):
        mask = y>0
        x1 = x[mask].copy()
        x1 = shuffle_col_vals(x1)
        xs.append(x1)

    for i in range(t//2):
        mask = y==0
        x1 = x[mask].copy()
        x1 = shuffle_col_vals(x1)
        xn.append(x1)

    xs = np.vstack(xs); xn = np.vstack(xn)
    ys = np.ones(xs.shape[0]);yn = np.zeros(xn.shape[0])
    x = np.vstack([x,xs,xn]); y = np.concatenate([y,ys,yn])
    
    return x,y

# %%
def lgbm_evaluate(**params):
    params['max_depth'] = int(params['max_depth'])
    test_pred_proba = np.zeros((train_df.shape[0], 9))
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(data.values, target['surface'].values)):
        X_train, X_valid = data.iloc[train_idx], data.iloc[valid_idx]
        y_train, y_valid = target['surface'][train_idx], target['surface'][valid_idx]
        
        model = lgb.LGBMClassifier(**params, n_estimators=300, n_jobs=-1)
        model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], 
                  eval_metric='multi_logloss', verbose=False, early_stopping_rounds=100)

        y_pred_valid = model.predict_proba(X_valid)

        test_pred_proba[valid_idx] = y_pred_valid

    return accuracy_score(y_valid, y_pred_valid.argmax(1))

# %%
# Random search
max_depth = np.random.choice(range(6, 25), 10, replace=False)
bagging_fraction = np.random.uniform(0.25, 1, 10)
feature_fraction = np.random.uniform(0.25, 1, 10)

param_grid = {
             'max_depth' : (6, 25),
             'bagging_fraction' : (0.25, 1),
             'feature_fraction': (0.25, 1)
             }

result = BayesianOptimization(lgbm_evaluate, param_grid)
result.maximize(init_points=5, n_iter=60)
print(result.max["params"])
# Out:
# |   iter    |  target   | baggin... | featur... | max_depth |
# -------------------------------------------------------------
# |  1        |  0.9388   |  0.3049   |  0.3049   |  21.97    |
# |  2        |  0.9335   |  0.2845   |  0.497    |  14.83    |
# |  3        |  0.9149   |  0.6647   |  0.6922   |  20.42    |
# |  4        |  0.9282   |  0.4651   |  0.8373   |  21.46    |
# |  5        |  0.9229   |  0.3945   |  0.9361   |  23.32    |
# |  6        |  0.9362   |  0.25     |  1.0      |  6.0      |
# |  7        |  0.9309   |  0.25     |  0.25     |  6.004    |
# |  8        |  0.9229   |  0.2513   |  0.9999   |  9.852    |
# |  9        |  0.9229   |  0.25     |  1.0      |  18.82    |
# |  10       |  0.9309   |  0.9969   |  0.9879   |  6.065    |
# |  11       |  0.9335   |  0.25     |  0.25     |  12.7     |
# |  12       |  0.9229   |  0.2549   |  0.9848   |  13.34    |
# |  13       |  0.9388   |  0.25     |  0.25     |  20.8     |
# |  14       |  0.9362   |  0.25     |  0.25     |  16.04    |
# |  15       |  0.9335   |  0.2526   |  0.2714   |  21.97    |
# |  16       |  0.9441   |  0.25     |  0.25     |  7.691    |
# |  17       |  0.9309   |  0.25     |  1.0      |  7.381    |
# |  18       |  0.9388   |  1.0      |  0.25     |  25.0     |
# |  19       |  0.9309   |  0.9926   |  0.2626   |  9.376    |
# |  20       |  0.9388   |  0.25     |  0.25     |  25.0     |
# |  21       |  0.9282   |  0.25     |  0.25     |  9.415    |
# |  22       |  0.9229   |  1.0      |  1.0      |  25.0     |
# |  23       |  0.9335   |  0.9972   |  0.2666   |  13.82    |
# |  24       |  0.9388   |  0.25     |  0.25     |  18.4     |
# |  25       |  0.9441   |  0.9923   |  0.2529   |  7.611    |
# |  26       |  0.9362   |  0.9964   |  0.2545   |  11.68    |
# |  27       |  0.9441   |  0.5507   |  0.25     |  7.047    |
# |  28       |  0.9441   |  0.6174   |  0.2521   |  7.776    |
# |  29       |  0.9309   |  0.9824   |  0.2534   |  6.997    |
# |  30       |  0.9388   |  1.0      |  0.25     |  22.6     |
# |  31       |  0.9282   |  1.0      |  1.0      |  16.08    |
# |  32       |  0.9255   |  1.0      |  1.0      |  11.5     |
# |  33       |  0.9229   |  0.25     |  1.0      |  17.01    |
# |  34       |  0.9309   |  0.9869   |  0.2564   |  16.86    |
# |  35       |  0.9282   |  0.9943   |  0.9811   |  8.117    |
# |  36       |  0.9362   |  0.25     |  0.25     |  11.14    |
# |  37       |  0.9415   |  0.999    |  0.2531   |  15.19    |
# |  38       |  0.9388   |  0.9996   |  0.2528   |  23.88    |
# |  39       |  0.9441   |  0.2723   |  0.2661   |  7.139    |
# |  40       |  0.9441   |  0.5939   |  0.2512   |  7.606    |
# |  41       |  0.9282   |  0.25     |  0.25     |  19.47    |
# |  42       |  0.9388   |  1.0      |  0.25     |  21.73    |
# |  43       |  0.9255   |  0.9757   |  0.2537   |  8.135    |
# |  44       |  0.9362   |  0.9741   |  0.2578   |  10.51    |
# |  45       |  0.9282   |  1.0      |  1.0      |  14.54    |
# |  46       |  0.9229   |  0.25     |  1.0      |  25.0     |
# |  47       |  0.9309   |  1.0      |  1.0      |  7.063    |
# |  48       |  0.9388   |  1.0      |  0.25     |  18.41    |
# |  49       |  0.9362   |  1.0      |  1.0      |  17.98    |
# |  50       |  0.9229   |  1.0      |  1.0      |  22.5     |
# |  51       |  0.9388   |  0.5726   |  0.2526   |  24.47    |
# |  52       |  0.9229   |  0.656    |  0.505    |  17.98    |
# |  53       |  0.9335   |  0.25     |  0.2501   |  14.19    |
# |  54       |  0.9229   |  0.9747   |  0.9936   |  9.937    |
# |  55       |  0.9282   |  0.2505   |  0.9632   |  11.86    |
# |  56       |  0.9335   |  0.6165   |  0.5137   |  7.467    |
# |  57       |  0.9202   |  1.0      |  1.0      |  12.67    |
# |  58       |  0.9388   |  0.25     |  0.25     |  23.43    |
# |  59       |  0.9255   |  0.2549   |  0.9948   |  15.29    |
# |  60       |  0.9388   |  0.6774   |  0.25     |  23.24    |
# |  61       |  0.9415   |  0.25     |  0.25     |  15.18    |
# |  62       |  0.9282   |  0.9998   |  0.2555   |  19.22    |
# |  63       |  0.9441   |  0.4398   |  0.2525   |  7.393    |
# |  64       |  0.9335   |  0.9949   |  0.2525   |  14.78    |
# |  65       |  0.9415   |  0.9981   |  0.2508   |  15.68    |
# =============================================================
# {'bagging_fraction': 0.25, 'feature_fraction': 0.2500000364856548, 'max_depth': 7.690750645117514}

# %%
for times, (trn_idx, val_idx) in enumerate(folds.split(data.values,target['surface'].values)):
    lgb_train = lgb.Dataset(data.iloc[trn_idx], label=target['surface'][trn_idx])
    lgb_val = lgb.Dataset(data.iloc[val_idx], label=target['surface'][val_idx])
    params = {
    'objective': 'multiclass',
    'metric': 'multi_error', 
    "num_class": 9,
    'nthread': -1,
    'n_estimators': 300,
    'max_depth': int(result.max["params"]['max_depth']),
    'bagging_fraction': result.max["params"]['bagging_fraction'],
    'feature_fraction': result.max["params"]['feature_fraction']
    }
    model = lgb.train(params, lgb_train, valid_sets=[lgb_train, lgb_val], early_stopping_rounds=100, verbose_eval=-1)

    measured[val_idx] = [np.argmax(x) for x in model.predict(data.iloc[val_idx])]
    predicted += model.predict(test)/folds.n_splits
    score += (1 - model.best_score['valid_1']['multi_error'])
    print("Fold: {} score: {}".format(times, (1 - model.best_score['valid_1']['multi_error'])))
# Out:
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [65]	training's multi_error: 0	valid_1's multi_error: 0.0779221
# Fold: 0 score: 0.922077922077922
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [69]	training's multi_error: 0	valid_1's multi_error: 0.138021
# Fold: 1 score: 0.8619791666666666
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [65]	training's multi_error: 0	valid_1's multi_error: 0.117493
# Fold: 2 score: 0.8825065274151436
# Training until validation scores don't improve for 100 rounds.
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Early stopping, best iteration is:
# [58]	training's multi_error: 0	valid_1's multi_error: 0.0968586
# Fold: 3 score: 0.9031413612565445
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [64]	training's multi_error: 0	valid_1's multi_error: 0.102362
# Fold: 4 score: 0.8976377952755905
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [68]	training's multi_error: 0	valid_1's multi_error: 0.112861
# Fold: 5 score: 0.8871391076115486
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [65]	training's multi_error: 0	valid_1's multi_error: 0.141732
# Fold: 6 score: 0.8582677165354331
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [70]	training's multi_error: 0	valid_1's multi_error: 0.118734
# Fold: 7 score: 0.8812664907651715
# Training until validation scores don't improve for 100 rounds.
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Early stopping, best iteration is:
# [68]	training's multi_error: 0	valid_1's multi_error: 0.119048
# Fold: 8 score: 0.8809523809523809
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [64]	training's multi_error: 0	valid_1's multi_error: 0.0984043
# Fold: 9 score: 0.901595744680851

# %%
print('Avg Accuracy RF', score / folds.n_splits)
Y_val_max = measured
val_pred = target['surface']
labels_names = target['surface'].unique()
cnf_matrix = confusion_matrix(Y_val_max, val_pred)
cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(cnf_matrix_norm, index=labels_names, columns=labels_names)

plt.figure(figsize=(20, 7))
ax = plt.axes()
ax.set_title('Validation')
sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax)
plt.show()
# Out:
# Avg Accuracy RF 0.8876564213237252

# %% [markdown]
# **Submission**

# %%
test_sub = [np.argmax(x) for x in model.predict(test)]
sub['surface'] = le.inverse_transform(test_sub)
sub.to_csv('submission.csv', index=False)
sub.head()
# Out:
#    series_id                 surface
# 0          0  hard_tiles_large_space
# 1          1                  carpet
# 2          2                   tiled
# 3          3                  carpet
# 4          4              soft_tiles
