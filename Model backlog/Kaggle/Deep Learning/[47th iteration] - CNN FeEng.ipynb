# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from keras import optimizers
from keras.layers import Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers.convolutional import Conv1D, MaxPooling1D
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load data

# %%
train = pd.read_csv('../input/X_train.csv')
labels = pd.read_csv('../input/y_train.csv')
test = pd.read_csv('../input/X_test.csv').sort_values(['series_id', 'measurement_number'])

# %% [markdown]
# ### Join train features with labels

# %%
train = pd.merge(train, labels, how='inner').sort_values(['series_id', 'measurement_number'])
print(train.shape)
display(train.head())
display(train.describe().T)
# Out:
# (487680, 15)
#   row_id  series_id      ...        group_id        surface
# 0    0_0          0      ...              13  fine_concrete
# 1    0_1          0      ...              13  fine_concrete
# 2    0_2          0      ...              13  fine_concrete
# 3    0_3          0      ...              13  fine_concrete
# 4    0_4          0      ...              13  fine_concrete
#
# [5 rows x 15 columns]
#                           count     ...             max
# series_id              487680.0     ...      3809.00000
# measurement_number     487680.0     ...       127.00000
# orientation_X          487680.0     ...         0.98910
# orientation_Y          487680.0     ...         0.98898
# orientation_Z          487680.0     ...         0.15571
# orientation_W          487680.0     ...         0.15477
# angular_velocity_X     487680.0     ...         2.28220
# angular_velocity_Y     487680.0     ...         1.07910
# angular_velocity_Z     487680.0     ...         1.38730
# linear_acceleration_X  487680.0     ...        36.79700
# linear_acceleration_Y  487680.0     ...        73.00800
# linear_acceleration_Z  487680.0     ...        65.83900
# group_id               487680.0     ...        72.00000
#
# [13 rows x 8 columns]

# %% [markdown]
# ### Feature engineering

# %%
def feat_eng(df):
    df['totl_anglr_vel'] = (df['angular_velocity_X']**2 + df['angular_velocity_Y']**2 + df['angular_velocity_Z'])** 0.5
    df['totl_linr_acc'] = (df['linear_acceleration_X']**2 + df['linear_acceleration_Y']**2 + df['linear_acceleration_Z'])**0.5
    df['totl_xyz'] = (df['orientation_X']**2 + df['orientation_Y']**2 + df['orientation_Z'])**0.5
    df['acc_vs_vel'] = df['totl_linr_acc'] / df['totl_anglr_vel']

feat_eng(train)
feat_eng(test)

train.fillna(0, inplace=True)
test.fillna(0, inplace=True)

# %%
def quaternion_to_euler(x, y, z, w):
    import math
    t0 = +2.0 * (w * x + y * z)
    t1 = +1.0 - 2.0 * (x * x + y * y)
    X = math.atan2(t0, t1)

    t2 = +2.0 * (w * y - z * x)
    t2 = +1.0 if t2 > +1.0 else t2
    t2 = -1.0 if t2 < -1.0 else t2
    Y = math.asin(t2)

    t3 = +2.0 * (w * z + x * y)
    t4 = +1.0 - 2.0 * (y * y + z * z)
    Z = math.atan2(t3, t4)

    return X, Y, Z


def perform_feature_engineering(df):
    x, y, z, w = df['orientation_X'].tolist(), df['orientation_Y'].tolist(), df['orientation_Z'].tolist(), df['orientation_W'].tolist()
    nx, ny, nz = [], [], []
    for i in range(len(x)):
        xx, yy, zz = quaternion_to_euler(x[i], y[i], z[i], w[i])
        nx.append(xx)
        ny.append(yy)
        nz.append(zz)
    
    df['euler_x'] = nx
    df['euler_y'] = ny
    df['euler_z'] = nz
    
    df['total_angle'] = np.sqrt(np.square(df['euler_x']) + np.square(df['euler_y']) + np.square(df['euler_z']))
    df['angle_vs_acc'] = df['total_angle'] / df['totl_linr_acc']
    df['angle_vs_vel'] = df['total_angle'] / df['totl_anglr_vel']
    
perform_feature_engineering(train)
perform_feature_engineering(test)

# %%
def mean_change_of_abs_change(x):
        return np.mean(np.diff(np.abs(np.diff(x))))

def mean_abs_change(x):
    return np.mean(np.abs(np.diff(x)))

def summarize_cols(df):
    cols = df.columns
    for col in cols:
        if col in ['row_id', 'series_id', 'measurement_number', 'group_id', 'surface']:
            continue
        df[col + '_mean'] = df.groupby(['series_id'])[col].mean()
        df[col + '_min'] = df.groupby(['series_id'])[col].min()
        df[col + '_max'] = df.groupby(['series_id'])[col].max()
        df[col + '_std'] = df.groupby(['series_id'])[col].std()
#         df[col + '_mad'] = df.groupby(['series_id'])[col].mad()
#         df[col + '_med'] = df.groupby(['series_id'])[col].median()
#         df[col + '_skew'] = df.groupby(['series_id'])[col].skew()
        df[col + '_max_to_min'] = df[col + '_max'] / df[col + '_min']
#         df[col + '_mean_abs_change'] = df.groupby('series_id')[col].apply(mean_abs_change)
#         df[col + '_mean_change_of_abs_change'] = df.groupby('series_id')[col].apply(mean_change_of_abs_change)
#         df[col + '_abs_max'] = df.groupby('series_id')[col].apply(lambda x: np.max(np.abs(x)))
#         df[col + '_abs_min'] = df.groupby('series_id')[col].apply(lambda x: np.min(np.abs(x)))
#         df[col + '_abs_mean'] = df.groupby('series_id')[col].apply(lambda x: np.mean(np.abs(x)))
#         df[col + '_abs_std'] = df.groupby('series_id')[col].apply(lambda x: np.std(np.abs(x)))

old_cols = list(train.columns)
summarize_cols(train)
summarize_cols(test)
add_cols = list(set(list(train.columns)) - set(old_cols))

# %%
train.fillna(0, inplace = True)
train.replace(-np.inf, 0, inplace = True)
train.replace(np.inf, 0, inplace = True)
test.fillna(0, inplace = True)
test.replace(-np.inf, 0, inplace = True)
test.replace(np.inf, 0, inplace = True)

# %% [markdown]
# ### Turn data into series

# %%
def series_to_supervised(data, features, window=1, dropnan=True):
    cols, names = list(), list()
    # Input sequence (t-n, ... t-1)
    for i in range(window, 0, -1):
        cols.append(data[features].shift(i))
        names += [('%s(t-%d)' % (col, i)) for col in features]
    # Current timestep (t=0)
    cols.append(data)
    names += [(col) for col in data.columns]
    # Put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    return agg

# %%
window = 3
features = ['orientation_X', 'orientation_Y', 'orientation_Z', 'orientation_W', 
            'angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z', 
            'linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z', 
            'totl_anglr_vel', 'totl_linr_acc', 'totl_xyz', 'acc_vs_vel' ,
            'series_id'] + add_cols
use_cols = features + ['surface']
# Train
train_series = series_to_supervised(train[use_cols], features, window=window)
train_series.dropna(inplace=True)        
train_series = train_series[(train_series['series_id'] == train_series['series_id(t-%s)' % window])]
display(train_series.head())

# Test
test_series = series_to_supervised(test[features], features, window=window)
test_series.fillna(test_series.mean(), inplace=True)

# Backwards inputation
for index, row in test_series.iterrows():
    for i in range(1, window+1):
        if row['series_id'] != row['series_id(t-%s)' % i]:
            for feature in features:
                if feature != 'series_id':
                    test_series.at[index, '%s(t-%s)' % (feature, i)] = row[feature]
display(test_series.head())
# Out:
#    orientation_X(t-3)      ...              surface
# 3            -0.75853      ...        fine_concrete
# 4            -0.75853      ...        fine_concrete
# 5            -0.75853      ...        fine_concrete
# 6            -0.75852      ...        fine_concrete
# 7            -0.75852      ...        fine_concrete
#
# [5 rows x 461 columns]
#    orientation_X(t-3)         ...          orientation_X_mean
# 0           -0.025773         ...                   -0.025810
# 1           -0.025683         ...                   -0.932288
# 2           -0.025617         ...                   -0.230186
# 3           -0.025773         ...                    0.164661
# 4           -0.025683         ...                   -0.253600
#
# [5 rows x 460 columns]

# %% [markdown]
# ### Pre process the labels

# %%
n_labels =  train_series['surface'].nunique()
labels_names = train_series['surface'].unique()
le = LabelEncoder()
train_series['surface'] = le.fit_transform(train_series['surface'].values)

# %% [markdown]
# ### Train/validation split

# %%
train_splited = []
val_splited = []
gp_surface = train.groupby(['surface', 'series_id'], as_index=False).count()[['surface', 'series_id']]
for surface in gp_surface['surface'].unique():
    df = gp_surface[gp_surface['surface'] == surface]
    tra, val = train_test_split(df, test_size=0.2, random_state=0)
    train_splited += list(tra['series_id'].values)
    val_splited += list(val['series_id'].values)
    
train_splited = pd.DataFrame(train_splited, columns=['series_id'])
val_splited = pd.DataFrame(val_splited, columns=['series_id'])

# %%
X_train = train_splited.merge(train_series)
X_val = val_splited.merge(train_series)

Y_train = X_train['surface']
Y_train = to_categorical(Y_train)
X_train.drop('surface', axis=1, inplace=True)
X_train = X_train

Y_val = X_val['surface']
Y_val = to_categorical(Y_val)
X_val.drop('surface', axis=1, inplace=True)
X_val = X_val

series_cols = list(X_train.filter(regex='series_id'))
X_train.drop(series_cols, axis=1, inplace=True)
X_val.drop(series_cols, axis=1, inplace=True)
test_series.drop(series_cols, axis=1, inplace=True)

print('Train shape', X_train.shape)
print('Validation shape', X_val.shape)
display(X_train.head())
# Out:
# Train shape (380500, 456)
# Validation shape (95750, 456)
#    orientation_X(t-3)         ...          orientation_X_mean
# 0            -0.98321         ...                         0.0
# 1            -0.98321         ...                         0.0
# 2            -0.98321         ...                         0.0
# 3            -0.98321         ...                         0.0
# 4            -0.98321         ...                         0.0
#
# [5 rows x 456 columns]

# %% [markdown]
# ### Feature engineering

# %%
features = list(X_train.columns)
print('Train shape', X_train.shape)
print('Validation shape', X_val.shape)
display(X_train.describe().T)
# Out:
# Train shape (380500, 456)
# Validation shape (95750, 456)
#                                           count     ...               max
# orientation_X(t-3)                     380500.0     ...          0.989100
# orientation_Y(t-3)                     380500.0     ...          0.988980
# orientation_Z(t-3)                     380500.0     ...          0.155710
# orientation_W(t-3)                     380500.0     ...          0.154770
# angular_velocity_X(t-3)                380500.0     ...          2.282200
# angular_velocity_Y(t-3)                380500.0     ...          1.079100
# angular_velocity_Z(t-3)                380500.0     ...          1.387300
# linear_acceleration_X(t-3)             380500.0     ...         36.797000
# linear_acceleration_Y(t-3)             380500.0     ...         55.948000
# linear_acceleration_Z(t-3)             380500.0     ...         65.839000
# totl_anglr_vel(t-3)                    380500.0     ...          2.354958
# totl_linr_acc(t-3)                     380500.0     ...         86.014069
# totl_xyz(t-3)                          380500.0     ...          1.063410
# acc_vs_vel(t-3)                        380500.0     ...       2644.116880
# linear_acceleration_Z_max_to_min(t-3)  380500.0     ...          0.995507
# totl_anglr_vel_max_to_min(t-3)         380500.0     ...         34.016816
# orientation_Y_std(t-3)                 380500.0     ...          0.044266
# linear_acceleration_Y_mean(t-3)        380500.0     ...          4.043316
# euler_x_std(t-3)                       380500.0     ...          0.015686
# orientation_W_min(t-3)                 380500.0     ...          0.153270
# linear_acceleration_Z_min(t-3)         380500.0     ...          0.000000
# totl_xyz_max(t-3)                      380500.0     ...          1.063220
# euler_y_max(t-3)                       380500.0     ...          0.010733
# totl_linr_acc_max(t-3)                 380500.0     ...        122.906924
# angular_velocity_X_min(t-3)            380500.0     ...          0.000000
# euler_z_max(t-3)                       380500.0     ...          3.141576
# euler_z_std(t-3)                       380500.0     ...          3.140594
# angular_velocity_Z_mean(t-3)           380500.0     ...          0.898955
# linear_acceleration_Y_max(t-3)         380500.0     ...         73.008000
# acc_vs_vel_std(t-3)                    380500.0     ...        238.927698
# ...                                         ...     ...               ...
# linear_acceleration_Z_std              380500.0     ...         19.953281
# linear_acceleration_Y_max_to_min       380500.0     ...       2003.296445
# angular_velocity_X_max                 380500.0     ...          2.282200
# euler_x_max_to_min                     380500.0     ...          1.021272
# angular_velocity_Y_std                 380500.0     ...          0.280561
# orientation_X_std                      380500.0     ...          0.042887
# orientation_X_min                      380500.0     ...          0.988220
# orientation_Z_max                      380500.0     ...          0.155660
# linear_acceleration_X_mean             380500.0     ...          1.031167
# angular_velocity_X_std                 380500.0     ...          0.815458
# total_angle_mean                       380500.0     ...          4.239153
# euler_y_std                            380500.0     ...          0.009889
# angle_vs_acc_max                       380500.0     ...          0.000000
# orientation_W_std                      380500.0     ...          0.006942
# totl_linr_acc_mean                     380500.0     ...         16.379495
# orientation_Z_mean                     380500.0     ...          0.152586
# orientation_Z_std                      380500.0     ...          0.007080
# linear_acceleration_Y_min              380500.0     ...          2.913500
# totl_anglr_vel_std                     380500.0     ...          0.579563
# angular_velocity_Y_max                 380500.0     ...          1.079100
# orientation_W_max                      380500.0     ...          0.154770
# orientation_Y_mean                     380500.0     ...          0.988642
# angular_velocity_Z_max                 380500.0     ...          1.387300
# euler_z_min                            380500.0     ...          3.122114
# angle_vs_vel_max                       380500.0     ...        284.557963
# orientation_Z_min                      380500.0     ...          0.151420
# angular_velocity_Z_std                 380500.0     ...          0.519182
# angle_vs_vel_min                       380500.0     ...        362.605454
# angular_velocity_Z_max_to_min          380500.0     ...       1570.173985
# orientation_X_mean                     380500.0     ...          0.988622
#
# [456 rows x 8 columns]

# %% [markdown]
# ### Scale the data

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(test_series)

# %%
X_val_series = X_val.reshape(X_val.shape[0], (window+1), (X_val.shape[1] // (window+1)))
print('Validation set shape', X_val_series.shape)
# Out:
# Validation set shape (95750, 4, 114)

# %%
X_train_series = X_train.reshape(X_train.shape[0], (window+1), (X_train.shape[1] // (window+1)))
X_val_series = X_val.reshape(X_val.shape[0], (window+1), (X_val.shape[1] // (window+1)))
X_test_series = X_test.reshape(X_test.shape[0], (window+1), (X_test.shape[1] // (window+1)))
print('Train set shape', X_train_series.shape)
print('Validation set shape', X_val_series.shape)
print('Test set shape', X_test_series.shape)
# Out:
# Train set shape (380500, 4, 114)
# Validation set shape (95750, 4, 114)
# Test set shape (488448, 4, 114)

# %% [markdown]
# ### Model

# %%
epochs = 120
batch = 128
lr = 0.0001
adam = optimizers.Adam(lr)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(X_train_series.shape[1], X_train_series.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(n_labels, activation="softmax"))
model.compile(loss='categorical_crossentropy', optimizer=adam)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 3, 64)             14656
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 1, 64)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                3250
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 459
# =================================================================
# Total params: 18,365
# Trainable params: 18,365
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train_series, Y_train, validation_data=(X_val_series, Y_val), epochs=epochs, verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 380500 samples, validate on 95750 samples
# Epoch 1/120
#  - 47s - loss: 1.8045 - val_loss: 1.6772
# Epoch 2/120
#  - 47s - loss: 1.5593 - val_loss: 1.5156
# Epoch 3/120
#  - 45s - loss: 1.4381 - val_loss: 1.4116
# Epoch 4/120
#  - 48s - loss: 1.3593 - val_loss: 1.3434
# Epoch 5/120
#  - 46s - loss: 1.2993 - val_loss: 1.2848
# Epoch 6/120
#  - 46s - loss: 1.2505 - val_loss: 1.2526
# Epoch 7/120
#  - 46s - loss: 1.2105 - val_loss: 1.2181
# Epoch 8/120
#  - 45s - loss: 1.1765 - val_loss: 1.1898
# Epoch 9/120
#  - 46s - loss: 1.1477 - val_loss: 1.1555
# Epoch 10/120
#  - 46s - loss: 1.1229 - val_loss: 1.1389
# Epoch 11/120
#  - 47s - loss: 1.0998 - val_loss: 1.1240
# Epoch 12/120
#  - 46s - loss: 1.0792 - val_loss: 1.1005
# Epoch 13/120
#  - 45s - loss: 1.0602 - val_loss: 1.0965
# Epoch 14/120
#  - 46s - loss: 1.0425 - val_loss: 1.0775
# Epoch 15/120
#  - 45s - loss: 1.0263 - val_loss: 1.0638
# Epoch 16/120
#  - 46s - loss: 1.0109 - val_loss: 1.0520
# Epoch 17/120
#  - 47s - loss: 0.9964 - val_loss: 1.0321
# Epoch 18/120
#  - 46s - loss: 0.9824 - val_loss: 1.0209
# Epoch 19/120
#  - 46s - loss: 0.9686 - val_loss: 1.0279
# Epoch 20/120
#  - 45s - loss: 0.9559 - val_loss: 0.9961
# Epoch 21/120
#  - 46s - loss: 0.9434 - val_loss: 0.9934
# Epoch 22/120
#  - 46s - loss: 0.9319 - val_loss: 0.9795
# Epoch 23/120
#  - 47s - loss: 0.9211 - val_loss: 0.9786
# Epoch 24/120
#  - 47s - loss: 0.9108 - val_loss: 0.9613
# Epoch 25/120
#  - 46s - loss: 0.9019 - val_loss: 0.9634
# Epoch 26/120
#  - 47s - loss: 0.8928 - val_loss: 0.9432
# Epoch 27/120
#  - 45s - loss: 0.8847 - val_loss: 0.9459
# Epoch 28/120
#  - 47s - loss: 0.8766 - val_loss: 0.9508
# Epoch 29/120
#  - 45s - loss: 0.8694 - val_loss: 0.9323
# Epoch 30/120
#  - 47s - loss: 0.8618 - val_loss: 0.9662
# Epoch 31/120
#  - 47s - loss: 0.8550 - val_loss: 0.9185
# Epoch 32/120
#  - 46s - loss: 0.8483 - val_loss: 0.9255
# Epoch 33/120
#  - 46s - loss: 0.8409 - val_loss: 0.9133
# Epoch 34/120
#  - 45s - loss: 0.8350 - val_loss: 0.9144
# Epoch 35/120
#  - 46s - loss: 0.8286 - val_loss: 0.9092
# Epoch 36/120
#  - 45s - loss: 0.8230 - val_loss: 0.9074
# Epoch 37/120
#  - 48s - loss: 0.8171 - val_loss: 0.8963
# Epoch 38/120
#  - 46s - loss: 0.8117 - val_loss: 0.8858
# Epoch 39/120
#  - 45s - loss: 0.8064 - val_loss: 0.8871
# Epoch 40/120
#  - 46s - loss: 0.8012 - val_loss: 0.8826
# Epoch 41/120
#  - 45s - loss: 0.7962 - val_loss: 0.8823
# Epoch 42/120
#  - 47s - loss: 0.7916 - val_loss: 0.9197
# Epoch 43/120
#  - 46s - loss: 0.7868 - val_loss: 0.8846
# Epoch 44/120
#  - 48s - loss: 0.7820 - val_loss: 0.8684
# Epoch 45/120
#  - 47s - loss: 0.7779 - val_loss: 0.8850
# Epoch 46/120
#  - 46s - loss: 0.7734 - val_loss: 0.8587
# Epoch 47/120
#  - 46s - loss: 0.7692 - val_loss: 0.8502
# Epoch 48/120
#  - 46s - loss: 0.7647 - val_loss: 0.8623
# Epoch 49/120
#  - 46s - loss: 0.7607 - val_loss: 0.8514
# Epoch 50/120
#  - 46s - loss: 0.7570 - val_loss: 0.8689
# Epoch 51/120
#  - 48s - loss: 0.7532 - val_loss: 0.8746
# Epoch 52/120
#  - 46s - loss: 0.7493 - val_loss: 0.8601
# Epoch 53/120
#  - 45s - loss: 0.7452 - val_loss: 0.8354
# Epoch 54/120
#  - 46s - loss: 0.7421 - val_loss: 0.8376
# Epoch 55/120
#  - 45s - loss: 0.7383 - val_loss: 0.8452
# Epoch 56/120
#  - 47s - loss: 0.7350 - val_loss: 0.8370
# Epoch 57/120
#  - 46s - loss: 0.7319 - val_loss: 0.8342
# Epoch 58/120
#  - 47s - loss: 0.7285 - val_loss: 0.8321
# Epoch 59/120
#  - 46s - loss: 0.7249 - val_loss: 0.8314
# Epoch 60/120
#  - 45s - loss: 0.7221 - val_loss: 0.8262
# Epoch 61/120
#  - 46s - loss: 0.7186 - val_loss: 0.8341
# Epoch 62/120
#  - 45s - loss: 0.7156 - val_loss: 0.8504
# Epoch 63/120
#  - 47s - loss: 0.7132 - val_loss: 0.8511
# Epoch 64/120
#  - 47s - loss: 0.7103 - val_loss: 0.8362
# Epoch 65/120
#  - 46s - loss: 0.7071 - val_loss: 0.8319
# Epoch 66/120
#  - 46s - loss: 0.7050 - val_loss: 0.8362
# Epoch 67/120
#  - 45s - loss: 0.7015 - val_loss: 0.8104
# Epoch 68/120
#  - 47s - loss: 0.6990 - val_loss: 0.8210
# Epoch 69/120
#  - 45s - loss: 0.6957 - val_loss: 0.8170
# Epoch 70/120
#  - 47s - loss: 0.6934 - val_loss: 0.8227
# Epoch 71/120
#  - 47s - loss: 0.6903 - val_loss: 0.8143
# Epoch 72/120
#  - 46s - loss: 0.6878 - val_loss: 0.8010
# Epoch 73/120
#  - 46s - loss: 0.6848 - val_loss: 0.8101
# Epoch 74/120
#  - 45s - loss: 0.6824 - val_loss: 0.8004
# Epoch 75/120
#  - 46s - loss: 0.6794 - val_loss: 0.8020
# Epoch 76/120
#  - 46s - loss: 0.6770 - val_loss: 0.8068
# Epoch 77/120
#  - 46s - loss: 0.6744 - val_loss: 0.7976
# Epoch 78/120
#  - 47s - loss: 0.6725 - val_loss: 0.7935
# Epoch 79/120
#  - 46s - loss: 0.6694 - val_loss: 0.7886
# Epoch 80/120
#  - 46s - loss: 0.6677 - val_loss: 0.7984
# Epoch 81/120
#  - 45s - loss: 0.6646 - val_loss: 0.8117
# Epoch 82/120
#  - 47s - loss: 0.6622 - val_loss: 0.7913
# Epoch 83/120
#  - 46s - loss: 0.6598 - val_loss: 0.8154
# Epoch 84/120
#  - 48s - loss: 0.6573 - val_loss: 0.8083
# Epoch 85/120
#  - 46s - loss: 0.6557 - val_loss: 0.8039
# Epoch 86/120
#  - 45s - loss: 0.6529 - val_loss: 0.7870
# Epoch 87/120
#  - 46s - loss: 0.6512 - val_loss: 0.7887
# Epoch 88/120
#  - 45s - loss: 0.6489 - val_loss: 0.7880
# Epoch 89/120
#  - 47s - loss: 0.6472 - val_loss: 0.7956
# Epoch 90/120
#  - 45s - loss: 0.6449 - val_loss: 0.7950
# Epoch 91/120
#  - 48s - loss: 0.6423 - val_loss: 0.7993
# Epoch 92/120
#  - 46s - loss: 0.6405 - val_loss: 0.7745
# Epoch 93/120
#  - 45s - loss: 0.6383 - val_loss: 0.7922
# Epoch 94/120
#  - 46s - loss: 0.6365 - val_loss: 0.7731
# Epoch 95/120
#  - 45s - loss: 0.6351 - val_loss: 0.7754
# Epoch 96/120
#  - 47s - loss: 0.6322 - val_loss: 0.8086
# Epoch 97/120
#  - 45s - loss: 0.6313 - val_loss: 0.8013
# Epoch 98/120
#  - 48s - loss: 0.6290 - val_loss: 0.7766
# Epoch 99/120
#  - 46s - loss: 0.6267 - val_loss: 0.7782
# Epoch 100/120
#  - 45s - loss: 0.6252 - val_loss: 0.7978
# Epoch 101/120
#  - 46s - loss: 0.6233 - val_loss: 0.7727
# Epoch 102/120
#  - 45s - loss: 0.6211 - val_loss: 0.7696
# Epoch 103/120
#  - 47s - loss: 0.6192 - val_loss: 0.7743
# Epoch 104/120
#  - 45s - loss: 0.6174 - val_loss: 0.7714
# Epoch 105/120
#  - 47s - loss: 0.6154 - val_loss: 0.7714
# Epoch 106/120
#  - 46s - loss: 0.6145 - val_loss: 0.7635
# Epoch 107/120
#  - 45s - loss: 0.6124 - val_loss: 0.7922
# Epoch 108/120
#  - 46s - loss: 0.6102 - val_loss: 0.7707
# Epoch 109/120
#  - 46s - loss: 0.6092 - val_loss: 0.7590
# Epoch 110/120
#  - 46s - loss: 0.6075 - val_loss: 0.7696
# Epoch 111/120
#  - 47s - loss: 0.6058 - val_loss: 0.7584
# Epoch 112/120
#  - 46s - loss: 0.6042 - val_loss: 0.8344
# Epoch 113/120
#  - 46s - loss: 0.6020 - val_loss: 0.7639
# Epoch 114/120
#  - 45s - loss: 0.6002 - val_loss: 0.7596
# Epoch 115/120
#  - 46s - loss: 0.5997 - val_loss: 0.7526
# Epoch 116/120
#  - 46s - loss: 0.5980 - val_loss: 0.7673
# Epoch 117/120
#  - 46s - loss: 0.5966 - val_loss: 0.7519
# Epoch 118/120
#  - 47s - loss: 0.5944 - val_loss: 0.7485
# Epoch 119/120
#  - 46s - loss: 0.5941 - val_loss: 0.7540
# Epoch 120/120
#  - 46s - loss: 0.5915 - val_loss: 0.7513

# %% [markdown]
# #### Model loss plot

# %%
history_pd = pd.DataFrame.from_dict(history.history)
plt.figure(figsize=(20, 8))
ax = plt.axes()
ax.set_title('Model Loss')
sns.lineplot(data=history_pd)
plt.show()

# %% [markdown]
# #### Model evaluation

# %%
train_pred = model.predict_classes(X_train_series)
val_pred = model.predict_classes(X_val_series)
Y_train_max = np.argmax(Y_train, axis=1)
Y_val_max = np.argmax(Y_val, axis=1)

print('Train accuracy', accuracy_score(Y_train_max, train_pred))
print('Validation accuracy', accuracy_score(Y_val_max, val_pred))
# Out:
# Train accuracy 0.7841787122207622
# Validation accuracy 0.7287728459530026

# %% [markdown]
# #### Model confusion matrix

# %%
cnf_matrix = confusion_matrix(Y_train_max, train_pred)
cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(cnf_matrix_norm, index=labels_names, columns=labels_names)

plt.figure(figsize=(20, 7))
ax = plt.axes()
ax.set_title('Train')
sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax)
plt.show()

cnf_matrix = confusion_matrix(Y_val_max, val_pred)
cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(cnf_matrix_norm, index=labels_names, columns=labels_names)

plt.figure(figsize=(20, 7))
ax = plt.axes()
ax.set_title('Validation')
sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax)
plt.show()

# %% [markdown]
# ### Test predictions

# %%
predictions = model.predict_classes(X_test_series)
test['surface'] = le.inverse_transform(predictions)
df = test[['series_id', 'surface']]
df = df.groupby('series_id', as_index=False).agg(lambda x:x.value_counts().index[0])
df.to_csv('submission.csv', index=False)
df.head(10)
# Out:
#    series_id                 surface
# 0          0  hard_tiles_large_space
# 1          1                  carpet
# 2          2                  carpet
# 3          3                  carpet
# 4          4                  carpet
# 5          5                concrete
# 6          6                concrete
# 7          7                  carpet
# 8          8              soft_tiles
# 9          9                  carpet
