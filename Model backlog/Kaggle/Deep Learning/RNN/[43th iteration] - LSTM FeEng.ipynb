# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from keras import optimizers
from keras.layers import Dense, Dropout, LSTM
from keras.utils import to_categorical
from keras.models import Sequential, Model
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load data

# %%
train = pd.read_csv('../input/X_train.csv')
labels = pd.read_csv('../input/y_train.csv')
test = pd.read_csv('../input/X_test.csv').sort_values(['series_id', 'measurement_number'])

# %% [markdown]
# ### Join train features with labels

# %%
train = pd.merge(train, labels, how='inner').sort_values(['series_id', 'measurement_number'])
print(train.shape)
display(train.head())
display(train.describe().T)
# Out:
# (487680, 15)
#   row_id  series_id      ...        group_id        surface
# 0    0_0          0      ...              13  fine_concrete
# 1    0_1          0      ...              13  fine_concrete
# 2    0_2          0      ...              13  fine_concrete
# 3    0_3          0      ...              13  fine_concrete
# 4    0_4          0      ...              13  fine_concrete
#
# [5 rows x 15 columns]
#                           count     ...             max
# series_id              487680.0     ...      3809.00000
# measurement_number     487680.0     ...       127.00000
# orientation_X          487680.0     ...         0.98910
# orientation_Y          487680.0     ...         0.98898
# orientation_Z          487680.0     ...         0.15571
# orientation_W          487680.0     ...         0.15477
# angular_velocity_X     487680.0     ...         2.28220
# angular_velocity_Y     487680.0     ...         1.07910
# angular_velocity_Z     487680.0     ...         1.38730
# linear_acceleration_X  487680.0     ...        36.79700
# linear_acceleration_Y  487680.0     ...        73.00800
# linear_acceleration_Z  487680.0     ...        65.83900
# group_id               487680.0     ...        72.00000
#
# [13 rows x 8 columns]

# %% [markdown]
# ### Feature engineering

# %%
def feat_eng(df):
    df['totl_anglr_vel'] = (df['angular_velocity_X']**2 + df['angular_velocity_Y']**2 + df['angular_velocity_Z'])** 0.5
    df['totl_linr_acc'] = (df['linear_acceleration_X']**2 + df['linear_acceleration_Y']**2 + df['linear_acceleration_Z'])**0.5
    df['totl_xyz'] = (df['orientation_X']**2 + df['orientation_Y']**2 + df['orientation_Z'])**0.5
    df['acc_vs_vel'] = df['totl_linr_acc'] / df['totl_anglr_vel']

feat_eng(train)
feat_eng(test)

train.fillna(0, inplace=True)
test.fillna(0, inplace=True)

# %%
def summarize_cols(df):
    cols = df.columns
    for col in cols:
        if col in ['row_id', 'series_id', 'measurement_number', 'group_id', 'surface']:
            continue
        df[col + '_mean'] = df.groupby(['series_id'])[col].mean()
        df[col + '_min'] = df.groupby(['series_id'])[col].min()
        df[col + '_max'] = df.groupby(['series_id'])[col].max()
        df[col + '_std'] = df.groupby(['series_id'])[col].std()
        df[col + '_mad'] = df.groupby(['series_id'])[col].mad()
        df[col + '_med'] = df.groupby(['series_id'])[col].median()
        df[col + '_skew'] = df.groupby(['series_id'])[col].skew()
        df[col + '_max_to_min'] = df[col + '_max'] / df[col + '_min']
#         df[col + '_mean_abs_change'] = df.groupby('series_id')[col].apply(mean_abs_change)
#         df[col + '_mean_change_of_abs_change'] = df.groupby('series_id')[col].apply(mean_change_of_abs_change)
#         df[col + '_abs_max'] = df.groupby('series_id')[col].apply(lambda x: np.max(np.abs(x)))
#         df[col + '_abs_min'] = df.groupby('series_id')[col].apply(lambda x: np.min(np.abs(x)))
#         df[col + '_abs_mean'] = df.groupby('series_id')[col].apply(lambda x: np.mean(np.abs(x)))
#         df[col + '_abs_std'] = df.groupby('series_id')[col].apply(lambda x: np.std(np.abs(x)))

old_cols = list(train.columns)
summarize_cols(train)
summarize_cols(test)
add_cols = list(set(list(train.columns)) - set(old_cols))

# %%
train.fillna(0, inplace = True)
train.replace(-np.inf, 0, inplace = True)
train.replace(np.inf, 0, inplace = True)
test.fillna(0, inplace = True)
test.replace(-np.inf, 0, inplace = True)
test.replace(np.inf, 0, inplace = True)

# %% [markdown]
# ### Turn data into series

# %%
def series_to_supervised(data, features, window=1, dropnan=True):
    cols, names = list(), list()
    # Input sequence (t-n, ... t-1)
    for i in range(window, 0, -1):
        cols.append(data[features].shift(i))
        names += [('%s(t-%d)' % (col, i)) for col in features]
    # Current timestep (t=0)
    cols.append(data)
    names += [(col) for col in data.columns]
    # Put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    return agg

# %%
window = 3
features = ['orientation_X', 'orientation_Y', 'orientation_Z', 'orientation_W', 
            'angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z', 
            'linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z', 
            'totl_anglr_vel', 'totl_linr_acc', 'totl_xyz', 'acc_vs_vel' ,
            'series_id'] + add_cols
use_cols = features + ['surface']
# Train
train_series = series_to_supervised(train[use_cols], features, window=window)
train_series.dropna(inplace=True)        
train_series = train_series[(train_series['series_id'] == train_series['series_id(t-%s)' % window])]
display(train_series.head())

# Test
test_series = series_to_supervised(test[features], features, window=window)
test_series.fillna(test_series.mean(), inplace=True)

# Backwards inputation
for index, row in test_series.iterrows():
    for i in range(1, window+1):
        if row['series_id'] != row['series_id(t-%s)' % i]:
            for feature in features:
                if feature != 'series_id':
                    test_series.at[index, '%s(t-%s)' % (feature, i)] = row[feature]
display(test_series.head())
# Out:
#    orientation_X(t-3)      ...              surface
# 3            -0.75853      ...        fine_concrete
# 4            -0.75853      ...        fine_concrete
# 5            -0.75853      ...        fine_concrete
# 6            -0.75852      ...        fine_concrete
# 7            -0.75852      ...        fine_concrete
#
# [5 rows x 509 columns]
#    orientation_X(t-3)            ...              linear_acceleration_X_min
# 0           -0.025773            ...                               -3.09390
# 1           -0.025683            ...                               -2.47020
# 2           -0.025617            ...                               -6.49970
# 3           -0.025773            ...                               -0.80127
# 4           -0.025683            ...                               -0.47434
#
# [5 rows x 508 columns]

# %% [markdown]
# ### Pre process the labels

# %%
n_labels =  train_series['surface'].nunique()
labels_names = train_series['surface'].unique()
le = LabelEncoder()
train_series['surface'] = le.fit_transform(train_series['surface'].values)

# %% [markdown]
# ### Train/validation split

# %%
train_splited = []
val_splited = []
gp_surface = train.groupby(['surface', 'series_id'], as_index=False).count()[['surface', 'series_id']]
for surface in gp_surface['surface'].unique():
    df = gp_surface[gp_surface['surface'] == surface]
    tra, val = train_test_split(df, test_size=0.2, random_state=0)
    train_splited += list(tra['series_id'].values)
    val_splited += list(val['series_id'].values)
    
train_splited = pd.DataFrame(train_splited, columns=['series_id'])
val_splited = pd.DataFrame(val_splited, columns=['series_id'])

# %%
X_train = train_splited.merge(train_series)
X_val = val_splited.merge(train_series)

Y_train = X_train['surface']
Y_train = to_categorical(Y_train)
X_train.drop('surface', axis=1, inplace=True)
X_train = X_train

Y_val = X_val['surface']
Y_val = to_categorical(Y_val)
X_val.drop('surface', axis=1, inplace=True)
X_val = X_val

series_cols = list(X_train.filter(regex='series_id'))
X_train.drop(series_cols, axis=1, inplace=True)
X_val.drop(series_cols, axis=1, inplace=True)
test_series.drop(series_cols, axis=1, inplace=True)

print('Train shape', X_train.shape)
print('Validation shape', X_val.shape)
display(X_train.head())
# Out:
# Train shape (380500, 504)
# Validation shape (95750, 504)
#    orientation_X(t-3)            ...              linear_acceleration_X_min
# 0            -0.98321            ...                                    0.0
# 1            -0.98321            ...                                    0.0
# 2            -0.98321            ...                                    0.0
# 3            -0.98321            ...                                    0.0
# 4            -0.98321            ...                                    0.0
#
# [5 rows x 504 columns]

# %% [markdown]
# ### Feature engineering

# %%
features = list(X_train.columns)
print('Train shape', X_train.shape)
print('Validation shape', X_val.shape)
display(X_train.describe().T)
# Out:
# Train shape (380500, 504)
# Validation shape (95750, 504)
#                                           count     ...               max
# orientation_X(t-3)                     380500.0     ...          0.989100
# orientation_Y(t-3)                     380500.0     ...          0.988980
# orientation_Z(t-3)                     380500.0     ...          0.155710
# orientation_W(t-3)                     380500.0     ...          0.154770
# angular_velocity_X(t-3)                380500.0     ...          2.282200
# angular_velocity_Y(t-3)                380500.0     ...          1.079100
# angular_velocity_Z(t-3)                380500.0     ...          1.387300
# linear_acceleration_X(t-3)             380500.0     ...         36.797000
# linear_acceleration_Y(t-3)             380500.0     ...         55.948000
# linear_acceleration_Z(t-3)             380500.0     ...         65.839000
# totl_anglr_vel(t-3)                    380500.0     ...          2.354958
# totl_linr_acc(t-3)                     380500.0     ...         86.014069
# totl_xyz(t-3)                          380500.0     ...          1.063410
# acc_vs_vel(t-3)                        380500.0     ...       2644.116880
# angular_velocity_X_min(t-3)            380500.0     ...          0.000000
# linear_acceleration_Z_max_to_min(t-3)  380500.0     ...          0.995507
# angular_velocity_X_std(t-3)            380500.0     ...          0.815458
# acc_vs_vel_min(t-3)                    380500.0     ...          0.000000
# linear_acceleration_Y_max_to_min(t-3)  380500.0     ...       2003.296445
# angular_velocity_Y_mean(t-3)           380500.0     ...          0.341377
# angular_velocity_X_max_to_min(t-3)     380500.0     ...          0.000000
# orientation_Z_mad(t-3)                 380500.0     ...          0.006172
# linear_acceleration_Y_med(t-3)         380500.0     ...          4.729850
# angular_velocity_Y_std(t-3)            380500.0     ...          0.280561
# totl_xyz_max(t-3)                      380500.0     ...          1.063220
# acc_vs_vel_std(t-3)                    380500.0     ...        238.927698
# orientation_Y_min(t-3)                 380500.0     ...          0.988440
# angular_velocity_Z_max(t-3)            380500.0     ...          1.387300
# angular_velocity_Z_mad(t-3)            380500.0     ...          0.452985
# linear_acceleration_Z_std(t-3)         380500.0     ...         19.953281
# ...                                         ...     ...               ...
# angular_velocity_Z_max_to_min          380500.0     ...       1570.173985
# acc_vs_vel_mean                        380500.0     ...         34.792408
# orientation_W_mad                      380500.0     ...          0.006022
# orientation_Z_max_to_min               380500.0     ...         24.168219
# totl_xyz_mean                          380500.0     ...          1.062678
# angular_velocity_Z_mean                380500.0     ...          0.898955
# totl_anglr_vel_skew                    380500.0     ...         11.313708
# totl_linr_acc_mad                      380500.0     ...         14.298857
# linear_acceleration_Y_max              380500.0     ...         73.008000
# orientation_Y_max_to_min               380500.0     ...          9.814997
# orientation_Y_std                      380500.0     ...          0.044266
# orientation_X_skew                     380500.0     ...          4.128344
# orientation_W_max_to_min               380500.0     ...         52.176956
# totl_linr_acc_skew                     380500.0     ...         11.313708
# linear_acceleration_X_skew             380500.0     ...          2.813943
# orientation_Z_std                      380500.0     ...          0.007080
# linear_acceleration_X_std              380500.0     ...         11.161193
# acc_vs_vel_max                         380500.0     ...       2644.116880
# angular_velocity_Y_max                 380500.0     ...          1.079100
# totl_xyz_std                           380500.0     ...          0.004347
# angular_velocity_X_med                 380500.0     ...          0.192145
# orientation_Z_mean                     380500.0     ...          0.152586
# orientation_Y_mean                     380500.0     ...          0.988642
# totl_anglr_vel_mad                     380500.0     ...          0.481867
# linear_acceleration_X_mean             380500.0     ...          1.031167
# orientation_Y_med                      380500.0     ...          0.988700
# linear_acceleration_Y_min              380500.0     ...          2.913500
# orientation_W_min                      380500.0     ...          0.153270
# totl_xyz_skew                          380500.0     ...          4.068773
# linear_acceleration_X_min              380500.0     ...          0.125160
#
# [504 rows x 8 columns]

# %% [markdown]
# ### Scale the data

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(test_series)

# %%
X_val_series = X_val.reshape(X_val.shape[0], (window+1), (X_val.shape[1] // (window+1)))
print('Validation set shape', X_val_series.shape)
# Out:
# Validation set shape (95750, 4, 126)

# %%
X_train_series = X_train.reshape(X_train.shape[0], (window+1), (X_train.shape[1] // (window+1)))
X_val_series = X_val.reshape(X_val.shape[0], (window+1), (X_val.shape[1] // (window+1)))
X_test_series = X_test.reshape(X_test.shape[0], (window+1), (X_test.shape[1] // (window+1)))
print('Train set shape', X_train_series.shape)
print('Validation set shape', X_val_series.shape)
print('Test set shape', X_test_series.shape)
# Out:
# Train set shape (380500, 4, 126)
# Validation set shape (95750, 4, 126)
# Test set shape (488448, 4, 126)

# %% [markdown]
# ### Model

# %%
epochs = 120
batch = 128
lr = 0.0001
adam = optimizers.Adam(lr)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model = Sequential()
model.add(LSTM(16, activation='relu', return_sequences=True, input_shape=(X_train_series.shape[1], X_train_series.shape[2])))
model.add(LSTM(8, activation='relu'))
model.add(Dense(n_labels, activation="softmax"))
model.compile(loss='categorical_crossentropy', optimizer=adam)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 4, 16)             9152
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 8)                 800
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 81
# =================================================================
# Total params: 10,033
# Trainable params: 10,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train_series, Y_train, validation_data=(X_val_series, Y_val), epochs=epochs, verbose=2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 380500 samples, validate on 95750 samples
# Epoch 1/120
#  - 201s - loss: 1.8102 - val_loss: 1.6477
# Epoch 2/120
#  - 200s - loss: 1.5327 - val_loss: 1.4814
# Epoch 3/120
#  - 199s - loss: 1.4264 - val_loss: 1.4082
# Epoch 4/120
#  - 199s - loss: 1.3474 - val_loss: 1.3319
# Epoch 5/120
#  - 200s - loss: 1.2869 - val_loss: 1.2954
# Epoch 6/120
#  - 201s - loss: 1.2431 - val_loss: 1.2359
# Epoch 7/120
#  - 197s - loss: 1.2051 - val_loss: 1.2149
# Epoch 8/120
#  - 197s - loss: 1.1682 - val_loss: 1.1586
# Epoch 9/120
#  - 197s - loss: 1.1361 - val_loss: 1.1217
# Epoch 10/120
#  - 197s - loss: 1.1058 - val_loss: 1.0990
# Epoch 11/120
#  - 197s - loss: 1.0774 - val_loss: 1.0766
# Epoch 12/120
#  - 198s - loss: 1.0536 - val_loss: 1.0669
# Epoch 13/120
#  - 195s - loss: 1.0327 - val_loss: 1.0472
# Epoch 14/120
#  - 197s - loss: 1.0154 - val_loss: 1.0120
# Epoch 15/120
#  - 195s - loss: 0.9985 - val_loss: 1.0575
# Epoch 16/120
#  - 195s - loss: 0.9847 - val_loss: 1.0118
# Epoch 17/120
#  - 196s - loss: 0.9726 - val_loss: 1.0132
# Epoch 18/120
#  - 195s - loss: 0.9615 - val_loss: 1.0037
# Epoch 19/120
#  - 196s - loss: 0.9512 - val_loss: 1.0284
# Epoch 20/120
#  - 196s - loss: 0.9401 - val_loss: 0.9832
# Epoch 21/120
#  - 194s - loss: 0.9318 - val_loss: 0.9640
# Epoch 22/120
#  - 195s - loss: 0.9226 - val_loss: 0.9677
# Epoch 23/120
#  - 197s - loss: 0.9147 - val_loss: 0.9726
# Epoch 24/120
#  - 193s - loss: 0.9079 - val_loss: 0.9834
# Epoch 25/120
#  - 195s - loss: 0.9003 - val_loss: 1.0208
# Epoch 26/120
#  - 196s - loss: 0.8932 - val_loss: 1.0635
# Epoch 27/120
#  - 193s - loss: 0.8872 - val_loss: 0.9571
# Epoch 28/120
#  - 196s - loss: 0.8793 - val_loss: 0.9976
# Epoch 29/120
#  - 197s - loss: 0.8725 - val_loss: 0.9619
# Epoch 30/120
#  - 200s - loss: 0.8657 - val_loss: 0.9287
# Epoch 31/120
#  - 198s - loss: 0.8595 - val_loss: 0.9238
# Epoch 32/120
#  - 201s - loss: 0.8525 - val_loss: 0.9300
# Epoch 33/120
#  - 202s - loss: 0.8471 - val_loss: 0.9506
# Epoch 34/120
#  - 200s - loss: 0.8425 - val_loss: 0.9287
# Epoch 35/120
#  - 199s - loss: 0.8360 - val_loss: 0.9084
# Epoch 36/120
#  - 200s - loss: 0.8314 - val_loss: 0.9108
# Epoch 37/120
#  - 199s - loss: 0.8268 - val_loss: 0.9210
# Epoch 38/120
#  - 197s - loss: 0.8226 - val_loss: 0.9247
# Epoch 39/120
#  - 196s - loss: 0.8187 - val_loss: 0.9209
# Epoch 40/120
#  - 197s - loss: 0.8131 - val_loss: 0.9133
# Epoch 41/120
#  - 195s - loss: 0.8086 - val_loss: 0.8926
# Epoch 42/120
#  - 196s - loss: 0.8040 - val_loss: 0.8935
# Epoch 43/120
#  - 197s - loss: 0.8008 - val_loss: 0.8690
# Epoch 44/120
#  - 196s - loss: 0.7965 - val_loss: 0.9738
# Epoch 45/120
#  - 196s - loss: 0.7931 - val_loss: 0.8797
# Epoch 46/120
#  - 194s - loss: 0.7889 - val_loss: 0.8603
# Epoch 47/120
#  - 196s - loss: 0.7840 - val_loss: 0.9153
# Epoch 48/120
#  - 198s - loss: 0.7821 - val_loss: 0.8619
# Epoch 49/120
#  - 196s - loss: 0.7764 - val_loss: 0.8636
# Epoch 50/120
#  - 196s - loss: 0.7722 - val_loss: 0.8844
# Epoch 51/120
#  - 194s - loss: 0.7681 - val_loss: 0.8627
# Epoch 52/120
#  - 196s - loss: 0.7638 - val_loss: 0.8607
# Epoch 53/120
#  - 196s - loss: 0.7600 - val_loss: 0.8569
# Epoch 54/120
#  - 194s - loss: 0.7567 - val_loss: 0.8730
# Epoch 55/120
#  - 197s - loss: 0.7528 - val_loss: 0.8778
# Epoch 56/120
#  - 196s - loss: 0.7489 - val_loss: 0.8642
# Epoch 57/120
#  - 196s - loss: 0.7450 - val_loss: 0.8568
# Epoch 58/120
#  - 195s - loss: 0.7414 - val_loss: 0.8384
# Epoch 59/120
#  - 196s - loss: 0.7377 - val_loss: 0.8476
# Epoch 60/120
#  - 196s - loss: 0.7348 - val_loss: 0.8554
# Epoch 61/120
#  - 197s - loss: 0.7329 - val_loss: 0.8719
# Epoch 62/120
#  - 196s - loss: 0.7279 - val_loss: 0.8614
# Epoch 63/120
#  - 199s - loss: 0.7242 - val_loss: 0.8351
# Epoch 64/120
#  - 198s - loss: 0.7208 - val_loss: 0.8743
# Epoch 65/120
#  - 197s - loss: 0.7179 - val_loss: 0.8197
# Epoch 66/120
#  - 199s - loss: 0.7143 - val_loss: 0.8435
# Epoch 67/120
#  - 196s - loss: 0.7125 - val_loss: 0.8438
# Epoch 68/120
#  - 196s - loss: 0.7094 - val_loss: 0.8153
# Epoch 69/120
#  - 196s - loss: 0.7072 - val_loss: 0.8189
# Epoch 70/120
#  - 197s - loss: 0.7023 - val_loss: 0.8225
# Epoch 71/120
#  - 197s - loss: 0.7005 - val_loss: 0.8516
# Epoch 72/120
#  - 195s - loss: 0.6994 - val_loss: 0.8263
# Epoch 73/120
#  - 197s - loss: 0.6961 - val_loss: 0.8389
# Epoch 74/120
#  - 198s - loss: 0.6930 - val_loss: 0.9173
# Epoch 75/120
#  - 197s - loss: 0.6909 - val_loss: 0.8769
# Epoch 76/120
#  - 196s - loss: 0.6878 - val_loss: 0.8130
# Epoch 77/120
#  - 199s - loss: 0.6880 - val_loss: 0.8347
# Epoch 78/120
#  - 195s - loss: 0.6845 - val_loss: 0.8705
# Epoch 79/120
#  - 198s - loss: 0.6819 - val_loss: 0.8100
# Epoch 80/120
#  - 198s - loss: 0.6794 - val_loss: 0.8053
# Epoch 81/120
#  - 196s - loss: 0.6774 - val_loss: 0.8218
# Epoch 82/120
#  - 200s - loss: 0.6759 - val_loss: 0.8317
# Epoch 83/120
#  - 196s - loss: 0.6728 - val_loss: 0.8241
# Epoch 84/120
#  - 196s - loss: 0.6701 - val_loss: 0.8213
# Epoch 85/120
#  - 195s - loss: 0.6684 - val_loss: 0.8048
# Epoch 86/120
#  - 196s - loss: 0.6653 - val_loss: 0.8120
# Epoch 87/120
#  - 195s - loss: 0.6645 - val_loss: 0.8141
# Epoch 88/120
#  - 199s - loss: 0.6627 - val_loss: 0.7792
# Epoch 89/120
#  - 194s - loss: 0.6606 - val_loss: 0.8233
# Epoch 90/120
#  - 197s - loss: 0.6579 - val_loss: 0.8149
# Epoch 91/120
#  - 198s - loss: 0.6560 - val_loss: 0.7836
# Epoch 92/120
#  - 194s - loss: 0.6539 - val_loss: 0.8113
# Epoch 93/120
#  - 198s - loss: 0.6526 - val_loss: 0.8230
# Epoch 94/120
#  - 198s - loss: 0.6514 - val_loss: 0.8081
# Epoch 95/120
#  - 195s - loss: 0.6492 - val_loss: 0.8063
# Epoch 96/120
#  - 196s - loss: 0.6485 - val_loss: 0.7715
# Epoch 97/120
#  - 196s - loss: 0.6458 - val_loss: 0.7752
# Epoch 98/120
#  - 195s - loss: 0.6440 - val_loss: 0.7648
# Epoch 99/120
#  - 195s - loss: 0.6427 - val_loss: 0.7801
# Epoch 100/120
#  - 195s - loss: 0.6409 - val_loss: 0.7618
# Epoch 101/120
#  - 195s - loss: 0.6388 - val_loss: 0.7587
# Epoch 102/120
#  - 197s - loss: 0.6365 - val_loss: 0.7843
# Epoch 103/120
#  - 193s - loss: 0.6366 - val_loss: 0.7819
# Epoch 104/120
#  - 197s - loss: 0.6333 - val_loss: 0.7975
# Epoch 105/120
#  - 196s - loss: 0.6314 - val_loss: 0.7664
# Epoch 106/120
#  - 194s - loss: 0.6307 - val_loss: 0.7685
# Epoch 107/120
#  - 200s - loss: 0.6288 - val_loss: 0.7634
# Epoch 108/120
#  - 196s - loss: 0.6271 - val_loss: 0.8315
# Epoch 109/120
#  - 198s - loss: 0.6247 - val_loss: 0.7696
# Epoch 110/120
#  - 200s - loss: 0.6230 - val_loss: 0.7679
# Epoch 111/120
#  - 199s - loss: 0.6213 - val_loss: 0.7475
# Epoch 112/120
#  - 199s - loss: 0.6190 - val_loss: 0.7408
# Epoch 113/120
#  - 201s - loss: 0.6185 - val_loss: 0.7603
# Epoch 114/120
#  - 198s - loss: 0.6179 - val_loss: 0.7762
# Epoch 115/120
#  - 199s - loss: 0.6174 - val_loss: 0.7643
# Epoch 116/120
#  - 199s - loss: 0.6151 - val_loss: 0.7272
# Epoch 117/120
#  - 199s - loss: 0.6137 - val_loss: 0.7301
# Epoch 118/120
#  - 201s - loss: 0.6121 - val_loss: 0.7570
# Epoch 119/120
#  - 199s - loss: 0.6097 - val_loss: 0.7711
# Epoch 120/120
#  - 197s - loss: 0.6078 - val_loss: 0.7862

# %% [markdown]
# #### Model loss plot

# %%
history_pd = pd.DataFrame.from_dict(history.history)
plt.figure(figsize=(20, 8))
ax = plt.axes()
ax.set_title('Model Loss')
sns.lineplot(data=history_pd)
plt.show()

# %% [markdown]
# #### Model evaluation

# %%
train_pred = model.predict_classes(X_train_series)
val_pred = model.predict_classes(X_val_series)
Y_train_max = np.argmax(Y_train, axis=1)
Y_val_max = np.argmax(Y_val, axis=1)

print('Train accuracy', accuracy_score(Y_train_max, train_pred))
print('Validation accuracy', accuracy_score(Y_val_max, val_pred))
# Out:
# Train accuracy 0.7663258869908016
# Validation accuracy 0.7120835509138381

# %% [markdown]
# #### Model confusion matrix

# %%
cnf_matrix = confusion_matrix(Y_train_max, train_pred)
cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(cnf_matrix_norm, index=labels_names, columns=labels_names)

plt.figure(figsize=(20, 7))
ax = plt.axes()
ax.set_title('Train')
sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax)
plt.show()

cnf_matrix = confusion_matrix(Y_val_max, val_pred)
cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(cnf_matrix_norm, index=labels_names, columns=labels_names)

plt.figure(figsize=(20, 7))
ax = plt.axes()
ax.set_title('Validation')
sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax)
plt.show()

# %% [markdown]
# ### Test predictions

# %%
predictions = model.predict_classes(X_test_series)
test['surface'] = le.inverse_transform(predictions)
df = test[['series_id', 'surface']]
df = df.groupby('series_id', as_index=False).agg(lambda x:x.value_counts().index[0])
df.to_csv('submission.csv', index=False)
df.head(10)
# Out:
#    series_id                 surface
# 0          0  hard_tiles_large_space
# 1          1                concrete
# 2          2                  carpet
# 3          3                  carpet
# 4          4                  carpet
# 5          5                concrete
# 6          6           fine_concrete
# 7          7                    wood
# 8          8           fine_concrete
# 9          9                  carpet
