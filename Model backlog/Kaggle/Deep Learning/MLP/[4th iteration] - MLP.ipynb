# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from keras import optimizers
from keras.layers import Dense
from keras.utils import to_categorical
from keras.models import Sequential, Model
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")

# Set seeds to make the experiment more reproducible.
from tensorflow import set_random_seed
from numpy.random import seed
set_random_seed(0)
seed(0)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load data

# %%
train = pd.read_csv('../input/X_train.csv')
labels = pd.read_csv('../input/y_train.csv')
test = pd.read_csv('../input/X_test.csv')

# %% [markdown]
# ### Join train features with labels

# %%
train = train.join(labels, on='series_id', rsuffix='_')
train.drop('series_id_', axis=1, inplace=True)
print(train.shape)
display(train.head())
# Out:
# (487680, 15)
#   row_id  series_id      ...        group_id        surface
# 0    0_0          0      ...              13  fine_concrete
# 1    0_1          0      ...              13  fine_concrete
# 2    0_2          0      ...              13  fine_concrete
# 3    0_3          0      ...              13  fine_concrete
# 4    0_4          0      ...              13  fine_concrete
#
# [5 rows x 15 columns]

# %% [markdown]
# ### Feature engineering

# %%
def agg_features(df):
    df['orientation'] = df['orientation_X'] + df['orientation_Y'] + df['orientation_Z'] + df['orientation_W']
    df['angular_velocity'] = df['angular_velocity_X'] + df['angular_velocity_Y'] + df['angular_velocity_Z']
    df['linear_acceleration'] = df['linear_acceleration_X'] + df['linear_acceleration_Y'] + df['linear_acceleration_Z']
    
agg_features(train)
agg_features(test)

# %% [markdown]
# ### Pre process the labels

# %%
target = train['surface']
n_labels = target.nunique()
labels_names = target.unique()
le = LabelEncoder()
target = le.fit_transform(target.values)
target = to_categorical(target)
train.drop('surface', axis=1, inplace=True)

# %% [markdown]
# ### Train/validation split

# %%
features = ['orientation_X', 'orientation_Y', 'orientation_Z', 'orientation_W', 
            'angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z', 
            'linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z', 
            'series_id', 'measurement_number', 
            'orientation', 'angular_velocity', 'linear_acceleration']

X_train, X_val, Y_train, Y_val = train_test_split(train[features], target, test_size=0.2, random_state=0, stratify=train['measurement_number'])
X_train.drop(['series_id', 'measurement_number'], axis=1, inplace=True)
X_val.drop(['series_id', 'measurement_number'], axis=1, inplace=True)
features = X_train.columns
print('Train shape', X_train.shape)
print('Validation shape', X_val.shape)
display(X_train.describe())
# Out:
# Train shape (390144, 13)
# Validation shape (97536, 13)
#        orientation_X         ...           linear_acceleration
# count  390144.000000         ...                 390144.000000
# mean       -0.017818         ...                     -6.342697
# std         0.685330         ...                      4.631298
# min        -0.989100         ...                   -183.983100
# 25%        -0.703872         ...                     -8.010352
# 50%        -0.104575         ...                     -6.358870
# 75%         0.651120         ...                     -4.677775
# max         0.989100         ...                    122.698700
#
# [8 rows x 13 columns]

# %% [markdown]
# ### Scale the data

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(test[features])

# %% [markdown]
# ### Model

# %%
epochs = 100
batch = 128
lr = 0.001
adam = optimizers.Adam(lr)

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(n_labels, activation="softmax"))
model.compile(loss='categorical_crossentropy', optimizer=adam)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                896
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_4 (Dense)              (None, 9)                 153
# =================================================================
# Total params: 3,657
# Trainable params: 3,657
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=epochs, verbose=2)
# Out:
# Train on 390144 samples, validate on 97536 samples
# Epoch 1/100
#  - 44s - loss: 1.4674 - val_loss: 1.2489
# Epoch 2/100
#  - 41s - loss: 1.2017 - val_loss: 1.1539
# Epoch 3/100
#  - 42s - loss: 1.1164 - val_loss: 1.0707
# Epoch 4/100
#  - 42s - loss: 1.0625 - val_loss: 1.0771
# Epoch 5/100
#  - 42s - loss: 1.0241 - val_loss: 1.0002
# Epoch 6/100
#  - 41s - loss: 0.9964 - val_loss: 0.9730
# Epoch 7/100
#  - 41s - loss: 0.9715 - val_loss: 0.9342
# Epoch 8/100
#  - 41s - loss: 0.9494 - val_loss: 0.9320
# Epoch 9/100
#  - 43s - loss: 0.9301 - val_loss: 0.9259
# Epoch 10/100
#  - 41s - loss: 0.9115 - val_loss: 0.9122
# Epoch 11/100
#  - 42s - loss: 0.8944 - val_loss: 0.8874
# Epoch 12/100
#  - 42s - loss: 0.8777 - val_loss: 0.8553
# Epoch 13/100
#  - 42s - loss: 0.8610 - val_loss: 0.8667
# Epoch 14/100
#  - 41s - loss: 0.8451 - val_loss: 0.8218
# Epoch 15/100
#  - 41s - loss: 0.8266 - val_loss: 0.8140
# Epoch 16/100
#  - 42s - loss: 0.8117 - val_loss: 0.7704
# Epoch 17/100
#  - 42s - loss: 0.7977 - val_loss: 0.7620
# Epoch 18/100
#  - 41s - loss: 0.7842 - val_loss: 0.7454
# Epoch 19/100
#  - 41s - loss: 0.7677 - val_loss: 0.7766
# Epoch 20/100
#  - 41s - loss: 0.7566 - val_loss: 0.7356
# Epoch 21/100
#  - 42s - loss: 0.7445 - val_loss: 0.7115
# Epoch 22/100
#  - 41s - loss: 0.7330 - val_loss: 0.6994
# Epoch 23/100
#  - 41s - loss: 0.7223 - val_loss: 0.7189
# Epoch 24/100
#  - 42s - loss: 0.7112 - val_loss: 0.7450
# Epoch 25/100
#  - 41s - loss: 0.7001 - val_loss: 0.6617
# Epoch 26/100
#  - 40s - loss: 0.6910 - val_loss: 0.6759
# Epoch 27/100
#  - 41s - loss: 0.6820 - val_loss: 0.6541
# Epoch 28/100
#  - 40s - loss: 0.6737 - val_loss: 0.6598
# Epoch 29/100
#  - 42s - loss: 0.6634 - val_loss: 0.6527
# Epoch 30/100
#  - 41s - loss: 0.6515 - val_loss: 0.6734
# Epoch 31/100
#  - 42s - loss: 0.6458 - val_loss: 0.6043
# Epoch 32/100
#  - 42s - loss: 0.6369 - val_loss: 0.7301
# Epoch 33/100
#  - 40s - loss: 0.6307 - val_loss: 0.5924
# Epoch 34/100
#  - 41s - loss: 0.6225 - val_loss: 0.6064
# Epoch 35/100
#  - 41s - loss: 0.6141 - val_loss: 0.5783
# Epoch 36/100
#  - 41s - loss: 0.6093 - val_loss: 0.6164
# Epoch 37/100
#  - 40s - loss: 0.6027 - val_loss: 0.5716
# Epoch 38/100
#  - 41s - loss: 0.5966 - val_loss: 0.6159
# Epoch 39/100
#  - 42s - loss: 0.5917 - val_loss: 0.5933
# Epoch 40/100
#  - 41s - loss: 0.5855 - val_loss: 0.5644
# Epoch 41/100
#  - 40s - loss: 0.5800 - val_loss: 0.5584
# Epoch 42/100
#  - 41s - loss: 0.5734 - val_loss: 0.5542
# Epoch 43/100
#  - 40s - loss: 0.5683 - val_loss: 0.5423
# Epoch 44/100
#  - 41s - loss: 0.5623 - val_loss: 0.5637
# Epoch 45/100
#  - 40s - loss: 0.5580 - val_loss: 0.5936
# Epoch 46/100
#  - 42s - loss: 0.5512 - val_loss: 0.5490
# Epoch 47/100
#  - 41s - loss: 0.5495 - val_loss: 0.5128
# Epoch 48/100
#  - 41s - loss: 0.5416 - val_loss: 0.5231
# Epoch 49/100
#  - 41s - loss: 0.5375 - val_loss: 0.5538
# Epoch 50/100
#  - 41s - loss: 0.5327 - val_loss: 0.5157
# Epoch 51/100
#  - 41s - loss: 0.5286 - val_loss: 0.5041
# Epoch 52/100
#  - 41s - loss: 0.5249 - val_loss: 0.4964
# Epoch 53/100
#  - 40s - loss: 0.5202 - val_loss: 0.5408
# Epoch 54/100
#  - 42s - loss: 0.5203 - val_loss: 0.5055
# Epoch 55/100
#  - 41s - loss: 0.5127 - val_loss: 0.4978
# Epoch 56/100
#  - 41s - loss: 0.5106 - val_loss: 0.5097
# Epoch 57/100
#  - 41s - loss: 0.5073 - val_loss: 0.4729
# Epoch 58/100
#  - 41s - loss: 0.5053 - val_loss: 0.5322
# Epoch 59/100
#  - 40s - loss: 0.4989 - val_loss: 0.4893
# Epoch 60/100
#  - 41s - loss: 0.4975 - val_loss: 0.5809
# Epoch 61/100
#  - 40s - loss: 0.4944 - val_loss: 0.5360
# Epoch 62/100
#  - 42s - loss: 0.4935 - val_loss: 0.4773
# Epoch 63/100
#  - 40s - loss: 0.4897 - val_loss: 0.5484
# Epoch 64/100
#  - 41s - loss: 0.4867 - val_loss: 0.5633
# Epoch 65/100
#  - 40s - loss: 0.4844 - val_loss: 0.4569
# Epoch 66/100
#  - 41s - loss: 0.4832 - val_loss: 0.5282
# Epoch 67/100
#  - 40s - loss: 0.4817 - val_loss: 0.4539
# Epoch 68/100
#  - 41s - loss: 0.4783 - val_loss: 0.4538
# Epoch 69/100
#  - 42s - loss: 0.4769 - val_loss: 0.4468
# Epoch 70/100
#  - 41s - loss: 0.4750 - val_loss: 0.5131
# Epoch 71/100
#  - 40s - loss: 0.4746 - val_loss: 0.4611
# Epoch 72/100
#  - 41s - loss: 0.4729 - val_loss: 0.4864
# Epoch 73/100
#  - 40s - loss: 0.4664 - val_loss: 0.4248
# Epoch 74/100
#  - 41s - loss: 0.4630 - val_loss: 0.4394
# Epoch 75/100
#  - 40s - loss: 0.4595 - val_loss: 0.4411
# Epoch 76/100
#  - 42s - loss: 0.4587 - val_loss: 0.4128
# Epoch 77/100
#  - 41s - loss: 0.4558 - val_loss: 0.4399
# Epoch 78/100
#  - 41s - loss: 0.4530 - val_loss: 0.4592
# Epoch 79/100
#  - 40s - loss: 0.4513 - val_loss: 0.4693
# Epoch 80/100
#  - 41s - loss: 0.4488 - val_loss: 0.4718
# Epoch 81/100
#  - 40s - loss: 0.4478 - val_loss: 0.4841
# Epoch 82/100
#  - 41s - loss: 0.4441 - val_loss: 0.4460
# Epoch 83/100
#  - 40s - loss: 0.4418 - val_loss: 0.4335
# Epoch 84/100
#  - 43s - loss: 0.4420 - val_loss: 0.4124
# Epoch 85/100
#  - 41s - loss: 0.4394 - val_loss: 0.4474
# Epoch 86/100
#  - 41s - loss: 0.4390 - val_loss: 0.4321
# Epoch 87/100
#  - 41s - loss: 0.4362 - val_loss: 0.4370
# Epoch 88/100
#  - 40s - loss: 0.4347 - val_loss: 0.4172
# Epoch 89/100
#  - 40s - loss: 0.4323 - val_loss: 0.4415
# Epoch 90/100
#  - 40s - loss: 0.4308 - val_loss: 0.4180
# Epoch 91/100
#  - 41s - loss: 0.4303 - val_loss: 0.4158
# Epoch 92/100
#  - 41s - loss: 0.4291 - val_loss: 0.4743
# Epoch 93/100
#  - 41s - loss: 0.4273 - val_loss: 0.4584
# Epoch 94/100
#  - 40s - loss: 0.4253 - val_loss: 0.4291
# Epoch 95/100
#  - 40s - loss: 0.4268 - val_loss: 0.4468
# Epoch 96/100
#  - 40s - loss: 0.4231 - val_loss: 0.4041
# Epoch 97/100
#  - 40s - loss: 0.4230 - val_loss: 0.4215
# Epoch 98/100
#  - 40s - loss: 0.4218 - val_loss: 0.4086
# Epoch 99/100
#  - 41s - loss: 0.4200 - val_loss: 0.4049
# Epoch 100/100
#  - 41s - loss: 0.4215 - val_loss: 0.4965

# %% [markdown]
# #### Model loss plot

# %%
history_pd = pd.DataFrame.from_dict(history.history)
plt.figure(figsize=(20, 8))
ax = plt.axes()
ax.set_title('Model Loss')
sns.lineplot(data=history_pd)
plt.show()

# %% [markdown]
# #### Model evaluation

# %%
train_pred = model.predict_classes(X_train)
val_pred = model.predict_classes(X_val)
Y_train_max = np.argmax(Y_train, axis=1)
Y_val_max = np.argmax(Y_val, axis=1)

print('Train accuracy', accuracy_score(Y_train_max, train_pred))
print('Validation accuracy', accuracy_score(Y_val_max, val_pred))
# Out:
# Train accuracy 0.8149247457349081
# Validation accuracy 0.813597030839895

# %% [markdown]
# #### Model confusion matrix

# %%
cnf_matrix = confusion_matrix(Y_train_max, train_pred)
cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(cnf_matrix_norm, index=labels_names, columns=labels_names)

plt.figure(figsize=(20, 7))
ax = plt.axes()
ax.set_title('Train')
sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax)
plt.show()

cnf_matrix = confusion_matrix(Y_val_max, val_pred)
cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(cnf_matrix_norm, index=labels_names, columns=labels_names)

plt.figure(figsize=(20, 7))
ax = plt.axes()
ax.set_title('Validation')
sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax)
plt.show()

# %% [markdown]
# ### Test predictions

# %%
predictions = model.predict_classes(X_test)
test['surface'] = le.inverse_transform(predictions)
df = test[['series_id', 'surface']]
df = df.groupby('series_id', as_index=False).agg(lambda x:x.value_counts().index[0])
df.to_csv('submission.csv', index=False)
df.head(10)
