# %% [markdown]
# **Load packages**

# %%
import os
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold, RepeatedKFold, GridSearchCV

sns.set()
PATH="../input/"

# %% [markdown]
# **Load data**

# %%
X_train_df = pd.read_csv(PATH+"/career-con-2019/X_train.csv")
X_test_df = pd.read_csv(PATH+"/career-con-2019/X_test.csv")
Y_train_df = pd.read_csv(PATH+"/career-con-2019/y_train.csv")
target = pd.read_csv(PATH+'/career-con-2019/y_train.csv')
sub = pd.read_csv(PATH+"/career-con-2019/sample_submission.csv")

# %% [markdown]
# # Feature Engineering

# %%
def fe(data):
    df = pd.DataFrame()
    data['totl_anglr_vel'] = (data['angular_velocity_X']**2 + data['angular_velocity_Y']**2 + data['angular_velocity_Z']**2)** 0.5
    data['totl_linr_acc'] = (data['linear_acceleration_X']**2 + data['linear_acceleration_Y']**2 + data['linear_acceleration_Z']**2)**0.5
    data['totl_xyz'] = (data['orientation_X']**2 + data['orientation_Y']**2 + data['orientation_Z']**2)**0.5
    data['acc_vs_vel'] = data['totl_linr_acc'] / data['totl_anglr_vel']
    
    def mean_change_of_abs_change(x):
        return np.mean(np.diff(np.abs(np.diff(x))))
    
    for col in data.columns:
        if col in ['row_id','series_id','measurement_number']:
            continue
        df[col + '_mean'] = data.groupby(['series_id'])[col].mean()
        df[col + '_median'] = data.groupby(['series_id'])[col].median()
        df[col + '_max'] = data.groupby(['series_id'])[col].max()
        df[col + '_min'] = data.groupby(['series_id'])[col].min()
        df[col + '_std'] = data.groupby(['series_id'])[col].std()
        df[col + '_range'] = df[col + '_max'] - df[col + '_min']
        df[col + '_maxtoMin'] = df[col + '_max'] / df[col + '_min']
        df[col + '_mean_abs_chg'] = data.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        df[col + '_mean_change_of_abs_change'] = data.groupby('series_id')[col].apply(mean_change_of_abs_change)
        df[col + '_abs_max'] = data.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        df[col + '_abs_min'] = data.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        df[col + '_abs_avg'] = (df[col + '_abs_min'] + df[col + '_abs_max'])/2
    return df

train_df = fe(X_train_df)
test_df = fe(X_test_df)
print ("New features: ",train_df.shape[1])
display(train_df.head())
# Out:
# New features:  168
#            orientation_X_mean         ...          acc_vs_vel_abs_avg
# series_id                             ...
# 0                   -0.758666         ...                  525.847045
# 1                   -0.958606         ...                  322.382516
# 2                   -0.512057         ...                  478.552183
# 3                   -0.939169         ...                  408.614740
# 4                   -0.891301         ...                   75.741783
#
# [5 rows x 168 columns]

# %% [markdown]
# **Filling missing NAs and infinite data ∞  by zeroes 0**

# %%
train_df.fillna(0, inplace = True)
train_df.replace(-np.inf, 0, inplace = True)
train_df.replace(np.inf, 0, inplace = True)
test_df.fillna(0, inplace = True)
test_df.replace(-np.inf, 0, inplace = True)
test_df.replace(np.inf, 0, inplace = True)

# %% [markdown]
# **Standarization**

# %%
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(train_df))
X_test_scaled = pd.DataFrame(scaler.transform(test_df))
X_train_scaled.head()
# Out:
#         0         1         2      ...          165       166       167
# 0 -1.080161 -1.079898 -1.089366    ...     0.143058  0.063600  0.139838
# 1 -1.371767 -1.371667 -1.381118    ...    -0.075991 -0.166719 -0.081564
# 2 -0.720492 -0.720416 -0.726728    ...     0.090946  0.030849  0.088373
# 3 -1.343418 -1.343338 -1.352650    ...     0.034807 -0.381534  0.012270
# 4 -1.273604 -1.273001 -1.276691    ...    -0.361545 -0.097638 -0.349948
#
# [5 rows x 168 columns]

# %% [markdown]
# **Label Encoding**

# %%
le = LabelEncoder()
target['surface'] = le.fit_transform(target['surface'])
target.head()
# Out:
#    series_id  group_id  surface
# 0          0        13        2
# 1          1        31        1
# 2          2        20        1
# 3          3        31        1
# 4          4        22        6

# %% [markdown]
# # Random forest

# %%
folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=59)

# %%
data = X_train_scaled
test = X_test_scaled

# %%
predicted = np.zeros((test.shape[0],9))
measured = np.zeros((data.shape[0]))
score = 0

# %% [markdown]
# ### SUFFLE + BOOTSTRAP

# %%
# https://www.kaggle.com/jiweiliu/lgb-2-leaves-augment#500381
def shuffle_col_vals(x1):
    rand_x = np.array([np.random.choice(x1.shape[0], size=x1.shape[0], replace=False) for i in range(x1.shape[1])]).T
    grid = np.indices(x1.shape)
    rand_y = grid[1]
    return x1[(rand_x, rand_y)]

def augment(x,y,t=2):
    xs,xn = [],[]
    for i in range(t):
        mask = y>0
        x1 = x[mask].copy()
        x1 = shuffle_col_vals(x1)
        xs.append(x1)

    for i in range(t//2):
        mask = y==0
        x1 = x[mask].copy()
        x1 = shuffle_col_vals(x1)
        xn.append(x1)

    xs = np.vstack(xs); xn = np.vstack(xn)
    ys = np.ones(xs.shape[0]);yn = np.zeros(xn.shape[0])
    x = np.vstack([x,xs,xn]); y = np.concatenate([y,ys,yn])
    
    return x,y

# %%
# Grid search
max_depth = [7, 8, 10, 12, 15, 20, 25]
max_features = [0.3, 0.5, 0.7, 0.8, 1.0]
param_grid = dict(max_depth=max_depth, max_features=max_features)

# K-Fold cross validation
n_folds = 5
kfold = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=0)

# Model
model = RandomForestClassifier(n_estimators=300)

grid_search = GridSearchCV(model, param_grid, scoring="accuracy", n_jobs=-1, cv=kfold, verbose=1)
result = grid_search.fit(data.values, target['surface'].values)

print("Best: %f using %s" % (result.best_score_, result.best_params_))
means = result.cv_results_['mean_test_score']
stds = result.cv_results_['std_test_score']
params = result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 5 folds for each of 35 candidates, totalling 175 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 175 out of 175 | elapsed: 71.5min finished
# Best: 0.870341 using {'max_depth': 25, 'max_features': 0.3}
# 0.797900 (0.011584) with: {'max_depth': 7, 'max_features': 0.3}
# 0.798950 (0.014863) with: {'max_depth': 7, 'max_features': 0.5}
# 0.793176 (0.014422) with: {'max_depth': 7, 'max_features': 0.7}
# 0.791076 (0.016064) with: {'max_depth': 7, 'max_features': 0.8}
# 0.784514 (0.016913) with: {'max_depth': 7, 'max_features': 1.0}
# 0.819160 (0.013561) with: {'max_depth': 8, 'max_features': 0.3}
# 0.819685 (0.015644) with: {'max_depth': 8, 'max_features': 0.5}
# 0.814173 (0.019009) with: {'max_depth': 8, 'max_features': 0.7}
# 0.813911 (0.019608) with: {'max_depth': 8, 'max_features': 0.8}
# 0.807349 (0.018812) with: {'max_depth': 8, 'max_features': 1.0}
# 0.851444 (0.013490) with: {'max_depth': 10, 'max_features': 0.3}
# 0.848556 (0.015280) with: {'max_depth': 10, 'max_features': 0.5}
# 0.843832 (0.017786) with: {'max_depth': 10, 'max_features': 0.7}
# 0.839108 (0.015549) with: {'max_depth': 10, 'max_features': 0.8}
# 0.836745 (0.016126) with: {'max_depth': 10, 'max_features': 1.0}
# 0.860892 (0.012249) with: {'max_depth': 12, 'max_features': 0.3}
# 0.856693 (0.013811) with: {'max_depth': 12, 'max_features': 0.5}
# 0.851444 (0.014186) with: {'max_depth': 12, 'max_features': 0.7}
# 0.850394 (0.014947) with: {'max_depth': 12, 'max_features': 0.8}
# 0.842782 (0.014907) with: {'max_depth': 12, 'max_features': 1.0}
# 0.867717 (0.013819) with: {'max_depth': 15, 'max_features': 0.3}
# 0.857743 (0.013641) with: {'max_depth': 15, 'max_features': 0.5}
# 0.852756 (0.012752) with: {'max_depth': 15, 'max_features': 0.7}
# 0.853281 (0.013114) with: {'max_depth': 15, 'max_features': 0.8}
# 0.846982 (0.015293) with: {'max_depth': 15, 'max_features': 1.0}
# 0.868241 (0.014324) with: {'max_depth': 20, 'max_features': 0.3}
# 0.860367 (0.015453) with: {'max_depth': 20, 'max_features': 0.5}
# 0.854856 (0.013589) with: {'max_depth': 20, 'max_features': 0.7}
# 0.856693 (0.015676) with: {'max_depth': 20, 'max_features': 0.8}
# 0.847769 (0.017213) with: {'max_depth': 20, 'max_features': 1.0}
# 0.870341 (0.012950) with: {'max_depth': 25, 'max_features': 0.3}
# 0.859580 (0.014696) with: {'max_depth': 25, 'max_features': 0.5}
# 0.861155 (0.015217) with: {'max_depth': 25, 'max_features': 0.7}
# 0.856693 (0.014666) with: {'max_depth': 25, 'max_features': 0.8}
# 0.850394 (0.013493) with: {'max_depth': 25, 'max_features': 1.0}

# %%
for times, (trn_idx, val_idx) in enumerate(folds.split(data.values,target['surface'].values)):
    
    max_depth = result.best_params_['max_depth']
    max_features = result.best_params_['max_features']
    model = RandomForestClassifier(n_estimators=300, max_depth=max_depth, max_features=max_features, bootstrap=True, class_weight="balanced", random_state=2019)

    model.fit(data.iloc[trn_idx],target['surface'][trn_idx])
    measured[val_idx] = model.predict(data.iloc[val_idx])
    predicted += model.predict_proba(test)/folds.n_splits
    score += model.score(data.iloc[val_idx],target['surface'][val_idx])
    print("Fold: {} score: {}".format(times,model.score(data.iloc[val_idx],target['surface'][val_idx])))

    importances = model.feature_importances_
    indices = np.argsort(importances)
    features = data.columns
    
    if model.score(data.iloc[val_idx],target['surface'][val_idx]) > 0.9500:
        hm = 30
        plt.figure(figsize=(7, 10))
        plt.title('Feature Importances')
        plt.barh(range(len(indices[:hm])), importances[indices][:hm], color='b', align='center')
        plt.yticks(range(len(indices[:hm])), [features[i] for i in indices])
        plt.xlabel('Relative Importance')
        plt.show()
# Out:
# Fold: 0 score: 0.9090909090909091
# Fold: 1 score: 0.8671875
# Fold: 2 score: 0.8668407310704961
# Fold: 3 score: 0.8691099476439791
# Fold: 4 score: 0.884514435695538
# Fold: 5 score: 0.8766404199475065
# Fold: 6 score: 0.84251968503937
# Fold: 7 score: 0.8839050131926122
# Fold: 8 score: 0.8677248677248677
# Fold: 9 score: 0.8962765957446809

# %%
print('Avg Accuracy RF', score / folds.n_splits)
Y_val_max = measured
val_pred = target['surface']
labels_names = target['surface'].unique()
cnf_matrix = confusion_matrix(Y_val_max, val_pred)
cnf_matrix_norm = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(cnf_matrix_norm, index=labels_names, columns=labels_names)

plt.figure(figsize=(20, 7))
ax = plt.axes()
ax.set_title('Validation')
sns.heatmap(df_cm, annot=True, fmt='.2f', cmap="Blues", ax=ax)
plt.show()
# Out:
# Avg Accuracy RF 0.876381010514996

# %% [markdown]
# **Submission**

# %%
test_sub = model.predict(test)
sub['surface'] = le.inverse_transform(test_sub)
sub.to_csv('submission.csv', index=False)
sub.head()
# Out:
#    series_id                 surface
# 0          0  hard_tiles_large_space
# 1          1                  carpet
# 2          2                   tiled
# 3          3                  carpet
# 4          4              soft_tiles
